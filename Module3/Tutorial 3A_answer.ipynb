# %% [markdown]
# # Tutorial 3A: Data Auditing

# %% [markdown]
# ## Data cleansing process:
#
# Data cleansing is an iterative process. The first step of the cleansing process is data auditing. In this step, we identify the types of anomalies that reduce the data quality.  Data auditing is about programmatically checking the data using some validation rules that are pre-specified, and then creating a report of the quality of the data and its problems. We often apply some statistical tests in this step for examining the data.
# Data Anomalies can be classified at a high level into three categories:
#
# ##### Syntactical Anomalies:
# describe characteristics concerning the format and values used for representation of the entities. Syntactical anomalies such as: lexical errors, domain format errors, syntactical error and irregularities.
# ###### Semantic Anomalies:
# hinder the data collection from being a comprehensive and non-redundant representation of the mini-world. These types of anomalies include: Integrity constraint violations, contradictions, duplicates and invalid tuples
# ##### Coverage Anomalies:
# decrease the amount of entities and entity properties from the mini-world that are represented in the data collection. Coverage anomalies are categorised as: missing values and missing tuples
#
#
# We give examples in this part of the auditing process that is applied to discover different anomalies in data.

# %% [markdown]
# ***
# ## Example 1: Titanic data
#
#
#
# The Titanic data is the data set provided in the Kaggle competition "Titanic: Machine Learning from Disaster". The competition has been available from 28 Sep 2012 with more than 4000 teams joining the competition.
#
# "The sinking of the RMS Titanic is one of the most infamous shipwrecks in history.  On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper-class.
#
# In this challenge, we ask you to complete the analysis of what sorts of people were likely to survive. In particular, we ask you to apply the tools of machine learning to predict which passengers survived the tragedy"
#
# "https://www.kaggle.com/c/titanic"
#
#
# ** Variable description: **
#
# survival: Survival <br>
# pclass: Passenger Class <br>
# name: Name <br>
# sex: Sex <br>
# age: Age <br>
# sibsp: Number of Siblings/Spouses Aboard <br>
# parch: Number of Parents/Children Aboard <br>
# ticket: Ticket Number <br>
# fare: Passenger Fare <br>
# cabin: Cabin <br>
# embarked: Port of Embarkation
#
# For convenience, we will use the demo version of Titanic data included in the seaborne library: https://github.com/mwaskom/seaborn-data/blob/master/titanic.csv
#
# We will need to install the seaborne library first :

# %% [markdown]
# !conda install seaborn -y

# %% [markdown]
# Libraries used include:

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### First, load the data using sns library

# %%
df1=sns.load_dataset("titanic")

# %% [markdown]
# ### Display the first 30 rows

# %%
df1.head(30)
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.0      1      0    7.2500        S   Third
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 2          1       3  female  26.0      0      0    7.9250        S   Third
# 3          1       1  female  35.0      1      0   53.1000        S   First
# 4          0       3    male  35.0      0      0    8.0500        S   Third
# 5          0       3    male   NaN      0      0    8.4583        Q   Third
# 6          0       1    male  54.0      0      0   51.8625        S   First
# 7          0       3    male   2.0      3      1   21.0750        S   Third
# 8          1       3  female  27.0      0      2   11.1333        S   Third
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# 11         1       1  female  58.0      0      0   26.5500        S   First
# 12         0       3    male  20.0      0      0    8.0500        S   Third
# 13         0       3    male  39.0      1      5   31.2750        S   Third
# 14         0       3  female  14.0      0      0    7.8542        S   Third
# 15         1       2  female  55.0      0      0   16.0000        S  Second
# 16         0       3    male   2.0      4      1   29.1250        Q   Third
# 17         1       2    male   NaN      0      0   13.0000        S  Second
# 18         0       3  female  31.0      1      0   18.0000        S   Third
# 19         1       3  female   NaN      0      0    7.2250        C   Third
# 20         0       2    male  35.0      0      0   26.0000        S  Second
# 21         1       2    male  34.0      0      0   13.0000        S  Second
# 22         1       3  female  15.0      0      0    8.0292        Q   Third
# 23         1       1    male  28.0      0      0   35.5000        S   First
# 24         0       3  female   8.0      3      1   21.0750        S   Third
# 25         1       3  female  38.0      1      5   31.3875        S   Third
# 26         0       3    male   NaN      0      0    7.2250        C   Third
# 27         0       1    male  19.0      3      2  263.0000        S   First
# 28         1       3  female   NaN      0      0    7.8792        Q   Third
# 29         0       3    male   NaN      0      0    7.8958        S   Third
#
#       who adult_male deck  embark_town alive  alone
# 0     man       True  NaN  Southampton    no  False
# 1   woman      False    C    Cherbourg   yes  False
# 2   woman      False  NaN  Southampton   yes   True
# 3   woman      False    C  Southampton   yes  False
# 4     man       True  NaN  Southampton    no   True
# 5     man       True  NaN   Queenstown    no   True
# 6     man       True    E  Southampton    no   True
# 7   child      False  NaN  Southampton    no  False
# 8   woman      False  NaN  Southampton   yes  False
# 9   child      False  NaN    Cherbourg   yes  False
# 10  child      False    G  Southampton   yes  False
# 11  woman      False    C  Southampton   yes   True
# 12    man       True  NaN  Southampton    no   True
# 13    man       True  NaN  Southampton    no  False
# 14  child      False  NaN  Southampton    no   True
# 15  woman      False  NaN  Southampton   yes   True
# 16  child      False  NaN   Queenstown    no  False
# 17    man       True  NaN  Southampton   yes   True
# 18  woman      False  NaN  Southampton    no  False
# 19  woman      False  NaN    Cherbourg   yes   True
# 20    man       True  NaN  Southampton    no   True
# 21    man       True    D  Southampton   yes   True
# 22  child      False  NaN   Queenstown   yes   True
# 23    man       True    A  Southampton   yes   True
# 24  child      False  NaN  Southampton    no  False
# 25  woman      False  NaN  Southampton   yes  False
# 26    man       True  NaN    Cherbourg    no   True
# 27    man       True    C  Southampton    no  False
# 28  woman      False  NaN   Queenstown   yes   True
# 29    man       True  NaN  Southampton    no   True

# %% [markdown]
# ### How many records?

# %%
df1.shape
# Out:
# (891, 15)

# %% [markdown]
# ## Is there any missing records?

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.2+ KB

# %% [markdown]
# ### How many missing values in each column?

# %%
df1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# #### Probably one of the more useful summary tools is 'describe()'It picks out all the numeric data, gives us totals, means, max, min etc. Tty it!

# %%
df1.describe()
# Out:
# /usr/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000         NaN    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000         NaN    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000         NaN    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# Interesting findings:
#
# * You can notice that (left to right) pclass & survived are compelete with no missing values, however about 200 ages are missing.
# * Some fares are 0 (the captain?)
# * The max fare is 512.329200. It seemed to be very high or is it might be converted from another units?
# * Values in pclass look like 1,2,3.
#
# ### What are the levels of other categorical variables?
#
# Lets look at unique values of categorical variables. Here we used [np.isreal](http://docs.scipy.org/doc/numpy-1.9.0/reference/generated/numpy.isreal.html) to check the type of each element ([applymap](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.applymap.html) applies a function to each element in the DataFrame).
#
# [any()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.any.html) is a function return whether any element is True over requested axis.

# %%
df1.applymap(np.isreal).any(0)
# Out:
# survived        True
# pclass          True
# sex            False
# age             True
# sibsp           True
# parch           True
# fare            True
# embarked        True
# class          False
# who            False
# adult_male      True
# deck            True
# embark_town     True
# alive          False
# alone           True
# dtype: bool

# %%
df1.embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df1.applymap(np.isreal).all(0)
# Out:
# survived        True
# pclass          True
# sex            False
# age             True
# sibsp           True
# parch           True
# fare            True
# embarked       False
# class          False
# who            False
# adult_male      True
# deck           False
# embark_town    False
# alive          False
# alone           True
# dtype: bool

# %%
numericalColumns = (df1.applymap(np.isreal).all(0))
categoricalColumns = ~numericalColumns
print(categoricalColumns)
# Out:
# survived       False
# pclass         False
# sex             True
# age            False
# sibsp          False
# parch          False
# fare           False
# embarked        True
# class           True
# who             True
# adult_male     False
# deck            True
# embark_town     True
# alive           True
# alone          False
# dtype: bool

# %% [markdown]
# ### What are all possible values of each categorical attribute?

# %%
for col in df1.iloc[:,categoricalColumns.tolist()]: 
    print(col)
    print(df1[col].unique())
# Out:
# sex
# ['male' 'female']
# embarked
# ['S' 'C' 'Q' nan]
# class
# [Third, First, Second]
# Categories (3, object): [Third, First, Second]
# who
# ['man' 'woman' 'child']
# deck
# [NaN, C, E, G, D, A, B, F]
# Categories (7, object): [C, E, G, D, A, B, F]
# embark_town
# ['Southampton' 'Cherbourg' 'Queenstown' nan]
# alive
# ['no' 'yes']

# %% [markdown]
# ### Next, we will check data consistency. Let's check first the age column with incosistency.
#
# Check the age with gender. Were all children's aged under 18? Were all women labeled as females?

# %%
df1['age'].groupby(df1['who']).describe()
# Out:
# /usr/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# who
# child  count     83.000000
#        mean       6.369518
#        std        4.729063
#        min        0.420000
#        25%        2.000000
#        50%        5.000000
#        75%        9.500000
#        max       15.000000
# man    count    413.000000
#        mean      33.173123
#        std       12.906908
#        min       16.000000
#        25%             NaN
#        50%             NaN
#        75%             NaN
#        max       80.000000
# woman  count    218.000000
#        mean      32.000000
#        std       11.495441
#        min       16.000000
#        25%             NaN
#        50%             NaN
#        75%             NaN
#        max       63.000000
# Name: age, dtype: float64

# %%
pd.crosstab(df1["who"],df1["sex"])
# Out:
# sex    female  male
# who
# child      43    40
# man         0   537
# woman     271     0

# %% [markdown]
# embarked is 'S', 'C', nan, 'Q'.
#
# What do the letters mean. How many missing values are there? Is this the same as embark_town?
#
# Check the wikipedia page to find out that https://en.wikipedia.org/wiki/RMS_Titanic"Southampton... Additional passengers were picked up at Cherbourg and Queenstown."
#
# Let's check if consistent information is provided in embarked and embark_town

# %%
pd.crosstab(df1["embark_town"],df1["embarked"])
# Out:
# embarked       C   Q    S
# embark_town
# Cherbourg    168   0    0
# Queenstown     0  77    0
# Southampton    0   0  644

# %% [markdown]
# Nice!
#
#
# ## Example 2: Real Data from a study into Autism Spectrum Disorder

# %%
from IPython.core.display import HTML
css = open('style/style-table.css').read() + open('style/style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %% [markdown]
# <div style=" color:black; text-shadow: 1px 1px brown; font-size:2em;  background:url(style/images/Lucerne3.jpg)">,
#     <h1 align="center">Scientific Python
#     <img src="style/images/kundalini_pythons_gold_outline.png" style="height:360px; align:center; " ></h1>
#     </div>

# %% [markdown]
# ## Real data problems
#
# Now that's have a look at reality. We are going to investigate a dataset from a study on Autism-Spectrum Disorder (de-identified for education purpose). The data made available by [Talitha Ford](https://figshare.com/s/d64342f300a092c303b0)
#
# The dataset contains fields collected on demographics, medical history and other risk factors.
#
# ### AQ test
#
# This clinical test was developed by [Simon Baron-Cohen](http://www.ncbi.nlm.nih.gov/pubmed/11439754) and commonly used as an indicator of high function autism or Asperger syndrome It produces a score between 0 and 50. 32 and above are a strong indicator of ASD.
#
# You can view an online version of the test which explains how the scores are interpreted [not a scholarly source](http://aspergerstest.net/interpreting-aq-test-results/)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Pandas has a number of methods to import data. The data file is in .xlsx format so we'll use the .read_excel method.

# %% [markdown]
# ### Visually inspect the data
#
#
# Open the data in excel and have a check

# %%
pd.read_excel('Phase2_ParticipantInfo_deident_data.xlsx').head(10)
# Out:
#   Phase 2 participant demographics Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0                              NaN        NaN        NaN         NaN
# 1                               ID        Age     Gender  Years Educ
# 2                              Low        NaN        NaN         NaN
# 3                               46         26     Female           6
# 4                               62         26          F         3.5
# 5                              131         27       Male          13
# 6                              180         19          F           2
# 7                              148         19          M           2
# 8                              237         18          F           3
# 9                              233         18     Female           3
#
#        Unnamed: 4                         Unnamed: 5         Unnamed: 6  \
# 0             NaN                                NaN                NaN
# 1  Education Comp                    Study disapline         Occupation
# 2             NaN                                NaN                NaN
# 3   Undergraduate              Nutrition & Dietetics  Dietician/Teacher
# 4  Secondary/TAFE              International studies        Electrician
# 5   Post Graduate                   Medical Research    Research Fellow
# 6       Secondary                 Psych and Forensic            Student
# 7   Undergraduate                         psychology            student
# 8       Secondary                         Psychology            Butcher
# 9       Secondary  Business (advertising)/Psychology            Student
#
#   Unnamed: 7  Unnamed: 8                              Unnamed: 9  \
# 0        NaN         NaN                                     NaN
# 1    Hearing  Medication                                     NaN
# 2        NaN         NaN                                     NaN
# 3        No.         No.                                     NaN
# 4         no          no                                     NaN
# 5        No.         yes                                  zertex
# 6         No          No                                     NaN
# 7        No.          no                                     NaN
# 8        No.          No                                     NaN
# 9        No.        Yes.  The Pill, Ventolin as needed, Seritide
#
#         ...                                           Unnamed: 11  \
# 0       ...                                                   NaN
# 1       ...                                                   NaN
# 2       ...                                                   NaN
# 3       ...         Grandfather had Seasonal Affective Depression
# 4       ...                                                   NaN
# 5       ...                                                   NaN
# 6       ...                                                   NaN
# 7       ...                                         Aunty Anxiety
# 8       ...                                                   NaN
# 9       ...                             Schizophrenia, Depression
#
#                  Unnamed: 12           Unnamed: 13       Unnamed: 14  \
# 0                        NaN                   NaN               NaN
# 1  1st degree Family history             Diagnosis  Personal History
# 2                        NaN                   NaN               NaN
# 3                         No                   NaN                No
# 4                        yes  Paternal cyclothymia                No
# 5                        No.                   NaN               NaN
# 6                         No                   NaN                No
# 7                         No                   NaN                No
# 8                         No                   NaN               NA?
# 9                        No.                   NaN                No
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18   Unnamed: 19  \
# 0         NaN         NaN         NaN         NaN           NaN
# 1   Diagnosis  Medicated?     Smoker?   Frequency  Menstruation
# 2         NaN         NaN         NaN         NaN           NaN
# 3         NaN          No          No         NaN             -
# 4         NaN         NaN          No         NaN           NaN
# 5         NaN         NaN          No         NaN           NaN
# 6         NaN         NaN         NaN         NaN           NaN
# 7         NaN         NaN     CONTACT         NaN           NaN
# 8         NaN         NaN         NaN         NaN           NaN
# 9         NaN         NaN          No         NaN       21 days
#
#        Unnamed: 20
# 0              NaN
# 1    Contraceptive
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9  Yes, Pill (Jaz)
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Initial inspection

# %% [markdown]
# Make note of the problems you can see.
#
# **Problems:**

# %% [markdown]
# -
# -
# -
# -
# -

# %% [markdown]
# ### Many hours of hard work can help you avoid 5 minutes of planning

# %% [markdown]
# Look through your list and make an initial plan for what order you will tackle them in.
#
# - Do previous steps remove information that you will need in later steps

# %% [markdown]
# It is common for humans to leave a couple of blank lines at the start of an excel file. They may also leave blank lines to show different groups in the data.
#
# - Make sure the blank lines aren't meaningful before removing them

# %%
df1 = pd.read_excel('Phase2_ParticipantInfo_deident_data.xlsx',skiprows=[0,1])
df1
# Out:
#      1    ID   Age  Gender  Years Educ          Education Comp  \
# 0    2   Low   NaN     NaN         NaN                     NaN
# 1    3    46  26.0  Female         6.0           Undergraduate
# 2    4    62  26.0       F         3.5          Secondary/TAFE
# 3    5   131  27.0    Male        13.0           Post Graduate
# 4    6   180  19.0       F         2.0               Secondary
# 5    7   148  19.0       M         2.0           Undergraduate
# 6    8   237  18.0       F         3.0               Secondary
# 7    9   233  18.0  Female         3.0               Secondary
# 8   10   312  19.0       F         3.0               Secondary
# 9   11   295  18.0       F         3.0               Secondary
# 10  12   327  33.0    Male        20.0           Post Graduate
# 11  13   403  20.0  Female         3.0               Secondary
# 12  14   468  19.0  Female         3.0               Secondary
# 13  15   563  27.0  Female         7.0           Undergraduate
# 14  16   573  25.0  Female        20.0           Undergraduate
# 15  17   611  26.0  Female        17.0                Graduate
# 16  18   660  30.0  Female         7.0           Undergraduate
# 17  19   NaN   NaN     NaN         NaN                     NaN
# 18  20  High   NaN     NaN         NaN                     NaN
# 19  21    57  37.0  Female        15.0                Graduate
# 20  22    62  20.0    Male         4.0               Secondary
# 21  23   136  18.0  Female        14.0               Secondary
# 22  24   188  18.0       M         3.0               Secondary
# 23  25   157  18.0       F         2.5               Secondary
# 24  26   181  19.0  Female         3.0               Secondary
# 25  27   305  27.0    Male        12.0                Graduate
# 26  28   382  18.0  Female         2.0               Secondary
# 27  29   405  18.0  Female         3.0               Secondary
# 28  30   558  22.0  Female         7.0               Secondary
# 29  31   649  29.0  Female         9.0  Undergraduate, Honours
#
#                       Study disapline                        Occupation  \
# 0                                 NaN                               NaN
# 1               Nutrition & Dietetics                 Dietician/Teacher
# 2               International studies                       Electrician
# 3                    Medical Research                   Research Fellow
# 4                  Psych and Forensic                           Student
# 5                          psychology                           student
# 6                          Psychology                           Butcher
# 7   Business (advertising)/Psychology                           Student
# 8                 Forensic Psychology       Student & part time watress
# 9                          Psychology                        unemployed
# 10                   hearing research                       audiologist
# 11        Psychology Forensic Science                           Student
# 12                         Psychology                      Receptionist
# 13                      neuro science                           Student
# 14                         Psychology                           Student
# 15                         psychology                           student
# 16        Human Resources & Education               HR Projects Officer
# 17                                NaN                               NaN
# 18                                NaN                               NaN
# 19               Sensory neuroscience                        Researcher
# 20  International & Political studies                           Student
# 21                         Philosophy                           Student
# 22                Science(Psychology)                            Studen
# 23                 Psych and Forensic                           Student
# 24                         Psychology                           Student
# 25                                 IT  PhD Student / Software Developer
# 26   Criminology and Forensic Science                           Student
# 27        Psychology/forensic science                           cinemas
# 28                   Psychophysiology                 Medical Scientist
# 29             Cognitive Neuroscience              Student / Researcher
#
#    Hearing Medication          ...           \
# 0      NaN        NaN          ...
# 1      No.        No.          ...
# 2       no         no          ...
# 3      No.        yes          ...
# 4       No         No          ...
# 5      No.         no          ...
# 6      No.         No          ...
# 7      No.       Yes.          ...
# 8      No.        Yes          ...
# 9      No.         No          ...
# 10     No.        No.          ...
# 11     No.        No.          ...
# 12     No.        Yes          ...
# 13     No.        No.          ...
# 14     No.       Yes.          ...
# 15     No.        No.          ...
# 16     No.        No.          ...
# 17     NaN        NaN          ...
# 18     NaN        NaN          ...
# 19     No.        No.          ...
# 20     No.        No.          ...
# 21     No.        Yes          ...
# 22      no         no          ...
# 23      no         no          ...
# 24     No.        No.          ...
# 25     No.        No.          ...
# 26     No.        No.          ...
# 27     No.        No.          ...
# 28     No.        No.          ...
# 29     No.        No.          ...
#
#                                           Unnamed: 12  \
# 0                                                 NaN
# 1       Grandfather had Seasonal Affective Depression
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                       Aunty Anxiety
# 6                                                 NaN
# 7                           Schizophrenia, Depression
# 8                                                 NaN
# 9                            Depression, bipolar, ASD
# 10                                                NaN
# 11                                                NaN
# 12                                         Depression
# 13                 Depression, Schizophrenia, Anxiety
# 14                                                NaN
# 15                             Bipolar, schizophrenia
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                          Paternal Major Depression
# 20  Mother's cousin on her father's side was diagn...
# 21                                       Schizophenia
# 22                                                NaN
# 23                                                NaN
# 24                                         Depression
# 25                                                NaN
# 26                                 Male cousin Autism
# 27                           Brother is schizophrenic
# 28                                                NaN
# 29                                                NaN
#
#    1st degree Family history                                        Diagnosis  \
# 0                        NaN                                              NaN
# 1                         No                                              NaN
# 2                        yes                             Paternal cyclothymia
# 3                        No.                                              NaN
# 4                         No                                              NaN
# 5                         No                                              NaN
# 6                         No                                              NaN
# 7                        No.                                              NaN
# 8                         No                                              NaN
# 9                       Yes.                 Maternal and Paternal Depression
# 10                        No                                              NaN
# 11                        No                                              NaN
# 12                       Yes          Maternal Depression, Sibling Depression
# 13                       Yes                 Mother Depression, Schizophrenia
# 14                        No                                              NaN
# 15                       Yes                                  Sibling Bipolar
# 16                      Yes.  brother ASD as adult, schizophrenia, depression
# 17                       NaN                                              NaN
# 18                       NaN                                              NaN
# 19                      Yes.                        Paternal Major Depression
# 20                       NaN                                              NaN
# 21                      Yes.                           Paternal Schizophrenia
# 22                       yes                              Maternal depression
# 23                        no                                              NaN
# 24                        No                                              NaN
# 25                        No                                              NaN
# 26                     Check                                              NaN
# 27                       NaN                                              NaN
# 28                       NaN                                              NaN
# 29                       NaN                                              NaN
#
#    Personal History                                        Diagnosis.1  \
# 0               NaN                                                NaN
# 1                No                                                NaN
# 2                No                                                NaN
# 3               NaN                                                NaN
# 4                No                                                NaN
# 5                No                                                NaN
# 6               NA?                                                NaN
# 7                No                                                NaN
# 8                No                                                NaN
# 9               Yes                                         Depression
# 10               No                                                NaN
# 11              No.                                                NaN
# 12               No                                                NaN
# 13               No                                                NaN
# 14               No                                                NaN
# 15               No                                                NaN
# 16               No                                                NaN
# 17              NaN                                                NaN
# 18              NaN                                                NaN
# 19              Yes  Bipolar affective disorder(type 1)with psychot...
# 20              NaN                                                NaN
# 21              Yes                                           Anorexia
# 22              NaN                                                NaN
# 23              NaN                                                NaN
# 24               No                                                NaN
# 25               No                                                NaN
# 26              Yes                                 Deression, Anxiety
# 27              NaN                                                NaN
# 28              NaN                                                NaN
# 29              NaN                                                NaN
#
#                 Medicated?  Smoker? Frequency    Menstruation  \
# 0                      NaN      NaN       NaN             NaN
# 1                       No       No       NaN               -
# 2                      NaN       No       NaN             NaN
# 3                      NaN       No       NaN             NaN
# 4                      NaN      NaN       NaN             NaN
# 5                      NaN  CONTACT       NaN             NaN
# 6                      NaN      NaN       NaN             NaN
# 7                      NaN       No       NaN         21 days
# 8                      NaN  CONTACT       NaN             NaN
# 9                       No  CONTACT       NaN             NaN
# 10                     NaN       No       NaN             NaN
# 11                     NaN       No       NaN           4days
# 12                     NaN       No       NaN          8 days
# 13                     NaN       No       NaN          1month
# 14                     NaN       No       NaN  Unknown(years)
# 15                     NaN       No       NaN          14days
# 16                     NaN       No       NaN           0days
# 17                     NaN      NaN       NaN             NaN
# 18                     NaN      NaN       NaN             NaN
# 19                     Yes       No       NaN             NaN
# 20                     NaN      NaN       NaN             NaN
# 21                      No       No       NaN           7days
# 22                     NaN      NaN       NaN             NaN
# 23                     NaN      NaN       NaN             NaN
# 24                     NaN       No       NaN          14days
# 25                     NaN       No       NaN             NaN
# 26  Yes(Zoloft sertraline)       No       NaN         5 weeks
# 27                     NaN      NaN       NaN             NaN
# 28                     NaN      NaN       NaN             NaN
# 29                     NaN       No       NaN          5 days
#
#            Contraceptive
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7        Yes, Pill (Jaz)
# 8       Yes,Pill(Levlin)
# 9              yes, pill
# 10                   NaN
# 11                    No
# 12           Yes, Levlin
# 13             Yes, Pill
# 14    Yes, Depo Ralovera
# 15                    No
# 16                    No
# 17                   NaN
# 18                   NaN
# 19           Yes, Merina
# 20                   NaN
# 21             yes, pill
# 22                   NaN
# 23                   NaN
# 24  Yes, Pill(femme tab)
# 25                   NaN
# 26                    no
# 27                   NaN
# 28                   NaN
# 29                    No
#
# [30 rows x 22 columns]

# %% [markdown]
# Once you have thought about a plan we can start cleansing the data

# %% [markdown]
# ### Detecting bad data

# %% [markdown]
# - Data type
# - Range Constraints
# - Uniqueness
# - Set-member Constraints
# - Cross-field Validation
#
# *what types of bad data do we have?*

# %% [markdown]
# ### Tidy Data

# %% [markdown]
# - Each value in the dataset belongs to a variable (or feature) and an observation
# - a variable contains all the values measuring the same underlying attribute
# - an observation contains all the values measured on the same unit
#
# [Hadley Wickam](http://vita.had.co.nz/papers/tidy-data.pdf)

# %% [markdown]
# *Do we have tidy data?*

# %% [markdown]
# One way to work out if the data is in the correct orientation is
#
# - There are functional relationships between columns (AQ score, age and sex)
# - Comparisons can be made between groups of rows (low and high AQ)

# %% [markdown]
# Things to look for when assessing if this is a tidy dataset
# 1. Each variable forms a column
# 2. Each observation forms a row
# 3. Each type of observational unit forms a table
#     - a little bit of relational database schema philosophy
#     - Primary keys
#     - Data normalisation shouldn't be taken to extreme lengths

# %% [markdown]
# ### Missing Values

# %% [markdown]
# - Missing values can represent a measurement that should have been taken but wasn't
# - Or a measurement that isn't possible to obtain

# %% [markdown]
# *Which type of missing value do we have in the dataset?*

# %% [markdown]
# ### The start of the low and high AQ scoring groups is at row 0 and 18. What is the problem there?

# %% [markdown]
# - Is this an observation?
# - Is it a measurement?
# - Is there a measurement for each row
# - Could this information be used to compare groups?
# - Is this two datasets?
# - What should we do?

# %%
df1['AQ'] = pd.np.nan

# %%
df1.loc[1:16,'AQ'] = 'low'

# %%
df1.loc[19:,'AQ'] = 'high'

# %%
df1.loc[:,'AQ']
# Out:
# 0      NaN
# 1      low
# 2      low
# 3      low
# 4      low
# 5      low
# 6      low
# 7      low
# 8      low
# 9      low
# 10     low
# 11     low
# 12     low
# 13     low
# 14     low
# 15     low
# 16     low
# 17     NaN
# 18     NaN
# 19    high
# 20    high
# 21    high
# 22    high
# 23    high
# 24    high
# 25    high
# 26    high
# 27    high
# 28    high
# 29    high
# Name: AQ, dtype: object

# %% [markdown]
# What will you do if there are multiple sub tables and the length is irregular?
#
# Let's try to first assign string values from column ID to the new AQ column.

# %%
df1['AQ'] = np.nan
df1['AQ'] =df1.ID[~df1.ID.apply(np.isreal)]
df1['AQ']
# Out:
# 0      Low
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18    High
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# Name: AQ, dtype: object

# %% [markdown]
# Then we can use pad method to fill missing values .

# %%
df1['AQ']= df1['AQ'].fillna(method= 'pad')
df1['AQ']
# Out:
# 0      Low
# 1      Low
# 2      Low
# 3      Low
# 4      Low
# 5      Low
# 6      Low
# 7      Low
# 8      Low
# 9      Low
# 10     Low
# 11     Low
# 12     Low
# 13     Low
# 14     Low
# 15     Low
# 16     Low
# 17     Low
# 18    High
# 19    High
# 20    High
# 21    High
# 22    High
# 23    High
# 24    High
# 25    High
# 26    High
# 27    High
# 28    High
# 29    High
# Name: AQ, dtype: object

# %% [markdown]
# Now we can drop the row with "high" and "low". I will have a check first to see if I my selection method works.

# %%
df1[~df1.ID.apply(np.isreal)]
# Out:
#      1    ID  Age Gender  Years Educ Education Comp Study disapline  \
# 0    2   Low  NaN    NaN         NaN            NaN             NaN
# 18  20  High  NaN    NaN         NaN            NaN             NaN
#
#    Occupation Hearing Medication  ...  1st degree Family history Diagnosis  \
# 0         NaN     NaN        NaN  ...                        NaN       NaN
# 18        NaN     NaN        NaN  ...                        NaN       NaN
#
#    Personal History Diagnosis.1 Medicated? Smoker? Frequency Menstruation  \
# 0               NaN         NaN        NaN     NaN       NaN          NaN
# 18              NaN         NaN        NaN     NaN       NaN          NaN
#
#    Contraceptive    AQ
# 0            NaN   Low
# 18           NaN  High
#
# [2 rows x 23 columns]

# %% [markdown]
# Looks fine. So I will remove these two rows.

# %%
df1=df1.drop(df1[~df1.ID.apply(np.isreal)].index,axis=0)
df1.shape
# Out:
# (28, 23)

# %%
df1.head(30)
# Out:
#      1   ID   Age  Gender  Years Educ          Education Comp  \
# 1    3   46  26.0  Female         6.0           Undergraduate
# 2    4   62  26.0       F         3.5          Secondary/TAFE
# 3    5  131  27.0    Male        13.0           Post Graduate
# 4    6  180  19.0       F         2.0               Secondary
# 5    7  148  19.0       M         2.0           Undergraduate
# 6    8  237  18.0       F         3.0               Secondary
# 7    9  233  18.0  Female         3.0               Secondary
# 8   10  312  19.0       F         3.0               Secondary
# 9   11  295  18.0       F         3.0               Secondary
# 10  12  327  33.0    Male        20.0           Post Graduate
# 11  13  403  20.0  Female         3.0               Secondary
# 12  14  468  19.0  Female         3.0               Secondary
# 13  15  563  27.0  Female         7.0           Undergraduate
# 14  16  573  25.0  Female        20.0           Undergraduate
# 15  17  611  26.0  Female        17.0                Graduate
# 16  18  660  30.0  Female         7.0           Undergraduate
# 17  19  NaN   NaN     NaN         NaN                     NaN
# 19  21   57  37.0  Female        15.0                Graduate
# 20  22   62  20.0    Male         4.0               Secondary
# 21  23  136  18.0  Female        14.0               Secondary
# 22  24  188  18.0       M         3.0               Secondary
# 23  25  157  18.0       F         2.5               Secondary
# 24  26  181  19.0  Female         3.0               Secondary
# 25  27  305  27.0    Male        12.0                Graduate
# 26  28  382  18.0  Female         2.0               Secondary
# 27  29  405  18.0  Female         3.0               Secondary
# 28  30  558  22.0  Female         7.0               Secondary
# 29  31  649  29.0  Female         9.0  Undergraduate, Honours
#
#                       Study disapline                        Occupation  \
# 1               Nutrition & Dietetics                 Dietician/Teacher
# 2               International studies                       Electrician
# 3                    Medical Research                   Research Fellow
# 4                  Psych and Forensic                           Student
# 5                          psychology                           student
# 6                          Psychology                           Butcher
# 7   Business (advertising)/Psychology                           Student
# 8                 Forensic Psychology       Student & part time watress
# 9                          Psychology                        unemployed
# 10                   hearing research                       audiologist
# 11        Psychology Forensic Science                           Student
# 12                         Psychology                      Receptionist
# 13                      neuro science                           Student
# 14                         Psychology                           Student
# 15                         psychology                           student
# 16        Human Resources & Education               HR Projects Officer
# 17                                NaN                               NaN
# 19               Sensory neuroscience                        Researcher
# 20  International & Political studies                           Student
# 21                         Philosophy                           Student
# 22                Science(Psychology)                            Studen
# 23                 Psych and Forensic                           Student
# 24                         Psychology                           Student
# 25                                 IT  PhD Student / Software Developer
# 26   Criminology and Forensic Science                           Student
# 27        Psychology/forensic science                           cinemas
# 28                   Psychophysiology                 Medical Scientist
# 29             Cognitive Neuroscience              Student / Researcher
#
#    Hearing Medication  ...  1st degree Family history  \
# 1      No.        No.  ...                         No
# 2       no         no  ...                        yes
# 3      No.        yes  ...                        No.
# 4       No         No  ...                         No
# 5      No.         no  ...                         No
# 6      No.         No  ...                         No
# 7      No.       Yes.  ...                        No.
# 8      No.        Yes  ...                         No
# 9      No.         No  ...                       Yes.
# 10     No.        No.  ...                         No
# 11     No.        No.  ...                         No
# 12     No.        Yes  ...                        Yes
# 13     No.        No.  ...                        Yes
# 14     No.       Yes.  ...                         No
# 15     No.        No.  ...                        Yes
# 16     No.        No.  ...                       Yes.
# 17     NaN        NaN  ...                        NaN
# 19     No.        No.  ...                       Yes.
# 20     No.        No.  ...                        NaN
# 21     No.        Yes  ...                       Yes.
# 22      no         no  ...                        yes
# 23      no         no  ...                         no
# 24     No.        No.  ...                         No
# 25     No.        No.  ...                         No
# 26     No.        No.  ...                      Check
# 27     No.        No.  ...                        NaN
# 28     No.        No.  ...                        NaN
# 29     No.        No.  ...                        NaN
#
#                                           Diagnosis Personal History  \
# 1                                               NaN               No
# 2                              Paternal cyclothymia               No
# 3                                               NaN              NaN
# 4                                               NaN               No
# 5                                               NaN               No
# 6                                               NaN              NA?
# 7                                               NaN               No
# 8                                               NaN               No
# 9                  Maternal and Paternal Depression              Yes
# 10                                              NaN               No
# 11                                              NaN              No.
# 12          Maternal Depression, Sibling Depression               No
# 13                 Mother Depression, Schizophrenia               No
# 14                                              NaN               No
# 15                                  Sibling Bipolar               No
# 16  brother ASD as adult, schizophrenia, depression               No
# 17                                              NaN              NaN
# 19                        Paternal Major Depression              Yes
# 20                                              NaN              NaN
# 21                           Paternal Schizophrenia              Yes
# 22                              Maternal depression              NaN
# 23                                              NaN              NaN
# 24                                              NaN               No
# 25                                              NaN               No
# 26                                              NaN              Yes
# 27                                              NaN              NaN
# 28                                              NaN              NaN
# 29                                              NaN              NaN
#
#                                           Diagnosis.1              Medicated?  \
# 1                                                 NaN                      No
# 2                                                 NaN                     NaN
# 3                                                 NaN                     NaN
# 4                                                 NaN                     NaN
# 5                                                 NaN                     NaN
# 6                                                 NaN                     NaN
# 7                                                 NaN                     NaN
# 8                                                 NaN                     NaN
# 9                                          Depression                      No
# 10                                                NaN                     NaN
# 11                                                NaN                     NaN
# 12                                                NaN                     NaN
# 13                                                NaN                     NaN
# 14                                                NaN                     NaN
# 15                                                NaN                     NaN
# 16                                                NaN                     NaN
# 17                                                NaN                     NaN
# 19  Bipolar affective disorder(type 1)with psychot...                     Yes
# 20                                                NaN                     NaN
# 21                                           Anorexia                      No
# 22                                                NaN                     NaN
# 23                                                NaN                     NaN
# 24                                                NaN                     NaN
# 25                                                NaN                     NaN
# 26                                 Deression, Anxiety  Yes(Zoloft sertraline)
# 27                                                NaN                     NaN
# 28                                                NaN                     NaN
# 29                                                NaN                     NaN
#
#     Smoker? Frequency    Menstruation         Contraceptive    AQ
# 1        No       NaN               -                   NaN   Low
# 2        No       NaN             NaN                   NaN   Low
# 3        No       NaN             NaN                   NaN   Low
# 4       NaN       NaN             NaN                   NaN   Low
# 5   CONTACT       NaN             NaN                   NaN   Low
# 6       NaN       NaN             NaN                   NaN   Low
# 7        No       NaN         21 days       Yes, Pill (Jaz)   Low
# 8   CONTACT       NaN             NaN      Yes,Pill(Levlin)   Low
# 9   CONTACT       NaN             NaN             yes, pill   Low
# 10       No       NaN             NaN                   NaN   Low
# 11       No       NaN           4days                    No   Low
# 12       No       NaN          8 days           Yes, Levlin   Low
# 13       No       NaN          1month             Yes, Pill   Low
# 14       No       NaN  Unknown(years)    Yes, Depo Ralovera   Low
# 15       No       NaN          14days                    No   Low
# 16       No       NaN           0days                    No   Low
# 17      NaN       NaN             NaN                   NaN   Low
# 19       No       NaN             NaN           Yes, Merina  High
# 20      NaN       NaN             NaN                   NaN  High
# 21       No       NaN           7days             yes, pill  High
# 22      NaN       NaN             NaN                   NaN  High
# 23      NaN       NaN             NaN                   NaN  High
# 24       No       NaN          14days  Yes, Pill(femme tab)  High
# 25       No       NaN             NaN                   NaN  High
# 26       No       NaN         5 weeks                    no  High
# 27      NaN       NaN             NaN                   NaN  High
# 28      NaN       NaN             NaN                   NaN  High
# 29       No       NaN          5 days                    No  High
#
# [28 rows x 23 columns]

# %% [markdown]
# Then let's remove useless columns and rows.

# %%
# remove the row with the label of "1"
df1.drop(1,axis=1,inplace=True)
df1.head()
# Out:
#     ID   Age  Gender  Years Educ  Education Comp        Study disapline  \
# 1   46  26.0  Female         6.0   Undergraduate  Nutrition & Dietetics
# 2   62  26.0       F         3.5  Secondary/TAFE  International studies
# 3  131  27.0    Male        13.0   Post Graduate       Medical Research
# 4  180  19.0       F         2.0       Secondary     Psych and Forensic
# 5  148  19.0       M         2.0   Undergraduate             psychology
#
#           Occupation Hearing Medication Unnamed: 10 ...   \
# 1  Dietician/Teacher     No.        No.         NaN ...
# 2        Electrician      no         no         NaN ...
# 3    Research Fellow     No.        yes      zertex ...
# 4            Student      No         No         NaN ...
# 5            student     No.         no         NaN ...
#
#   1st degree Family history             Diagnosis Personal History  \
# 1                        No                   NaN               No
# 2                       yes  Paternal cyclothymia               No
# 3                       No.                   NaN              NaN
# 4                        No                   NaN               No
# 5                        No                   NaN               No
#
#   Diagnosis.1 Medicated?  Smoker? Frequency Menstruation  Contraceptive   AQ
# 1         NaN         No       No       NaN            -            NaN  Low
# 2         NaN        NaN       No       NaN          NaN            NaN  Low
# 3         NaN        NaN       No       NaN          NaN            NaN  Low
# 4         NaN        NaN      NaN       NaN          NaN            NaN  Low
# 5         NaN        NaN  CONTACT       NaN          NaN            NaN  Low
#
# [5 rows x 22 columns]

# %%
#remove rows where original excluding the last column include only missing values.
df1.dropna(how = 'all',inplace=True, subset=df1.columns[1:-1])
df1
# Out:
#      ID   Age  Gender  Years Educ          Education Comp  \
# 1    46  26.0  Female         6.0           Undergraduate
# 2    62  26.0       F         3.5          Secondary/TAFE
# 3   131  27.0    Male        13.0           Post Graduate
# 4   180  19.0       F         2.0               Secondary
# 5   148  19.0       M         2.0           Undergraduate
# 6   237  18.0       F         3.0               Secondary
# 7   233  18.0  Female         3.0               Secondary
# 8   312  19.0       F         3.0               Secondary
# 9   295  18.0       F         3.0               Secondary
# 10  327  33.0    Male        20.0           Post Graduate
# 11  403  20.0  Female         3.0               Secondary
# 12  468  19.0  Female         3.0               Secondary
# 13  563  27.0  Female         7.0           Undergraduate
# 14  573  25.0  Female        20.0           Undergraduate
# 15  611  26.0  Female        17.0                Graduate
# 16  660  30.0  Female         7.0           Undergraduate
# 19   57  37.0  Female        15.0                Graduate
# 20   62  20.0    Male         4.0               Secondary
# 21  136  18.0  Female        14.0               Secondary
# 22  188  18.0       M         3.0               Secondary
# 23  157  18.0       F         2.5               Secondary
# 24  181  19.0  Female         3.0               Secondary
# 25  305  27.0    Male        12.0                Graduate
# 26  382  18.0  Female         2.0               Secondary
# 27  405  18.0  Female         3.0               Secondary
# 28  558  22.0  Female         7.0               Secondary
# 29  649  29.0  Female         9.0  Undergraduate, Honours
#
#                       Study disapline                        Occupation  \
# 1               Nutrition & Dietetics                 Dietician/Teacher
# 2               International studies                       Electrician
# 3                    Medical Research                   Research Fellow
# 4                  Psych and Forensic                           Student
# 5                          psychology                           student
# 6                          Psychology                           Butcher
# 7   Business (advertising)/Psychology                           Student
# 8                 Forensic Psychology       Student & part time watress
# 9                          Psychology                        unemployed
# 10                   hearing research                       audiologist
# 11        Psychology Forensic Science                           Student
# 12                         Psychology                      Receptionist
# 13                      neuro science                           Student
# 14                         Psychology                           Student
# 15                         psychology                           student
# 16        Human Resources & Education               HR Projects Officer
# 19               Sensory neuroscience                        Researcher
# 20  International & Political studies                           Student
# 21                         Philosophy                           Student
# 22                Science(Psychology)                            Studen
# 23                 Psych and Forensic                           Student
# 24                         Psychology                           Student
# 25                                 IT  PhD Student / Software Developer
# 26   Criminology and Forensic Science                           Student
# 27        Psychology/forensic science                           cinemas
# 28                   Psychophysiology                 Medical Scientist
# 29             Cognitive Neuroscience              Student / Researcher
#
#    Hearing Medication                             Unnamed: 10  ...   \
# 1      No.        No.                                     NaN  ...
# 2       no         no                                     NaN  ...
# 3      No.        yes                                  zertex  ...
# 4       No         No                                     NaN  ...
# 5      No.         no                                     NaN  ...
# 6      No.         No                                     NaN  ...
# 7      No.       Yes.  The Pill, Ventolin as needed, Seritide  ...
# 8      No.        Yes                     Pill(Levlin), xyzal  ...
# 9      No.         No                                     NaN  ...
# 10     No.        No.                                     NaN  ...
# 11     No.        No.                                     NaN  ...
# 12     No.        Yes                                    Pill  ...
# 13     No.        No.                                     NaN  ...
# 14     No.       Yes.                           Contraceptive  ...
# 15     No.        No.                                     NaN  ...
# 16     No.        No.                                     NaN  ...
# 19     No.        No.                                     NaN  ...
# 20     No.        No.                                     NaN  ...
# 21     No.        Yes                                    Pill  ...
# 22      no         no                                     NaN  ...
# 23      no         no                                     NaN  ...
# 24     No.        No.                         Pill(Femme tab)  ...
# 25     No.        No.                                     NaN  ...
# 26     No.        No.                                     NaN  ...
# 27     No.        No.                                     NaN  ...
# 28     No.        No.                                     NaN  ...
# 29     No.        No.                                     NaN  ...
#
#    1st degree Family history                                        Diagnosis  \
# 1                         No                                              NaN
# 2                        yes                             Paternal cyclothymia
# 3                        No.                                              NaN
# 4                         No                                              NaN
# 5                         No                                              NaN
# 6                         No                                              NaN
# 7                        No.                                              NaN
# 8                         No                                              NaN
# 9                       Yes.                 Maternal and Paternal Depression
# 10                        No                                              NaN
# 11                        No                                              NaN
# 12                       Yes          Maternal Depression, Sibling Depression
# 13                       Yes                 Mother Depression, Schizophrenia
# 14                        No                                              NaN
# 15                       Yes                                  Sibling Bipolar
# 16                      Yes.  brother ASD as adult, schizophrenia, depression
# 19                      Yes.                        Paternal Major Depression
# 20                       NaN                                              NaN
# 21                      Yes.                           Paternal Schizophrenia
# 22                       yes                              Maternal depression
# 23                        no                                              NaN
# 24                        No                                              NaN
# 25                        No                                              NaN
# 26                     Check                                              NaN
# 27                       NaN                                              NaN
# 28                       NaN                                              NaN
# 29                       NaN                                              NaN
#
#    Personal History                                        Diagnosis.1  \
# 1                No                                                NaN
# 2                No                                                NaN
# 3               NaN                                                NaN
# 4                No                                                NaN
# 5                No                                                NaN
# 6               NA?                                                NaN
# 7                No                                                NaN
# 8                No                                                NaN
# 9               Yes                                         Depression
# 10               No                                                NaN
# 11              No.                                                NaN
# 12               No                                                NaN
# 13               No                                                NaN
# 14               No                                                NaN
# 15               No                                                NaN
# 16               No                                                NaN
# 19              Yes  Bipolar affective disorder(type 1)with psychot...
# 20              NaN                                                NaN
# 21              Yes                                           Anorexia
# 22              NaN                                                NaN
# 23              NaN                                                NaN
# 24               No                                                NaN
# 25               No                                                NaN
# 26              Yes                                 Deression, Anxiety
# 27              NaN                                                NaN
# 28              NaN                                                NaN
# 29              NaN                                                NaN
#
#                 Medicated?  Smoker? Frequency    Menstruation  \
# 1                       No       No       NaN               -
# 2                      NaN       No       NaN             NaN
# 3                      NaN       No       NaN             NaN
# 4                      NaN      NaN       NaN             NaN
# 5                      NaN  CONTACT       NaN             NaN
# 6                      NaN      NaN       NaN             NaN
# 7                      NaN       No       NaN         21 days
# 8                      NaN  CONTACT       NaN             NaN
# 9                       No  CONTACT       NaN             NaN
# 10                     NaN       No       NaN             NaN
# 11                     NaN       No       NaN           4days
# 12                     NaN       No       NaN          8 days
# 13                     NaN       No       NaN          1month
# 14                     NaN       No       NaN  Unknown(years)
# 15                     NaN       No       NaN          14days
# 16                     NaN       No       NaN           0days
# 19                     Yes       No       NaN             NaN
# 20                     NaN      NaN       NaN             NaN
# 21                      No       No       NaN           7days
# 22                     NaN      NaN       NaN             NaN
# 23                     NaN      NaN       NaN             NaN
# 24                     NaN       No       NaN          14days
# 25                     NaN       No       NaN             NaN
# 26  Yes(Zoloft sertraline)       No       NaN         5 weeks
# 27                     NaN      NaN       NaN             NaN
# 28                     NaN      NaN       NaN             NaN
# 29                     NaN       No       NaN          5 days
#
#            Contraceptive    AQ
# 1                    NaN   Low
# 2                    NaN   Low
# 3                    NaN   Low
# 4                    NaN   Low
# 5                    NaN   Low
# 6                    NaN   Low
# 7        Yes, Pill (Jaz)   Low
# 8       Yes,Pill(Levlin)   Low
# 9              yes, pill   Low
# 10                   NaN   Low
# 11                    No   Low
# 12           Yes, Levlin   Low
# 13             Yes, Pill   Low
# 14    Yes, Depo Ralovera   Low
# 15                    No   Low
# 16                    No   Low
# 19           Yes, Merina  High
# 20                   NaN  High
# 21             yes, pill  High
# 22                   NaN  High
# 23                   NaN  High
# 24  Yes, Pill(femme tab)  High
# 25                   NaN  High
# 26                    no  High
# 27                   NaN  High
# 28                   NaN  High
# 29                    No  High
#
# [27 rows x 22 columns]

# %% [markdown]
# I then want to reset the index so it is isn't missing 16 and 17 (as they were removed when we dropped the rows)

# %%
df1.reset_index(drop = True,inplace = True) 
df1
# Out:
#      ID   Age  Gender  Years Educ          Education Comp  \
# 0    46  26.0  Female         6.0           Undergraduate
# 1    62  26.0       F         3.5          Secondary/TAFE
# 2   131  27.0    Male        13.0           Post Graduate
# 3   180  19.0       F         2.0               Secondary
# 4   148  19.0       M         2.0           Undergraduate
# 5   237  18.0       F         3.0               Secondary
# 6   233  18.0  Female         3.0               Secondary
# 7   312  19.0       F         3.0               Secondary
# 8   295  18.0       F         3.0               Secondary
# 9   327  33.0    Male        20.0           Post Graduate
# 10  403  20.0  Female         3.0               Secondary
# 11  468  19.0  Female         3.0               Secondary
# 12  563  27.0  Female         7.0           Undergraduate
# 13  573  25.0  Female        20.0           Undergraduate
# 14  611  26.0  Female        17.0                Graduate
# 15  660  30.0  Female         7.0           Undergraduate
# 16   57  37.0  Female        15.0                Graduate
# 17   62  20.0    Male         4.0               Secondary
# 18  136  18.0  Female        14.0               Secondary
# 19  188  18.0       M         3.0               Secondary
# 20  157  18.0       F         2.5               Secondary
# 21  181  19.0  Female         3.0               Secondary
# 22  305  27.0    Male        12.0                Graduate
# 23  382  18.0  Female         2.0               Secondary
# 24  405  18.0  Female         3.0               Secondary
# 25  558  22.0  Female         7.0               Secondary
# 26  649  29.0  Female         9.0  Undergraduate, Honours
#
#                       Study disapline                        Occupation  \
# 0               Nutrition & Dietetics                 Dietician/Teacher
# 1               International studies                       Electrician
# 2                    Medical Research                   Research Fellow
# 3                  Psych and Forensic                           Student
# 4                          psychology                           student
# 5                          Psychology                           Butcher
# 6   Business (advertising)/Psychology                           Student
# 7                 Forensic Psychology       Student & part time watress
# 8                          Psychology                        unemployed
# 9                    hearing research                       audiologist
# 10        Psychology Forensic Science                           Student
# 11                         Psychology                      Receptionist
# 12                      neuro science                           Student
# 13                         Psychology                           Student
# 14                         psychology                           student
# 15        Human Resources & Education               HR Projects Officer
# 16               Sensory neuroscience                        Researcher
# 17  International & Political studies                           Student
# 18                         Philosophy                           Student
# 19                Science(Psychology)                            Studen
# 20                 Psych and Forensic                           Student
# 21                         Psychology                           Student
# 22                                 IT  PhD Student / Software Developer
# 23   Criminology and Forensic Science                           Student
# 24        Psychology/forensic science                           cinemas
# 25                   Psychophysiology                 Medical Scientist
# 26             Cognitive Neuroscience              Student / Researcher
#
#    Hearing Medication                             Unnamed: 10  ...   \
# 0      No.        No.                                     NaN  ...
# 1       no         no                                     NaN  ...
# 2      No.        yes                                  zertex  ...
# 3       No         No                                     NaN  ...
# 4      No.         no                                     NaN  ...
# 5      No.         No                                     NaN  ...
# 6      No.       Yes.  The Pill, Ventolin as needed, Seritide  ...
# 7      No.        Yes                     Pill(Levlin), xyzal  ...
# 8      No.         No                                     NaN  ...
# 9      No.        No.                                     NaN  ...
# 10     No.        No.                                     NaN  ...
# 11     No.        Yes                                    Pill  ...
# 12     No.        No.                                     NaN  ...
# 13     No.       Yes.                           Contraceptive  ...
# 14     No.        No.                                     NaN  ...
# 15     No.        No.                                     NaN  ...
# 16     No.        No.                                     NaN  ...
# 17     No.        No.                                     NaN  ...
# 18     No.        Yes                                    Pill  ...
# 19      no         no                                     NaN  ...
# 20      no         no                                     NaN  ...
# 21     No.        No.                         Pill(Femme tab)  ...
# 22     No.        No.                                     NaN  ...
# 23     No.        No.                                     NaN  ...
# 24     No.        No.                                     NaN  ...
# 25     No.        No.                                     NaN  ...
# 26     No.        No.                                     NaN  ...
#
#    1st degree Family history                                        Diagnosis  \
# 0                         No                                              NaN
# 1                        yes                             Paternal cyclothymia
# 2                        No.                                              NaN
# 3                         No                                              NaN
# 4                         No                                              NaN
# 5                         No                                              NaN
# 6                        No.                                              NaN
# 7                         No                                              NaN
# 8                       Yes.                 Maternal and Paternal Depression
# 9                         No                                              NaN
# 10                        No                                              NaN
# 11                       Yes          Maternal Depression, Sibling Depression
# 12                       Yes                 Mother Depression, Schizophrenia
# 13                        No                                              NaN
# 14                       Yes                                  Sibling Bipolar
# 15                      Yes.  brother ASD as adult, schizophrenia, depression
# 16                      Yes.                        Paternal Major Depression
# 17                       NaN                                              NaN
# 18                      Yes.                           Paternal Schizophrenia
# 19                       yes                              Maternal depression
# 20                        no                                              NaN
# 21                        No                                              NaN
# 22                        No                                              NaN
# 23                     Check                                              NaN
# 24                       NaN                                              NaN
# 25                       NaN                                              NaN
# 26                       NaN                                              NaN
#
#    Personal History                                        Diagnosis.1  \
# 0                No                                                NaN
# 1                No                                                NaN
# 2               NaN                                                NaN
# 3                No                                                NaN
# 4                No                                                NaN
# 5               NA?                                                NaN
# 6                No                                                NaN
# 7                No                                                NaN
# 8               Yes                                         Depression
# 9                No                                                NaN
# 10              No.                                                NaN
# 11               No                                                NaN
# 12               No                                                NaN
# 13               No                                                NaN
# 14               No                                                NaN
# 15               No                                                NaN
# 16              Yes  Bipolar affective disorder(type 1)with psychot...
# 17              NaN                                                NaN
# 18              Yes                                           Anorexia
# 19              NaN                                                NaN
# 20              NaN                                                NaN
# 21               No                                                NaN
# 22               No                                                NaN
# 23              Yes                                 Deression, Anxiety
# 24              NaN                                                NaN
# 25              NaN                                                NaN
# 26              NaN                                                NaN
#
#                 Medicated?  Smoker? Frequency    Menstruation  \
# 0                       No       No       NaN               -
# 1                      NaN       No       NaN             NaN
# 2                      NaN       No       NaN             NaN
# 3                      NaN      NaN       NaN             NaN
# 4                      NaN  CONTACT       NaN             NaN
# 5                      NaN      NaN       NaN             NaN
# 6                      NaN       No       NaN         21 days
# 7                      NaN  CONTACT       NaN             NaN
# 8                       No  CONTACT       NaN             NaN
# 9                      NaN       No       NaN             NaN
# 10                     NaN       No       NaN           4days
# 11                     NaN       No       NaN          8 days
# 12                     NaN       No       NaN          1month
# 13                     NaN       No       NaN  Unknown(years)
# 14                     NaN       No       NaN          14days
# 15                     NaN       No       NaN           0days
# 16                     Yes       No       NaN             NaN
# 17                     NaN      NaN       NaN             NaN
# 18                      No       No       NaN           7days
# 19                     NaN      NaN       NaN             NaN
# 20                     NaN      NaN       NaN             NaN
# 21                     NaN       No       NaN          14days
# 22                     NaN       No       NaN             NaN
# 23  Yes(Zoloft sertraline)       No       NaN         5 weeks
# 24                     NaN      NaN       NaN             NaN
# 25                     NaN      NaN       NaN             NaN
# 26                     NaN       No       NaN          5 days
#
#            Contraceptive    AQ
# 0                    NaN   Low
# 1                    NaN   Low
# 2                    NaN   Low
# 3                    NaN   Low
# 4                    NaN   Low
# 5                    NaN   Low
# 6        Yes, Pill (Jaz)   Low
# 7       Yes,Pill(Levlin)   Low
# 8              yes, pill   Low
# 9                    NaN   Low
# 10                    No   Low
# 11           Yes, Levlin   Low
# 12             Yes, Pill   Low
# 13    Yes, Depo Ralovera   Low
# 14                    No   Low
# 15                    No   Low
# 16           Yes, Merina  High
# 17                   NaN  High
# 18             yes, pill  High
# 19                   NaN  High
# 20                   NaN  High
# 21  Yes, Pill(femme tab)  High
# 22                   NaN  High
# 23                    no  High
# 24                   NaN  High
# 25                   NaN  High
# 26                    No  High
#
# [27 rows x 22 columns]

# %% [markdown]
# using the unique function I can better see what type of values are in the data for each row.

# %% [markdown]
# ### What type of information do we have

# %% [markdown]
# *Can we identify and fix data based on this information?*

# %%
[df1[x].unique() for x in df1.columns]
# Out:
# [array([46, 62, 131, 180, 148, 237, 233, 312, 295, 327, 403, 468, 563, 573,
#         611, 660, 57, 136, 188, 157, 181, 305, 382, 405, 558, 649], dtype=object),
#  array([ 26.,  27.,  19.,  18.,  33.,  20.,  25.,  30.,  37.,  22.,  29.]),
#  array(['Female', 'F', 'Male', 'M'], dtype=object),
#  array([  6. ,   3.5,  13. ,   2. ,   3. ,  20. ,   7. ,  17. ,  15. ,
#           4. ,  14. ,   2.5,  12. ,   9. ]),
#  array(['Undergraduate', 'Secondary/TAFE', 'Post Graduate', 'Secondary',
#         'Graduate', 'Undergraduate, Honours'], dtype=object),
#  array(['Nutrition & Dietetics', 'International studies',
#         'Medical Research', 'Psych and Forensic', 'psychology',
#         'Psychology', 'Business (advertising)/Psychology',
#         'Forensic Psychology', 'hearing research',
#         'Psychology Forensic Science', 'neuro science',
#         'Human Resources & Education', 'Sensory neuroscience',
#         'International & Political studies', 'Philosophy',
#         'Science(Psychology)', 'IT', 'Criminology and Forensic Science',
#         'Psychology/forensic science', 'Psychophysiology',
#         'Cognitive Neuroscience'], dtype=object),
#  array(['Dietician/Teacher', 'Electrician', 'Research Fellow', 'Student',
#         'student', 'Butcher', 'Student & part time watress', 'unemployed',
#         'audiologist', 'Receptionist', 'HR Projects Officer', 'Researcher',
#         'Studen', 'PhD Student / Software Developer', 'cinemas',
#         'Medical Scientist', 'Student / Researcher'], dtype=object),
#  array(['No.', 'no', 'No'], dtype=object),
#  array(['No.', 'no', 'yes', 'No', 'Yes.', 'Yes'], dtype=object),
#  array([nan, 'zertex', 'The Pill, Ventolin as needed, Seritide',
#         'Pill(Levlin), xyzal', 'Pill', 'Contraceptive', 'Pill(Femme tab)'], dtype=object),
#  array(['Yes.', 'No', nan, 'Yes', 'No.'], dtype=object),
#  array(['Grandfather had Seasonal Affective Depression', nan,
#         'Aunty Anxiety', 'Schizophrenia, Depression',
#         'Depression, bipolar, ASD', 'Depression',
#         'Depression, Schizophrenia, Anxiety', 'Bipolar, schizophrenia',
#         'Paternal Major Depression',
#         "Mother's cousin on her father's side was diagnosed with schizophrenia. Great Grandmother on Mother's side had bipolar.",
#         'Schizophenia', 'Male cousin Autism', 'Brother is schizophrenic'], dtype=object),
#  array(['No', 'yes', 'No.', 'Yes.', 'Yes', nan, 'no', 'Check'], dtype=object),
#  array([nan, 'Paternal cyclothymia', 'Maternal and Paternal Depression',
#         'Maternal Depression, Sibling Depression',
#         'Mother Depression, Schizophrenia', 'Sibling Bipolar',
#         'brother ASD as adult, schizophrenia, depression',
#         'Paternal Major Depression', 'Paternal Schizophrenia',
#         'Maternal depression'], dtype=object),
#  array(['No', nan, 'NA?', 'Yes', 'No.'], dtype=object),
#  array([nan, 'Depression',
#         'Bipolar affective disorder(type 1)with psychotic fearures',
#         'Anorexia', 'Deression, Anxiety'], dtype=object),
#  array(['No', nan, 'Yes', 'Yes(Zoloft sertraline)'], dtype=object),
#  array(['No', nan, 'CONTACT'], dtype=object),
#  array([ nan]),
#  array(['-', nan, '21 days', '4days', '8 days', '1month', 'Unknown(years)',
#         '14days', '0days', '7days', '5 weeks', '5 days'], dtype=object),
#  array([nan, 'Yes, Pill (Jaz)', 'Yes,Pill(Levlin)', 'yes, pill', 'No',
#         'Yes, Levlin', 'Yes, Pill', 'Yes, Depo Ralovera', 'Yes, Merina',
#         'Yes, Pill(femme tab)', 'no'], dtype=object),
#  array(['Low', 'High'], dtype=object)]

# %% [markdown]
# ### Rules to identify bad data

# %% [markdown]
# - What is the relationship between the columns?
#     - Does the data fit this?
# - Are there any range constraints?
# - Missing Values, are they OK or do they need to be replaced?
# - Are multiple values stored in the one column?
# - Are unique values unique?
# - Are there any odd categories in the categorical variables?

# %% [markdown]
# Fix some problems:

# %%
# First replace space with dash
names = [x.replace(" ","-") for x in df1.columns]
names
# Out:
# ['ID',
#  'Age',
#  'Gender',
#  'Years-Educ',
#  'Education-Comp',
#  'Study-disapline',
#  'Occupation',
#  'Hearing',
#  'Medication',
#  'Unnamed:-10',
#  'General-Fam-history?',
#  'Unnamed:-12',
#  '1st-degree-Family-history',
#  'Diagnosis',
#  'Personal-History',
#  'Diagnosis.1',
#  'Medicated?',
#  'Smoker?',
#  'Frequency',
#  'Menstruation',
#  'Contraceptive',
#  'AQ']

# %%
# Then remove question mark
names = [x.replace("?","") for x in names]
names
# Out:
# ['ID',
#  'Age',
#  'Gender',
#  'Years-Educ',
#  'Education-Comp',
#  'Study-disapline',
#  'Occupation',
#  'Hearing',
#  'Medication',
#  'Unnamed:-10',
#  'General-Fam-history',
#  'Unnamed:-12',
#  '1st-degree-Family-history',
#  'Diagnosis',
#  'Personal-History',
#  'Diagnosis.1',
#  'Medicated',
#  'Smoker',
#  'Frequency',
#  'Menstruation',
#  'Contraceptive',
#  'AQ']

# %%
# assign names back to column names
df1.columns=names 
df1.head()
# Out:
#     ID   Age  Gender  Years-Educ  Education-Comp        Study-disapline  \
# 0   46  26.0  Female         6.0   Undergraduate  Nutrition & Dietetics
# 1   62  26.0       F         3.5  Secondary/TAFE  International studies
# 2  131  27.0    Male        13.0   Post Graduate       Medical Research
# 3  180  19.0       F         2.0       Secondary     Psych and Forensic
# 4  148  19.0       M         2.0   Undergraduate             psychology
#
#           Occupation Hearing Medication Unnamed:-10 ...   \
# 0  Dietician/Teacher     No.        No.         NaN ...
# 1        Electrician      no         no         NaN ...
# 2    Research Fellow     No.        yes      zertex ...
# 3            Student      No         No         NaN ...
# 4            student     No.         no         NaN ...
#
#   1st-degree-Family-history             Diagnosis Personal-History  \
# 0                        No                   NaN               No
# 1                       yes  Paternal cyclothymia               No
# 2                       No.                   NaN              NaN
# 3                        No                   NaN               No
# 4                        No                   NaN               No
#
#   Diagnosis.1 Medicated   Smoker Frequency Menstruation  Contraceptive   AQ
# 0         NaN        No       No       NaN            -            NaN  Low
# 1         NaN       NaN       No       NaN          NaN            NaN  Low
# 2         NaN       NaN       No       NaN          NaN            NaN  Low
# 3         NaN       NaN      NaN       NaN          NaN            NaN  Low
# 4         NaN       NaN  CONTACT       NaN          NaN            NaN  Low
#
# [5 rows x 22 columns]

# %%
df1.Gender.value_counts()
# Out:
# Female    15
# F          6
# Male       4
# M          2
# Name: Gender, dtype: int64

# %%
# relabeling with gender
df1.Gender = df1.Gender.str.lower().replace('m','male').replace('f','female')
df1.Gender
# Out:
# 0     female
# 1     female
# 2       male
# 3     female
# 4       male
# 5     female
# 6     female
# 7     female
# 8     female
# 9       male
# 10    female
# 11    female
# 12    female
# 13    female
# 14    female
# 15    female
# 16    female
# 17      male
# 18    female
# 19      male
# 20    female
# 21    female
# 22      male
# 23    female
# 24    female
# 25    female
# 26    female
# Name: Gender, dtype: object
