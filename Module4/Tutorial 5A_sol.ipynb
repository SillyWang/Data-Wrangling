# %% [markdown]
# # Tutorial 5:
# ## Part A: Web Scraping
# We cover in this part scraping data from the web. Data can be presented in HTML, XML and API etc. Web scraping is the practice of using libraries to sift through a web page and gather the data that you need in a format most useful to you while at the same time preserving the structure of the data.
#
# There are several ways to extract information from the web. Use of APIs being probably the best way to extract data from a website. Almost all large websites like Twitter, Facebook, Google, Twitter, StackOverflow provide APIs to access their data in a more structured manner. If you can get what you need through an API, it is almost always preferred approach over web scrapping. However, not all websites provide an API.Thus, we need to scrape the HTML website to fetch the information.
#
# We first explain how to extract information from HTML pages.

# %% [markdown]
# ***
#
# ## HTML:
#
# Web sites are written using HTML, which means that each web page is a structured document. HTML data is easy to read in the browser but not downloadable in machine readable format.
#
# ### 1. Urllib2 :
# Python has many libraries for reading and writing data in the ubiquitous HTML. lxml (http://lxml.de) is one that has consistently strong performance in parsing very large files. lxml has multiple programmer interfaces.
#
#
# So, how can we deal with HTML data?
# #### 1. First, locate th e website (URL) of the data:
# For example, check the URL https://www.google.com/finance#stockscreener for google finance live feeds.
#
# #### 2. Install Libraries required for web scraping:
#
# **Urllib2:** It is a Python module which can be used for fetching URLs. It defines functions and classes to help with URL actions (basic and digest authentication, redirections, cookies, etc).
#
#         pip install urllib2
#
# **lxml:** provides a very simple and powerful API for parsing XML and HTML. It supports one-step parsing as well as step-by-step parsing using an event-driven API.
#
#         pip install lxml
#
#
# For more detail refer to the documentation page.
# http://lxml.de
# https://docs.python.org/2/library/urllib2.html
#
# #### 3. Get the page contents:

# %%
#import libraries
from lxml.html import parse 
from urllib2 import urlopen

#specify the url
financeURL= 'https://www.google.com/finance#stockscreener'

##Query the website and return the html to the variable 'page'

page= urlopen(financeURL)

#Parse the page variable with lxl
data_parsed = parse(page)

# Get the root element for this tree.	
data = data_parsed.getroot()
print type(data), type(data_parsed)
# Out:
# <class 'lxml.html.HtmlElement'> <type 'lxml.etree._ElementTree'>

# %% [markdown]
# #### 4. Understand the page structure:
#
# To be able to extract information from an HTML page, you need to understand the elements and attributes of any HTML page. Details about this can be found in: <a href="http://www.w3schools.com/html/default.asp"> HTML Tutorial</a>.
#
# To start, we need to take a look at the HTML that displays different categories. If you're in Chrome or Firefox, highlight "Readers' Poll Winners", right-click, and select Inspect Element. Such as the following:
# <img src="ss1.png">
#
# <img src="ss2.png">

# %% [markdown]
# ### You could dump the raw html:

# %%
import lxml.html
from lxml import etree
file = urlopen('https://www.google.com/finance#stockscreener').read()
#html.fromstring implicitly expects bytes as input
tree = lxml.html.fromstring(file)
#convert the tree into a string
#the string now contains the whole HTML ile 
html = lxml.html.tostring(tree)
html
# Out:
# '<html><head><script>(function(){(function(){function e(a){this.t={};this.tick=function(a,c,b){var d=void 0!=b?b:(new Date).getTime();this.t[a]=[d,c];if(void 0==b)try{window.console.timeStamp("CSI/"+a)}catch(e){}};this.tick("start",null,a)}var a,d;window.performance&&(d=(a=window.performance.timing)&&a.responseStart);var f=0<d?new e(d):new e;window.jstiming={Timer:e,load:f};if(a){var c=a.navigationStart;0<c&&d>=c&&(window.jstiming.srt=d-c)}if(a){var b=window.jstiming.load;0<c&&d>=c&&(b.tick("_wtsrt",void 0,c),b.tick("wtsrt_","_wtsrt",\nd),b.tick("tbsd_","wtsrt_"))}try{a=null,window.chrome&&window.chrome.csi&&(a=Math.floor(window.chrome.csi().pageT),b&&0<c&&(b.tick("_tbnd",void 0,window.chrome.csi().startE),b.tick("tbnd_","_tbnd",c))),null==a&&window.gtbExternal&&(a=window.gtbExternal.pageT()),null==a&&window.external&&(a=window.external.pageT,b&&0<c&&(b.tick("_tbnd",void 0,window.external.startE),b.tick("tbnd_","_tbnd",c))),a&&(window.jstiming.pt=a)}catch(g){}})();})();\n</script><title>Google Finance: Stock market quotes, news, currency conversions &amp; more</title><meta name="Description" content="Get real-time stock quotes &amp; charts, financial news, currency conversions, or track your portfolio with Google Finance."><meta http-equiv="X-UA-Compatible" content="IE=10"><link rel="stylesheet" type="text/css" href="/finance/f/finance_us-1489929081.css"><link rel="stylesheet" type="text/css" href="/_/scs/finance-static/_/ss/k=finance.a.-1ad9g7dkeydo6.L.X.O/d=0/rs=AGHGApEUgACXqD4VPp-NLv9z8Y70NzrMQA"><link rel="icon" type="image/vnd.microsoft.icon" href="/finance/favicon.ico"><style>#gbar,#guser{font-size:13px;padding-right:8px;padding-top:4px !important;}#gbar{padding-left:8px;height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}\n</style><script></script><script>\n      function _rpt() {}\n      function _tck() {}\n    </script><script>\n    (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n    })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\n    ga(\'create\', \'UA-40765809-1\', {\n      \'allowLinker\': true,\n      \'cookiePath\': \'/finance\'\n    });\n    ga(\'send\', \'pageview\');\n    </script></head><body><div class="fjfe-bodywrapper"><div id="fjfe-real-body" class="g-doc"><input type="text" name="hist_state" id="hist_state" style="display:none;"><iframe id="hist_frame" name="hist_frame" class="invfr" tabindex="-1"></iframe><iframe src="/_/scs/finance-static/_/js/k=finance.a.en_US.0md5hz5pgeA.O/m=b/rt=h/d=0/rs=AGHGApHi_3j1v_Z6n816dUrW-04N4o1Vbg" class="invfr" tabindex="-1"></iframe><div id="gbar"><nobr><a class="gb1" href="https://www.google.com.au/webhp?tab=ew">Search</a> <a class="gb1" href="http://www.google.com.au/imghp?hl=en&amp;tab=ei">Images</a> <a class="gb1" href="https://maps.google.com.au/maps?hl=en&amp;tab=el">Maps</a> <a class="gb1" href="https://play.google.com/?hl=en&amp;tab=e8">Play</a> <a class="gb1" href="https://www.youtube.com/?tab=e1">YouTube</a> <a class="gb1" href="https://news.google.com.au/nwshp?hl=en&amp;tab=en">News</a> <a class="gb1" href="https://mail.google.com/mail/?tab=em">Gmail</a> <a class="gb1" href="https://drive.google.com/?tab=eo">Drive</a> <a class="gb1" style="text-decoration:none" href="https://www.google.com.au/intl/en/options/"><u>More</u> &#187;</a></nobr></div><div id="guser" width="100%"><nobr><span id="gbn" class="gbi"></span><span id="gbf" class="gbf"></span><span id="gbe"></span><a href="http: ...

# %%
# Or print the tree in a prettier way using the tree structure
print(etree.tostring(tree, encoding='unicode', pretty_print=True))
# Out:
# <html>
#   <head>
#     <script>(function(){(function(){function e(a){this.t={};this.tick=function(a,c,b){var d=void 0!=b?b:(new Date).getTime();this.t[a]=[d,c];if(void 0==b)try{window.console.timeStamp("CSI/"+a)}catch(e){}};this.tick("start",null,a)}var a,d;window.performance&amp;&amp;(d=(a=window.performance.timing)&amp;&amp;a.responseStart);var f=0&lt;d?new e(d):new e;window.jstiming={Timer:e,load:f};if(a){var c=a.navigationStart;0&lt;c&amp;&amp;d&gt;=c&amp;&amp;(window.jstiming.srt=d-c)}if(a){var b=window.jstiming.load;0&lt;c&amp;&amp;d&gt;=c&amp;&amp;(b.tick("_wtsrt",void 0,c),b.tick("wtsrt_","_wtsrt",
# d),b.tick("tbsd_","wtsrt_"))}try{a=null,window.chrome&amp;&amp;window.chrome.csi&amp;&amp;(a=Math.floor(window.chrome.csi().pageT),b&amp;&amp;0&lt;c&amp;&amp;(b.tick("_tbnd",void 0,window.chrome.csi().startE),b.tick("tbnd_","_tbnd",c))),null==a&amp;&amp;window.gtbExternal&amp;&amp;(a=window.gtbExternal.pageT()),null==a&amp;&amp;window.external&amp;&amp;(a=window.external.pageT,b&amp;&amp;0&lt;c&amp;&amp;(b.tick("_tbnd",void 0,window.external.startE),b.tick("tbnd_","_tbnd",c))),a&amp;&amp;(window.jstiming.pt=a)}catch(g){}})();})();
# </script>
#     <title>Google Finance: Stock market quotes, news, currency conversions &amp; more</title>
#     <meta name="Description" content="Get real-time stock quotes &amp; charts, financial news, currency conversions, or track your portfolio with Google Finance."/>
#     <meta http-equiv="X-UA-Compatible" content="IE=10"/>
#     <link rel="stylesheet" type="text/css" href="/finance/f/finance_us-1489929081.css"/>
#     <link rel="stylesheet" type="text/css" href="/_/scs/finance-static/_/ss/k=finance.a.-1ad9g7dkeydo6.L.X.O/d=0/rs=AGHGApEUgACXqD4VPp-NLv9z8Y70NzrMQA"/>
#     <link rel="icon" type="image/vnd.microsoft.icon" href="/finance/favicon.ico"/>
#     <style>#gbar,#guser{font-size:13px;padding-right:8px;padding-top:4px !important;}#gbar{padding-left:8px;height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}
# </style>
#     <script/>
#     <script>
#       function _rpt() {}
#       function _tck() {}
#     </script>
#     <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-40765809-1', {
#       'allowLinker': true,
#       'cookiePath': '/finance'
#     });
#     ga('send', 'pageview');
#     </script>
#   </head>
#   <body>
#     <div class="fjfe-bodywrapper">
#       <div id="fjfe-real-body" class="g-doc"><input type="text" name="hist_state" id="hist_state" style="display:none;"/><iframe id="hist_frame" name="hist_frame" class="invfr" tabindex="-1"/><iframe src="/_/scs/finance-static/_/js/k=finance.a.en_US.0md5hz5pgeA.O/m=b/rt=h/d=0/rs=AGHGApHi_3j1v_Z6n816dUrW-04N4o1Vbg" class="invfr" tabindex="-1"/><div id="gbar"><nobr><a class="gb1" href="https://www.google.com.au/webhp?tab=ew">Search</a> <a class="gb1" href="http://www.google.com.au/imghp?hl=en&amp;tab=ei">Images</a> <a class="gb1" href="https://maps.google.com.au/maps?hl=en&amp;tab=el">Maps</a> <a class="gb1" href="https://play.google.com/?hl=en&amp;tab=e8">Play</a> <a class="gb1" href="https://www.youtube.com/?tab=e1">YouTube</a> <a class="gb1" href="https://news.google.com.au/nwshp?hl=en&amp;tab=en">News</a> <a class="gb1" href="https://mail.google.com/mail/?tab=em">Gmail</a> <a class="gb1" href="https://drive.google.com/?tab=eo">Drive</a> <a class="gb1" style="text-decoration:none" href="https://www.google.com.au/intl/en/options/"><u>More</u> »</a></nobr></div><div id="guser" width="100%"><nobr><span id="gbn" class="gbi"/><span id="gbf" class="gbf"/><span id="gbe"/><a href="http://www.google.com/support/finance?hl=en" class="gb4">Help</a> | <a target="_top" id="gb_70" href="https://accounts.google.com/ServiceLogin?service=finance&amp;passive=1209600&amp;continue=https://www.google.com/finance&amp;followup=https://www.google.com/finance" class="gb4">Sign in</a></nobr></div><div class="gbh" style="left:0"/><div class="gbh" style="right:0"/><div id="fjfe-click-wrapper"><script>
# (function() {
#   var l = window.location;
#   var q = l.search ? l.search.substr(1) : '';
#   var h = l.hash ? l.hash.substr(1) : '';
#   var p = '/finance';
#   var ss = 'stockscreener';
#   var conn = window.history &amp;&amp; window.history.pushState ? '/' : '#';
#   if (l.pathname == p + '/' + ss) {
#     if (h) l.href = p + conn + ss + '?' + q + '&amp;' + h;
#   } else if (l.pathname != p &amp;&amp; h) {
#     l.href = p + l.hash;
#   }
#   if (h) {
# document.getElementById('fjfe-click-wrapper').style.display = 'none';
#   }
# })();
# </script><div id="gf-head" class="g-section g-tpl-75-25 g-split"><div class="g-unit g-first"><div class="fjfe-logo"><a href="/finance/?ei=W5jHV5DrIIrK0AT-oreYDQ"><img src="/finance/f/logo_material-4224265490.png" alt="Google Finance"/></a></div><div id="gf-search" class="fjfe-search"><form method="get" action="/finance" autocomplete="off"><input class="fjfe-searchbox-input" name="q" type="text" tabindex="1" value=""/><span class="fjfe-searchbox-button-wrapper"><span class="fjfe-searchbox-button-wrapper2"><input class="fjfe-searchbox-button" type="submit" tabindex="2" value="Get quotes"/></span></span><input type="hidden" name="ei" value="W5jHV5DrIIrK0AT-oreYDQ"/></form></div></div><div class="g-unit fjfe-promo"><div id="ad2-target" class="id-ad2-target"/></div></div><div class="elastic"><div id="app" class="g-section g-tpl-left-11p4em"><div class="g-unit g-first"><div id="gf-nav"><div class="fjfe-nav-nav"><ul class="fjfe-nav" id="navmenu"><li class="fjfe-nav-selected">Markets</li><li class="fjfe-nav-item"><a href="/finance/market_news?ei=W5jHV5DrIIrK0AT-oreYDQ"><div>News</div></a></li><li class="fjfe-nav-item"><a href="/finance/portfolio?action=view&amp;ei=W5jHV5DrIIrK0AT-oreYDQ"><div>Portfolios</div></a></li><li class="fjfe-nav-item"><a href="/finance/stockscreener?ei=W5jHV5DrIIrK0AT-oreYDQ"><div>Stock screener</div></a></li><li class="fjfe-nav-item"><a href="/finance/domestic_trends?ei=W5jHV5DrIIrK0AT-oreYDQ"><div>Google Domestic Trends</div></a></li></ul></div><div class="fjfe-recentquotes fjfe-recentquotes-noquote"><h4>Recent Quotes <span class="fjfe-recentquotes-duration">(<a href="//www.google.com/history/optout?hl=en">30 days</a>)</span></h4><div class="fjfe-recentquotes-noquote-notification">You have no recent quotes</div><div class="fjfe-recentquotes-quotes"><div class="fjfe-toggle fjfe-toggle-button"><span class="fjfe-chg-toggle">chg</span> | <span class="fjfe-perc-toggle">%</span></div><div class="fjfe-table-div"><table class="fjfe-recentquotes-table" id="rq" width="100%"/></div></div></div></div></div><div class="g-unit" id="gf-viewc"><div class="fjfe-content">
# <div class="g-section sfe-break-bottom-13">
# <div class="hdg top appbar-hide"><div class="g-section g-tpl-50-50 g-split">
# <div class="g-unit g-first"><h3>Market summary</h3></div>
# <div class="g-unit">Aug 31 - Markets closed
# </div>
# </div></div>
# </div>
# <div id="reorder" class="g-section g-tpl-right-1 id-reorder">
# <div class="g-unit g-first">
# <div class="g-c">
# <div id="ad" class="sfe-break-bottom-16">
# <div id="ad-label" class="id-ad-label invisible">
# Advertisement</div>
# <div id="ad-target" class="id-ad-target ads-300-250"/>
# </div>
# <div>
# </div>
# <div class="rgt-reorder">
# <div id="portfolios">
# <div id="home-portfolios" class="id-home-portfolios">
# </div>
# </div><script>_tck('aft');</script>
# <div id="markets">
# <div id="markets">
# <div class="hdg"><div class="float"><h3>World markets</h3></div>
# <div class="gf-reorder-btn SP_menu_button"/>
# </div>
# <div class="sfe-section">
# <table class="quotes" width="100%"><tbody><tr>
# <td class="symbol"><a href="/finance?q=SHA:000001&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Shanghai
# </a></td><td class="price"><span id="ref_7521596_l">3,078.86</span>
# </td><td class="change"><span class="chr" id="ref_7521596_c">-6.63</span> <span class="chr" id="ref_7521596_cp">(-0.21%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=INDEXNIKKEI:NI225&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Nikkei 225
# </a></td><td class="price"><span id="ref_15513676_l">16,908.52</span>
# </td><td class="change"><span class="chg" id="ref_15513676_c">+21.12</span> <span class="chg" id="ref_15513676_cp">(0.13%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=INDEXHANGSENG:HSI&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Hang Seng Index
# </a></td><td class="price"><span id="ref_13414271_l">23,010.42</span>
# </td><td class="change"><span class="chg" id="ref_13414271_c">+33.54</span> <span class="chg" id="ref_13414271_cp">(0.15%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=TPE:TAIEX&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">TSEC
# </a></td><td class="price"><span id="ref_9947405_l">8,999.31</span>
# </td><td class="change"><span class="chr" id="ref_9947405_c">-69.54</span> <span class="chr" id="ref_9947405_cp">(-0.77%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=INDEXFTSE:UKX&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">FTSE 100
# </a></td><td class="price"><span id="ref_12590587_l">6,781.51</span>
# </td><td class="change"><span class="chr" id="ref_12590587_c">-39.28</span> <span class="chr" id="ref_12590587_cp">(-0.58%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=INDEXSTOXX:SX5E&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">EURO STOXX 50
# </a></td><td class="price"><span id="ref_7354851_l">3,023.13</span>
# </td><td class="change"><span class="chr" id="ref_7354851_c">-7.62</span> <span class="chr" id="ref_7354851_cp">(-0.25%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=INDEXEURO:PX1&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">CAC 40
# </a></td><td class="price"><span id="ref_9237947_l">4,438.22</span>
# </td><td class="change"><span class="chr" id="ref_9237947_c">-19.27</span> <span class="chr" id="ref_9237947_cp">(-0.43%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=INDEXTSI:OSPTX&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">S&amp;P TSX
# </a></td><td class="price"><span id="ref_9291235_l">14,597.15</span>
# </td><td class="change"><span class="chr" id="ref_9291235_c">-87.70</span> <span class="chr" id="ref_9291235_cp">(-0.60%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=INDEXASX:XJO&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">S&amp;P/ASX 200
# </a></td><td class="price"><span id="ref_14240693_l">5,417.10</span>
# </td><td class="change"><span class="chr" id="ref_14240693_c">-15.90</span> <span class="chr" id="ref_14240693_cp">(-0.29%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=INDEXBOM:SENSEX&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">BSE Sensex
# </a></td><td class="price"><span id="ref_15173681_l">28,452.17</span>
# </td><td class="change"><span class="chg" id="ref_15173681_c">+109.16</span> <span class="chg" id="ref_15173681_cp">(0.39%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=TLV:T25&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">TA25
# </a></td><td class="price"><span id="ref_835285966959493_l">1,447.01</span>
# </td><td class="change"><span class="chr" id="ref_835285966959493_c">-1.83</span> <span class="chr" id="ref_835285966959493_cp">(-0.13%)</span></td></tr><tr/><tr>
# <td class="symbol"><a href="/finance?q=INDEXSWX:SMI&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">SMI
# </a></td><td class="price"><span id="ref_1052581216806242_l">8,202.13</span>
# </td><td class="change"><span class="chr" id="ref_1052581216806242_c">-33.88</span> <span class="chr" id="ref_1052581216806242_cp">(-0.41%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=INDEXVIE:ATX&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">ATX
# </a></td><td class="price"><span id="ref_1066235873319497_l">2,314.38</span>
# </td><td class="change"><span class="chr" id="ref_1066235873319497_c">-18.14</span> <span class="chr" id="ref_1066235873319497_cp">(-0.78%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=INDEXBVMF:IBOV&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">IBOVESPA
# </a></td><td class="price"><span id="ref_851377182412228_l">57,901.11</span>
# </td><td class="change"><span class="chr" id="ref_851377182412228_c">-674.31</span> <span class="chr" id="ref_851377182412228_cp">(-1.15%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=INDEXBKK:SET&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">SET
# </a></td><td class="price"><span id="ref_192906426752897_l">1,548.44</span>
# </td><td class="change"><span class="chb" id="ref_192906426752897_c">0.00</span> <span class="chb" id="ref_192906426752897_cp">(0.00%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=INDEXIST:XU100&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">BIST100
# </a></td><td class="price"><span id="ref_456528970194751_l">75,967.63</span>
# </td><td class="change"><span class="chr" id="ref_456528970194751_c">-151.21</span> <span class="chr" id="ref_456528970194751_cp">(-0.20%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=INDEXBME:IB&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">IBEX
# </a></td><td class="price"><span id="ref_1054681020857808_l">8,716.80</span>
# </td><td class="change"><span class="chg" id="ref_1054681020857808_c">+31.40</span> <span class="chg" id="ref_1054681020857808_cp">(0.36%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=WSE:WIG&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">WIG
# </a></td><td class="price"><span id="ref_698684623076010_l">47,935.10</span>
# </td><td class="change"><span class="chr" id="ref_698684623076010_c">-54.49</span> <span class="chr" id="ref_698684623076010_cp">(-0.11%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=TADAWUL:TASI&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">TASI
# </a></td><td class="price"><span id="ref_1095233500396574_l">6,079.51</span>
# </td><td class="change"><span class="chr" id="ref_1095233500396574_c">-50.08</span> <span class="chr" id="ref_1095233500396574_cp">(-0.82%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=BCBA:IAR&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">MERVAL
# </a></td><td class="price"><span id="ref_393322345722481_l">14,480.19</span>
# </td><td class="change"><span class="chr" id="ref_393322345722481_c">-121.14</span> <span class="chr" id="ref_393322345722481_cp">(-0.83%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=INDEXBMV:ME&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">IPC
# </a></td><td class="price"><span id="ref_999678732197294_l">47,541.32</span>
# </td><td class="change"><span class="chr" id="ref_999678732197294_c">-109.25</span> <span class="chr" id="ref_999678732197294_cp">(-0.23%)</span></td></tr><tr>
# <td class="symbol"><a href="/finance?q=IDX:COMPOSITE&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">IDX Composite
# </a></td><td class="price"><span id="ref_218574097879841_l">5,368.45</span>
# </td><td class="change"><span class="chr" id="ref_218574097879841_c">-17.63</span> <span class="chr" id="ref_218574097879841_cp">(-0.33%)</span>
# </td></tr></tbody></table>
# </div>
# </div>
# </div>
# <div id="currencies">
# <div id="currencies">
# <div class="hdg"><div class="float"><h3>Currencies</h3></div>
# <div class="gf-reorder-btn SP_menu_button"/>
# </div>
# <div class="sfe-section">
# <table class="quotes" width="100%"><tbody><tr>
# <td class="symbol"><a href="/finance?q=EURUSD&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">EUR/USD</a>
# </td><td class="price">1.1156
# </td><td class="change chr">-0.0003 (-0.03%)</td></tr><tr>
# <td class="symbol"><a href="/finance?q=USDJPY&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">USD/JPY</a>
# </td><td class="price">103.2250
# </td><td class="change chr">-0.0830 (-0.08%)</td></tr><tr>
# <td class="symbol"><a href="/finance?q=GBPUSD&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">GBP/USD</a>
# </td><td class="price">1.3141
# </td><td class="change chg">+0.0009 (0.07%)</td></tr><tr>
# <td class="symbol"><a href="/finance?q=USDCAD&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">USD/CAD</a>
# </td><td class="price">1.3105
# </td><td class="change chr">-0.0006 (-0.05%)</td></tr><tr>
# <td class="symbol"><a href="/finance?q=USDHKD&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">USD/HKD</a>
# </td><td class="price">7.7570
# </td><td class="change chg">+0.0005 (0.01%)</td></tr><tr>
# <td class="symbol"><a href="/finance?q=USDCNY&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">USD/CNY</a>
# </td><td class="price">6.6805
# </td><td class="change chg">+0.0018 (0.03%)</td></tr><tr>
# <td class="symbol"><a href="/finance?q=AUDUSD&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">AUD/USD</a>
# </td><td class="price">0.7532
# </td><td class="change chg">+0.0013 (0.17%)
# </td></tr></tbody></table>
# </div>
# </div>
# </div>
# <div id="bonds">
# <div id="bonds">
# <div class="hdg"><div class="float"><h3>Bonds</h3></div>
# <div class="gf-reorder-btn SP_menu_button"/>
# </div>
# <div class="sfe-section">
# <table class="quotes" width="100%"><tbody><tr>
# <td class="symbol">3 Month
# </td><td class="price">0.29%
# </td><td class="change chr">-0.01 (-3.33%)</td></tr><tr>
# <td class="symbol">6 Month
# </td><td class="price">0.45%
# </td><td class="change chr">-0.01 (-2.17%)</td></tr><tr/><tr>
# <td class="symbol">2 Year
# </td><td class="price">0.80%
# </td><td class="change chg">+0.01 (1.27%)</td></tr><tr>
# <td class="symbol">5 Year
# </td><td class="price">1.19%
# </td><td class="change chg">+0.01 (0.85%)</td></tr><tr>
# <td class="symbol">10 Year
# </td><td class="price">1.58%
# </td><td class="change chg">+0.01 (0.64%)</td></tr><tr>
# <td class="symbol">30 Year
# </td><td class="price">2.23%
# </td><td class="change chr">-0.01 (-0.45%)
# </td></tr></tbody></table>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="g-unit">
# <div class="g-c sfe-break-right g-floatfix">
# <div class="sfe-section" id="summary">
# <div id="summary-news-story">
# <div class="g-section news">
# <div id="fix-w" class="news major">
# <span class="name">
# <a href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=http://www.bloomberg.com/news/articles/2016-09-01/asian-stocks-swing-before-u-s-jobs-data-as-energy-shares-slip&amp;cid=52779195575814&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNGOZBt7576gOw7OcMFpHIu1mi3VGQ" rel="nofollow" id="n-hp-">Asian Stocks Swing Before U.S. Jobs Data as Energy Shares Slip</a>
# </span>
# <br/>
# <div class="byline">
# <span class="src">Bloomberg</span> - <span class="date">2 hours ago</span>
# </div>
# <!-- google_ad_section_end -->
# <div class="snippet">Asian stocks swung between gains and losses, after capping a monthly increase, as commodity shares fell after a selloff in U.S. energy companies and investors awaited a report on U.S.</div>
# <!-- google_ad_section_start -->
# <div class="rel-article">
# <a href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=http://www.cnbc.com/2016/08/31/suddenly-these-two-fears-could-spook-stocks.html&amp;cid=52779195575814&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNHlF0Teq2LYyAflYQIxcLr7y1ESwA" rel="nofollow" id="n-hp-">Suddenly, these two fears could spook stocks</a>  <span class="byline">
# <span class="src">CNBC</span>
# </span></div>
# <div class="rel-article">
# <a href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=http://www.marketwatch.com/story/japan-shares-rise-on-yen-weakness-other-asia-stocks-drop-2016-08-31&amp;cid=52779195575814&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNFjgcFmivjiwmKSjaIowAB9rnAMyg" rel="nofollow" id="n-hp-">Nikkei bucks downward trend in Asia markets, boosted by weak yen</a>  <span class="byline">
# <span class="src">MarketWatch</span>
# </span></div>
# <div class="rel-article">
# <span class="byline">
# <a href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=https://www.zacks.com/stock/news/229901/stock-market-news-for-august-31-2016&amp;cid=52779195575814&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNEDiXT1vbaypLFcgqmLYWH_YyJ9Vw" rel="nofollow" class="rel" id="n-hp-">Zacks.com</a>
# <a href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=https://www.tradingfloor.com/posts/todays-trade-asx-slips-on-oil-price-spill-8031088&amp;cid=52779195575814&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNFdHiZMb9-ppKKSsxeTrFWunoTGMg" rel="nofollow" class="rel" id="n-hp-">TradingFloor.com</a>
# </span></div>
# </div>
# </div>
# </div>
# <div class="id-summary-chart"><div class="sfe-home-chart">
# <div class="ic-chart"><a href="/finance?q=INDEXDJX:.DJI,INDEXSP:.INX,INDEXNASDAQ:.IXIC&amp;ei=W5jHV5DrIIrK0AT-oreYDQ"><img src="/finance/chart?cht=c&amp;q=INDEXDJX:.DJI,INDEXSP:.INX,INDEXNASDAQ:.IXIC&amp;tlf=12h&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" height="130" width="250" id="mkt-chart" class="id-mkt-chart" onload="_tck('ic')" alt="Market Chart"/></a></div>
# </div>
# <table id="sfe-mktsumm">
# <tr>
# <td class="legend"><img alt="" class="SP_legend0 legend" src="..."/>
# </td><td><div class="name bld">
# <a href="/finance?q=INDEXDJX:.DJI&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Dow Jones</a></div>
# </td><td class="bld"><span id="ref_983582_l">18,400.88</span>
# </td><td><span class="bld chr" id="ref_983582_c">-53.42</span>
# </td><td><span class="chr" id="ref_983582_cp">(-0.29%)</span>
# </td></tr><tr>
# <td class="legend"><img alt="" class="SP_legend1 legend" src="..."/>
# </td><td><div class="name bld">
# <a href="/finance?q=INDEXSP:.INX&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">S&amp;P 500</a></div>
# </td><td class="bld"><span id="ref_626307_l">2,170.95</span>
# </td><td><span class="bld chr" id="ref_626307_c">-5.17</span>
# </td><td><span class="chr" id="ref_626307_cp">(-0.24%)</span>
# </td></tr><tr>
# <td class="legend"><img alt="" class="SP_legend2 legend" src="..."/>
# </td><td><div class="name bld">
# <a href="/finance?q=INDEXNASDAQ:.IXIC&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Nasdaq</a></div>
# </td><td class="bld"><span id="ref_13756934_l">5,213.22</span>
# </td><td><span class="bld chr" id="ref_13756934_c">-9.77</span>
# </td><td><span class="chr" id="ref_13756934_cp">(-0.19%)</span>
# </td></tr></table>
# </div>
# </div>
# <div class="sfe-section clf"/>
# <div class="mid-reorder">
# <div id="mk-news">
# <div class="hdg">
# <h3>Top stories</h3>
# <div class="gf-reorder-btn SP_menu_button"/>
# </div>
# <div class="goog-tab-bar hdg id-news-tabs" id="news-tabs">
# <div class="goog-tab goog-tab-selected">
# <a id="market-news-title" class="t"><b class="t"><b class="t">Market</b></b></a></div>
# </div>
# <div class="goog-tabpane-clear"/>
# <div class="news sfe-section-major id-market-news" id="market-news">
# <div class="g-section g-tpl-right-14 g-floatfix">
# <div class="g-unit g-first">
# <div id="scroll-container"/>
# </div>
# <div class="g-unit">
# <div class="streaming id-market-news-stream" id="market-news-stream">
# <div class="cluster">
# <div>
# <a class="title" href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=http://www.chicagotribune.com/business/ct-mcdonalds-president-leaving-0901-biz-20160831-story.html&amp;cid=52779195715522&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNFg_oaHoxtq7UJkG9ZW-yU3IaFLDw" rel="nofollow" id="n-hp-">McDonald's U.S. president, key architect of transformation, to leave at year-end</a></div>
# <div class="byline">
# <span class="src">Chicago Tribune</span>
# <span class="date" tm="1472675477"> - 6 hours ago</span></div>
# <!-- google_ad_section_end -->
# <div class="snippet">Mike Andres, the president of McDonald's U.S. business and a key architect of the fast food giant's attempt to transform itself through initiatives like all-day breakfast, will leave the company at the end of the year.</div>
# <!-- google_ad_section_start -->
# </div>
# <div class="cluster">
# <div>
# <a class="title" href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=http://www.forbes.com/sites/alanohnsman/2016/08/31/musk-promises-major-upgrade-in-tesla-autopilots-ability-to-see/&amp;cid=52779193398911&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNGjVVeJvQTnnTyZsNYhqX2PJA-CoA" rel="nofollow" id="n-hp-">Musk Promises Major Upgrade In Tesla Autopilot's Ability To 'See'</a></div>
# <div class="byline">
# <span class="src">Forbes</span>
# <span class="date" tm="1472670655"> - 7 hours ago</span></div>
# <!-- google_ad_section_end -->
# <div class="snippet">Elon Musk said Wednesday he's soon going to make good on a promise to upgrade Tesla Motors' TSLA +0.34% semi-automated Autopilot driving system.</div>
# <!-- google_ad_section_start -->
# </div>
# <div class="cluster">
# <div>
# <a class="title" href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=http://www.presstelegram.com/business/20160831/why-big-ships-are-adrift-off-the-ports-of-los-angeles-and-long-beach&amp;cid=52779195613871&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNFNI032dTSOebAPbXkujKE9Sse-KA" rel="nofollow" id="n-hp-">Why big ships are adrift off the ports of Los Angeles and Long Beach</a></div>
# <div class="byline">
# <span class="src">Long Beach Press Telegram</span>
# <span class="date" tm="1472696775"> - 28 minutes ago</span></div>
# <!-- google_ad_section_end -->
# <div class="snippet">The container ship Hanjin Montevideo leaves the Hanjin Terminal and the the Port of Long Beach. Hanjin's financial troubles led to the ship Hanjin Montevideo being anchored inside the breakwater.</div>
# <!-- google_ad_section_start -->
# </div>
# <div class="cluster">
# <div>
# <a class="title" href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=http://www.cnbc.com/2016/08/31/why-the-federal-reserve-probably-will-not-like-the-nonfarm-payrolls-jobs-report-friday.html&amp;cid=52779195350789&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNE5nhDzG3BEyEhZbQq3UHPE-jy6CA" rel="nofollow" id="n-hp-">Why the Fed probably won't like the jobs report Friday</a></div>
# <div class="byline">
# <span class="src">CNBC</span>
# <span class="date" tm="1472664375"> - 9 hours ago</span></div>
# <!-- google_ad_section_end -->
# <div class="snippet">August has disappointed the market nine of the last 12 years and is usually followed by substantial revisions. Jeff Cox | @JeffCoxCNBCcom.</div>
# <!-- google_ad_section_start -->
# </div>
# <div class="cluster">
# <div>
# <a class="title" href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=http://www.reuters.com/article/us-usa-stocks-idUSKCN1161O0&amp;cid=52779195680199&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNGY7Uq23Seyrf6dnaAcrjh5XhVpJg" rel="nofollow" id="n-hp-">Energy drags Wall St. lower; S&amp;P down slightly in August</a></div>
# <div class="byline">
# <span class="src">Reuters</span>
# <span class="date" tm="1472648472"> - 13 hours ago</span></div>
# <!-- google_ad_section_end -->
# <div class="snippet">Traders work on the floor of the New York Stock Exchange (NYSE) in New York City, U.S., August 31, 2016. REUTERS/Brendan McDermid.</div>
# <!-- google_ad_section_start -->
# </div></div>
# </div>
# </div>
# <div class="section-link"><a href="/finance/market_news?ei=W5jHV5DrIIrK0AT-oreYDQ">More market news »
# </a></div>
# </div>
# </div>
# <div id="trend">
# <div class="hdg">
# <h3>Trends</h3>
# <div class="gf-reorder-btn SP_menu_button hide"/>
# </div>
# <div id="trends" class="hdg goog-tab-bar id-trends">
# <div class="goog-tab goog-tab-selected"><a id="l_tm_zeitgeist" class="t"><b class="t"><b class="t">Popular</b></b></a></div>
# <div class="goog-tab"><a id="l_tm_price" class="t"><b class="t"><b class="t">Price</b></b></a></div>
# <div class="goog-tab"><a id="l_tm_mcap" class="t"><b class="t"><b class="t">Mkt Cap</b></b></a></div>
# <div class="goog-tab"><a id="l_tm_volume" class="t"><b class="t"><b class="t">Vol</b></b></a></div>
# </div>
# <div class="goog-tab-bar-clear"/>
# <div id="topmovers" class="id-topmovers sfe-section-major"><div class="g-wrap">
# <div style="display:none" id="tm_price_0" class="tm_category id-tm_price_0">
# <table cellpadding="3">
# <tr class="colHeader">
# <td class="title chg">Gainers</td><td class="change">Change
# </td><td class="mktCap">Mkt Cap
# </td></tr>
# <tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:JW.B&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="JW.B">JW.B</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:JW.B&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">John Wiley &amp; Sons Inc</a>
# </td><td class="change chg">18.67%
# </td><td class="mktCap">3.36B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:CIG.C&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="CIG.C">CIG.C</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:CIG.C&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Companhia Energetica Minas Gerais (ADR)</a>
# </td><td class="change chg">13.06%
# </td><td class="mktCap">3.89B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:CHS&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="CHS">CHS</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:CHS&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Chico's FAS, Inc.</a>
# </td><td class="change chg">12.21%
# </td><td class="mktCap">1.61B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:VEEV&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="VEEV">VEEV</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:VEEV&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Veeva Systems Inc</a>
# </td><td class="change chg">8.71%
# </td><td class="mktCap">5.37B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NASDAQ:HIMX&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="HIMX">HIMX</a>
# </td><td class="name">
# <a href="/finance?q=NASDAQ:HIMX&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Himax Technologies, Inc. (ADR)</a>
# </td><td class="change chg">8.59%
# </td><td class="mktCap">1.81B
# </td></tr><tr><td style="height:.7em">
# </td></tr><tr class="colHeader">
# <td class="title chr">Losers</td><td class="change">Change
# </td><td class="mktCap">Mkt Cap
# </td></tr>
# <tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:NCS&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="NCS">NCS</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:NCS&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">NCI Building Systems Inc</a>
# </td><td class="change chr">-15.04%
# </td><td class="mktCap">1.14B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:HRB&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="HRB">HRB</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:HRB&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">H &amp; R Block Inc</a>
# </td><td class="change chr">-10.51%
# </td><td class="mktCap">4.72B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:YRD&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="YRD">YRD</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:YRD&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Yirendai Ltd - ADR</a>
# </td><td class="change chr">-10.45%
# </td><td class="mktCap">1.38B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSEARCA:UWTI&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="UWTI">UWTI</a>
# </td><td class="name">
# <a href="/finance?q=NYSEARCA:UWTI&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">VelocityShares 3X Long Crude ETN linked to the S&amp;P GSCI Crude Oil Index Excess Return</a>
# </td><td class="change chr">-10.20%
# </td><td class="mktCap">1.08B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:DDD&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="DDD">DDD</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:DDD&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">3D Systems Corporation</a>
# </td><td class="change chr">-8.98%
# </td><td class="mktCap">1.61B
# </td></tr><tr><td style="height:.7em">
# </td></tr></table>
# <div class="dis">Excludes stocks with mkt cap less than $1B.
# <a href="//www.google.com/support/finance/bin/answer.py?answer=71891&amp;hl=en-US" class="secondary">Learn more</a></div></div>
# <div style="display:none" id="tm_mcap_0" class="tm_category id-tm_mcap_0">
# <table cellpadding="3">
# <tr class="colHeader">
# <td class="title chg">Gainers</td><td class="change">Change
# </td><td class="mktCap">Mkt Cap
# </td></tr>
# <tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:BABA&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="BABA">BABA</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:BABA&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Alibaba Group Holding Ltd</a>
# </td><td class="change chg">1.24%
# </td><td class="mktCap">243.28B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:HSBC&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="HSBC">HSBC</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:HSBC&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">HSBC Holdings plc (ADR)</a>
# </td><td class="change chg">1.72%
# </td><td class="mktCap">149.63B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:MTU&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="MTU">MTU</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:MTU&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Mitsubishi UFJ Financial Group Inc (ADR)</a>
# </td><td class="change chg">3.28%
# </td><td class="mktCap">78.20B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NASDAQ:KHC&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="KHC">KHC</a>
# </td><td class="name">
# <a href="/finance?q=NASDAQ:KHC&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Kraft Heinz Co</a>
# </td><td class="change chg">1.73%
# </td><td class="mktCap">108.23B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:SAN&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="SAN">SAN</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:SAN&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Banco Santander, S.A. (ADR)</a>
# </td><td class="change chg">2.52%
# </td><td class="mktCap">65.78B
# </td></tr><tr><td style="height:.7em">
# </td></tr><tr class="colHeader">
# <td class="title chr">Losers</td><td class="change">Change
# </td><td class="mktCap">Mkt Cap
# </td></tr>
# <tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:RDS.B&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="RDS.B">RDS.B</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:RDS.B&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Royal Dutch Shell plc (ADR)</a>
# </td><td class="change chr">-1.86%
# </td><td class="mktCap">201.73B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:RDS.A&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="RDS.A">RDS.A</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:RDS.A&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Royal Dutch Shell plc (ADR)</a>
# </td><td class="change chr">-1.83%
# </td><td class="mktCap">201.81B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:BHP&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="BHP">BHP</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:BHP&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">BHP Billiton Limited (ADR)</a>
# </td><td class="change chr">-4.73%
# </td><td class="mktCap">74.58B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:BBL&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="BBL">BBL</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:BBL&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">BHP Billiton plc (ADR)</a>
# </td><td class="change chr">-4.69%
# </td><td class="mktCap">74.20B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:PTR&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="PTR">PTR</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:PTR&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">PetroChina Company Limited (ADR)</a>
# </td><td class="change chr">-1.74%
# </td><td class="mktCap">192.75B
# </td></tr><tr><td style="height:.7em">
# </td></tr></table>
# <div class="dis">Excludes stocks with mkt cap less than $1B.
# <a href="//www.google.com/support/finance/bin/answer.py?answer=71891&amp;hl=en-US" class="secondary">Learn more</a></div></div>
# <div style="display:none" id="tm_volume_0" class="tm_category id-tm_volume_0">
# <table cellpadding="3">
# <tr class="colHeader">
# <td class="title chg">Leaders</td><td class="volume">Volume
# </td><td class="mktCap">Mkt Cap
# </td></tr>
# <tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:BAC&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="BAC">BAC</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:BAC&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Bank of America Corp</a>
# </td><td class="volume">127.66M
# </td><td class="mktCap">168.34B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:SVU&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="SVU">SVU</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:SVU&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">SUPERVALU INC.</a>
# </td><td class="volume">46.96M
# </td><td class="mktCap">1.45B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:EMC&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="EMC">EMC</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:EMC&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">EMC Corporation</a>
# </td><td class="volume">43.36M
# </td><td class="mktCap">57.36B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NASDAQ:SIRI&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="SIRI">SIRI</a>
# </td><td class="name">
# <a href="/finance?q=NASDAQ:SIRI&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Sirius XM Holdings Inc.</a>
# </td><td class="volume">40.14M
# </td><td class="mktCap">20.29B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:ABX&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="ABX">ABX</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:ABX&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Barrick Gold Corporation (USA)</a>
# </td><td class="volume">36.42M
# </td><td class="mktCap">18.77B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:CHK&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="CHK">CHK</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:CHK&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Chesapeake Energy Corporation</a>
# </td><td class="volume">34.65M
# </td><td class="mktCap">4.99B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:TWTR&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="TWTR">TWTR</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:TWTR&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Twitter Inc</a>
# </td><td class="volume">34.22M
# </td><td class="mktCap">13.53B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:GE&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="GE">GE</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:GE&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">General Electric Company</a>
# </td><td class="volume">33.42M
# </td><td class="mktCap">280.04B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:FCX&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="FCX">FCX</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:FCX&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Freeport-McMoRan Inc</a>
# </td><td class="volume">32.24M
# </td><td class="mktCap">13.14B
# </td></tr><tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:VALE&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="VALE">VALE</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:VALE&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Vale SA (ADR)</a>
# </td><td class="volume">32.23M
# </td><td class="mktCap">25.43B
# </td></tr><tr><td colspan="3" style="height:.7em">
# </td></tr></table>
# <div class="dis">Excludes stocks with mkt cap less than $1B.
# <a href="//www.google.com/support/finance/bin/answer.py?answer=71891&amp;hl=en-US" class="secondary">Learn more</a></div></div>
# <div id="tm_zeitgeist" class="tm_category id-tm_zeitgeist">
# <table cellpadding="3">
# <tr class="colHeader">
# <td class="grey">Popular searches on Google</td><td class="change">Change
# </td><td class="mktCap">Mkt Cap
# </td></tr>
# <tr>
# <td class="symbol">
# <a href="/finance?q=NYSE:FRO&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" title="FRO">FRO</a>
# </td><td class="name">
# <a href="/finance?q=NYSE:FRO&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Frontline Ltd.</a>
# </td><td class="change chr">-5.79%
# </td><td class="mktCap">10.00B
# </td></tr><tr><td style="height:.7em">
# </td></tr></table>
# </div>
# </div></div>
# </div>
# <div id="country-widget">
# <div class="hdg">
# <div class="float"><h3>Sector summary</h3></div>
# <div class="gf-reorder-btn SP_menu_button hide"/>
# </div>
# <div id="secperf" class="id-secperf sfe-section-major">
# <table width="100%" cellpadding="0" cellspacing="0">
# <tr class="colHeader">
# <td style="text-align:left; padding-right:0.5em">Sector</td>
# <td style="padding-right:1em;">Change</td>
# <td style="text-align:center" colspan="2">% down / up</td>
# </tr>
# <tr>
# <td style="text-align:left; padding-right:0.5em"><a href="/finance?catid=TRBC:50&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Energy</a></td>
# <td style="width:20%; padding-right:1em">
# <span class="chr">-1.37%</span>
# </td>
# <td style="width:32%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td style="background-color:#FFFFFF; width:1%"/>
# <td class="chrSectorDark" style="width:42%" title="32% companies in Energy down by more than 2%"/>
# <td class="chrSectorLight" style="width:57%; border-right:1px #CCB3AB solid" title="43% companies in Energy down between 0% and 2%"/>
# </tr>
# </table>
# </td>
# <td style="width:28%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td class="chgSectorLight" style="width:32%;" title="20% companies in Energy are up between 0% and 2%"/>
# <td class="chgSectorDark" style="width:8%" title="5% companies in Energy are up more than 2%"/>
# <td style="background-color:#FFFFFF; width:60%"/>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td style="text-align:left; padding-right:0.5em"><a href="/finance?catid=TRBC:51&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Basic Materials</a></td>
# <td style="width:20%; padding-right:1em">
# <span class="chr">-1.22%</span>
# </td>
# <td style="width:32%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td style="background-color:#FFFFFF; width:11%"/>
# <td class="chrSectorDark" style="width:29%" title="22% companies in Basic Materials down by more than 2%"/>
# <td class="chrSectorLight" style="width:60%; border-right:1px #CCB3AB solid" title="45% companies in Basic Materials down between 0% and 2%"/>
# </tr>
# </table>
# </td>
# <td style="width:28%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td class="chgSectorLight" style="width:46%;" title="29% companies in Basic Materials are up between 0% and 2%"/>
# <td class="chgSectorDark" style="width:6%" title="4% companies in Basic Materials are up more than 2%"/>
# <td style="background-color:#FFFFFF; width:48%"/>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td style="text-align:left; padding-right:0.5em"><a href="/finance?catid=TRBC:52&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Industrials</a></td>
# <td style="width:20%; padding-right:1em">
# <span class="chr">-0.42%</span>
# </td>
# <td style="width:32%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td style="background-color:#FFFFFF; width:14%"/>
# <td class="chrSectorDark" style="width:17%" title="13% companies in Industrials down by more than 2%"/>
# <td class="chrSectorLight" style="width:69%; border-right:1px #CCB3AB solid" title="52% companies in Industrials down between 0% and 2%"/>
# </tr>
# </table>
# </td>
# <td style="width:28%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td class="chgSectorLight" style="width:46%;" title="29% companies in Industrials are up between 0% and 2%"/>
# <td class="chgSectorDark" style="width:9%" title="6% companies in Industrials are up more than 2%"/>
# <td style="background-color:#FFFFFF; width:45%"/>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td style="text-align:left; padding-right:0.5em"><a href="/finance?catid=TRBC:53&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Cyclical Cons. Goods ...</a></td>
# <td style="width:20%; padding-right:1em">
# <span class="chr">-0.22%</span>
# </td>
# <td style="width:32%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td style="background-color:#FFFFFF; width:26%"/>
# <td class="chrSectorDark" style="width:13%" title="10% companies in Cyclical Cons. Goods &amp; Services down by more than 2%"/>
# <td class="chrSectorLight" style="width:61%; border-right:1px #CCB3AB solid" title="46% companies in Cyclical Cons. Goods &amp; Services down between 0% and 2%"/>
# </tr>
# </table>
# </td>
# <td style="width:28%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td class="chgSectorLight" style="width:59%;" title="37% companies in Cyclical Cons. Goods &amp; Services are up between 0% and 2%"/>
# <td class="chgSectorDark" style="width:11%" title="7% companies in Cyclical Cons. Goods &amp; Services are up more than 2%"/>
# <td style="background-color:#FFFFFF; width:30%"/>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td style="text-align:left; padding-right:0.5em"><a href="/finance?catid=TRBC:54&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Non-Cyclical Cons. Goods...</a></td>
# <td style="width:20%; padding-right:1em">
# <span class="chg">+0.23%</span>
# </td>
# <td style="width:32%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td style="background-color:#FFFFFF; width:34%"/>
# <td class="chrSectorDark" style="width:12%" title="9% companies in Non-Cyclical Cons. Goods &amp; Services down by more than 2%"/>
# <td class="chrSectorLight" style="width:54%; border-right:1px #CCB3AB solid" title="41% companies in Non-Cyclical Cons. Goods &amp; Services down between 0% and 2%"/>
# </tr>
# </table>
# </td>
# <td style="width:28%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td class="chgSectorLight" style="width:64%;" title="40% companies in Non-Cyclical Cons. Goods &amp; Services are up between 0% and 2%"/>
# <td class="chgSectorDark" style="width:16%" title="10% companies in Non-Cyclical Cons. Goods &amp; Services are up more than 2%"/>
# <td style="background-color:#FFFFFF; width:20%"/>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td style="text-align:left; padding-right:0.5em"><a href="/finance?catid=TRBC:55&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Financials</a></td>
# <td style="width:20%; padding-right:1em">
# <span class="chg">+0.14%</span>
# </td>
# <td style="width:32%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td style="background-color:#FFFFFF; width:44%"/>
# <td class="chrSectorDark" style="width:2%" title="2% companies in Financials down by more than 2%"/>
# <td class="chrSectorLight" style="width:54%; border-right:1px #CCB3AB solid" title="41% companies in Financials down between 0% and 2%"/>
# </tr>
# </table>
# </td>
# <td style="width:28%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td class="chgSectorLight" style="width:85%;" title="53% companies in Financials are up between 0% and 2%"/>
# <td class="chgSectorDark" style="width:6%" title="4% companies in Financials are up more than 2%"/>
# <td style="background-color:#FFFFFF; width:9%"/>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td style="text-align:left; padding-right:0.5em"><a href="/finance?catid=TRBC:56&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Healthcare</a></td>
# <td style="width:20%; padding-right:1em">
# <span class="chr">-0.41%</span>
# </td>
# <td style="width:32%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td style="background-color:#FFFFFF; width:16%"/>
# <td class="chrSectorDark" style="width:22%" title="17% companies in Healthcare down by more than 2%"/>
# <td class="chrSectorLight" style="width:62%; border-right:1px #CCB3AB solid" title="47% companies in Healthcare down between 0% and 2%"/>
# </tr>
# </table>
# </td>
# <td style="width:28%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td class="chgSectorLight" style="width:51%;" title="32% companies in Healthcare are up between 0% and 2%"/>
# <td class="chgSectorDark" style="width:6%" title="4% companies in Healthcare are up more than 2%"/>
# <td style="background-color:#FFFFFF; width:43%"/>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td style="text-align:left; padding-right:0.5em"><a href="/finance?catid=TRBC:57&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Technology</a></td>
# <td style="width:20%; padding-right:1em">
# <span class="chr">-0.22%</span>
# </td>
# <td style="width:32%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td style="background-color:#FFFFFF; width:30%"/>
# <td class="chrSectorDark" style="width:16%" title="12% companies in Technology down by more than 2%"/>
# <td class="chrSectorLight" style="width:54%; border-right:1px #CCB3AB solid" title="41% companies in Technology down between 0% and 2%"/>
# </tr>
# </table>
# </td>
# <td style="width:28%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td class="chgSectorLight" style="width:64%;" title="40% companies in Technology are up between 0% and 2%"/>
# <td class="chgSectorDark" style="width:11%" title="7% companies in Technology are up more than 2%"/>
# <td style="background-color:#FFFFFF; width:25%"/>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td style="text-align:left; padding-right:0.5em"><a href="/finance?catid=TRBC:58&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Telecommunications Servi...</a></td>
# <td style="width:20%; padding-right:1em">
# <span class="chr">-0.41%</span>
# </td>
# <td style="width:32%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td style="background-color:#FFFFFF; width:14%"/>
# <td class="chrSectorDark" style="width:16%" title="12% companies in Telecommunications Services down by more than 2%"/>
# <td class="chrSectorLight" style="width:70%; border-right:1px #CCB3AB solid" title="53% companies in Telecommunications Services down between 0% and 2%"/>
# </tr>
# </table>
# </td>
# <td style="width:28%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td class="chgSectorLight" style="width:50%;" title="31% companies in Telecommunications Services are up between 0% and 2%"/>
# <td class="chgSectorDark" style="width:6%" title="4% companies in Telecommunications Services are up more than 2%"/>
# <td style="background-color:#FFFFFF; width:44%"/>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td style="text-align:left; padding-right:0.5em"><a href="/finance?catid=TRBC:59&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Utilities</a></td>
# <td style="width:20%; padding-right:1em">
# <span class="chg">+0.23%</span>
# </td>
# <td style="width:32%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td style="background-color:#FFFFFF; width:50%"/>
# <td class="chrSectorDark" style="width:4%" title="3% companies in Utilities down by more than 2%"/>
# <td class="chrSectorLight" style="width:46%; border-right:1px #CCB3AB solid" title="35% companies in Utilities down between 0% and 2%"/>
# </tr>
# </table>
# </td>
# <td style="width:28%">
# <table class="bars" cellpadding="0" cellspacing="0" width="100%">
# <tr style="height:0.9em">
# <td class="chgSectorLight" style="width:93%;" title="58% companies in Utilities are up between 0% and 2%"/>
# <td class="chgSectorDark" style="width:6%" title="4% companies in Utilities are up more than 2%"/>
# <td style="background-color:#FFFFFF; width:1%"/>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div></div></div></div></div><div id="gf-foot"><div id="fjfe-edition-links" class="fjfe-footer-links">Google Finance Beta available in: <a href="http://www.google.com.hk/finance?ei=W5jHV5DrIIrK0AT-oreYDQ" class="fjfe-edition-link">Hong Kong</a> - <a href="http://www.google.ca/finance?ei=W5jHV5DrIIrK0AT-oreYDQ" class="fjfe-edition-link">Canada</a> - <a href="http://www.google.com/finance?ei=W5jHV5DrIIrK0AT-oreYDQ" class="fjfe-edition-link">U.S.</a> - <a href="http://www.google.com.hk/finance?hl=zh-CN&amp;ei=W5jHV5DrIIrK0AT-oreYDQ" class="fjfe-edition-link">China</a> - <a href="http://www.google.co.uk/finance?ei=W5jHV5DrIIrK0AT-oreYDQ" class="fjfe-edition-link">U.K.</a></div><p class="fjfe-footer-disclaimer">Information is provided "as is" and solely for informational purposes, not for trading purposes or advice, and may be delayed.<br/>To see all exchange delays, please <a href="http://www.google.com/intl/en/googlefinance/disclaimer/?ei=W5jHV5DrIIrK0AT-oreYDQ" class="fjfe-secondary-link fjfe-no-sticky-params"> see disclaimer</a>.</p><div class="fjfe-footer-links">©2016 Google - <a href="http://www.google.com?hl=en&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Google Home</a> - <a href="http://googlefinanceblog.blogspot.com?ei=W5jHV5DrIIrK0AT-oreYDQ">Blog</a> - <a href="http://support.google.com/finance?hl=en&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Help</a> - <a href="http://support.google.com/finance?ctx=report&amp;hl=en&amp;ei=W5jHV5DrIIrK0AT-oreYDQ">Report a Problem</a> - <a href="http://www.google.com/intl/en/policies/privacy/?ei=W5jHV5DrIIrK0AT-oreYDQ">Privacy Policy</a> - <a href="http://www.google.com/intl/en/policies/terms/?ei=W5jHV5DrIIrK0AT-oreYDQ">Terms of Service</a></div></div><script>var _cleardot = '...\/\/\/\/\/\/\/yH5BAEKAAEALAAAAAABAAEAAAICTAEAOw\x3d\x3d';
#     var google = google || {};
#     google.finance = google.finance || {};
#     google.finance.gce = false ;</script><script src="/finance/f/sfe-opt-3379333646.js"/><script>
#       _regOnLoad = function(f) {
#         if (document.readyState == 'complete') {
#           f &amp;&amp; f();
#         } else {
#           // Window.attachEvent() for IE8 and below compatability.
#           var addEventFunction = window.attachEvent ||
#               window.addEventListener || function(ignored, f) { f(); };
#           var event = window.attachEvent ? 'onload' : 'load';
#           f &amp;&amp; addEventFunction(event, f);
#         }
#       };
#
#       google.finance.renderRecentQuotes = function() {};
#     </script>
# <script>
# var _prefs=_prefs||{};_prefs.hash="";
# _prefs.promo=_prefs.promo||{};
# _prefs.home_tabs=_prefs.home_tabs||{};
# _prefs.home=_prefs.home||{};
# _prefs.home["sorder"] = 'MPTC-WAFB';
# function initPage() {
# google.MiniPortfolios.setHiddenPids(
# "",
# "");
# google.finance.data.home = google.finance.data.home || {};
# google.finance.data.home.tmExch = [];
# google.finance.common.listenToForm('pform');
# google.finance.onHomeLoad();
# }
# var _chartConfigObject;
# var _cleardot;
# var _companyName;
# var _eventid = 'W5jHV5DrIIrK0AT-oreYDQ';
# var _expid;
# var _external_target;
# var _localDomain = 'www.google.com';
# var _minZoomDays;
# var _minZoomDaysNoIntraDay;
# var _prefs;
# var _ticker;
# var _urlSuffix;
# var google = google || {};
# google.finance = google.finance || {};
# google.finance.data = {common:{rq:{ct:""},up:"chg",down:"chr",linktargetInternal:"",hash:"",dfp:"ad-g.doubleclick.net/adi/com.gf.home/default;ssl=1;dcopt=ist;myd=ad;sz=300x250;tile=1",streaming:[{cid:"983582",s:".DJI",e:"INDEXDJX"},{cid:"626307",s:".INX",e:"INDEXSP"},{cid:"13756934",s:".IXIC",e:"INDEXNASDAQ"},{cid:"7521596",s:"000001",e:"SHA"},{cid:"15513676",s:"NI225",e:"INDEXNIKKEI"},{cid:"13414271",s:"HSI",e:"INDEXHANGSENG"},{cid:"9947405",s:"TAIEX",e:"TPE"},{cid:"12590587",s:"UKX",e:"INDEXFTSE"},{cid:"7354851",s:"SX5E",e:"INDEXSTOXX"},{cid:"9237947",s:"PX1",e:"INDEXEURO"},{cid:"9291235",s:"OSPTX",e:"INDEXTSI"},{cid:"14240693",s:"XJO",e:"INDEXASX"},{cid:"15173681",s:"SENSEX",e:"INDEXBOM"},{cid:"835285966959493",s:"T25",e:"TLV"},{cid:"542029859096076",s:"KOSPI",e:"INDEXKRX"},{cid:"1052581216806242",s:"SMI",e:"INDEXSWX"},{cid:"1066235873319497",s:"ATX",e:"INDEXVIE"},{cid:"851377182412228",s:"IBOV",e:"INDEXBVMF"},{cid:"192906426752897",s:"SET",e:"INDEXBKK"},{cid:"456528970194751",s:"XU100",e:"INDEXIST"},{cid:"1054681020857808",s:"IB",e:"INDEXBME"},{cid:"698684623076010",s:"WIG",e:"WSE"},{cid:"1095233500396574",s:"TASI",e:"TADAWUL"},{cid:"393322345722481",s:"IAR",e:"BCBA"},{cid:"999678732197294",s:"ME",e:"INDEXBMV"},{cid:"218574097879841",s:"COMPOSITE",e:"IDX"}]},home:{widescreen_width:1290},stickyUrlArgs:"\u0026ei=W5jHV5DrIIrK0AT-oreYDQ"};
# google.finance.data.numberFormat = [{'threshold':1000000, 'symbol':'M'}, {'threshold':1000000000,'symbol':'B'}, {'threshold':1000000000000,'symbol':'T'}] ;
# _setStickyUrlParams("ei=W5jHV5DrIIrK0AT-oreYDQ");
# if (_s_Store) {
# _s_Store._allowMatchAdvancedSearch = true;
# var _fieldToDisplayNameMap = {GrossMargin:"Gross margin&amp;nbsp;(%)",Return1Week:"1w return",Return156Week:"156w return",NextYearEPS:"Next year EPS",LTDebtToAssetsYear:"LT debt/assets (Recent&amp;nbsp;yr)&amp;nbsp;(%)",RevenueGrowthRate5Years:"5y revenue growth rate",EarningsAfterTaxes:"Earnings after taxes",DividendPerShare:"Div per share",MarketCap:"Market cap",NetProfitMarginPercent:"Net profit margin&amp;nbsp;(%)",Float:"Float",EarningsBeforeTaxes:"Earnings before taxes",QuotePercChange:"Quote change&amp;nbsp;(%)",TotalDebtToEquityYear:"Total debt/equity (Recent&amp;nbsp;yr)&amp;nbsp;(%)",TotalDebtToCapitalQuarter:"Total debt/capital (Recent&amp;nbsp;qtr)&amp;nbsp;(%)",LTDebtToCapitalQuarter:"LT debt/capital (Recent&amp;nbsp;qtr)&amp;nbsp;(%)",EPSGrowthRate10Years:"10y EPS growth rate",Beta:"Beta",ReturnOnAssetsPTM:"Return on assets (PTM)&amp;nbsp;(%)",CapitalGain:"Capital gain",BetaDown:"Beta down from RAS",IncomeDividend:"Income dividend",RevenueGrowthRate10Years:"10y revenue growth rate",MarketCapShareBasis:"Market cap share basis",IAD:"Div rate indicated annual",Return4Week:"4w return",Price150DayAverage:"150d avg price",EPSGrowthRate5Years:"5y EPS growth rate",ReturnOnAssetsTTM:"Return on assets (TTM)&amp;nbsp;(%)",TotalDebtToAssetsYear:"Total debt/assets (Recent&amp;nbsp;yr)&amp;nbsp;(%)",Volume:"Volume",DividendRecentQuarter:"Div recent quarter",CurrentRatioYear:"Current ratio",Low52Week:"52w low",ExpenseRatio:"Expense ratio",Price13WeekPercChange:"13w&amp;nbsp;price change&amp;nbsp;(%)",Price1DayPercChange:"1d&amp;nbsp;price change&amp;nbsp;(%)",ReturnOnEquity5Years:"Return on equity (5&amp;nbsp;yr&amp;nbsp;avg)&amp;nbsp;(%)",TotalDebtToCapitalYear:"Total debt/capital (Recent&amp;nbsp;yr)&amp;nbsp;(%)",TotalDebtToAssetsQuarter:"Total debt/assets (Recent&amp;nbsp;qtr)&amp;nbsp;(%)",NavChange:"Nav change",OperatingMargin:"Operating margin&amp;nbsp;(%)",DPSRecentYear:"Div per share (Recent&amp;nbsp;yr)",ANI:"Earnings after taxes (Recent&amp;nbsp;yr)",AverageVolume:"Average volume",High52Week:"52w high",Return13Week:"13w return",PriceToCashFlowPerShare:"Price to cash flow per share",ATAXRATE:"Tax rate (Recent&amp;nbsp;yr)",Price26WeekPercChange:"26w&amp;nbsp;price change&amp;nbsp;(%)",QuoteChange:"Quote change",NetIncomeChangePerc:"Net income change&amp;nbsp;(%)",ReturnOnInvestment5Years:"Return on investment (5&amp;nbsp;yr&amp;nbsp;avg)&amp;nbsp;(%)",PE:"P/E ratio",ReturnOnInvestmentYear:"Return on investment (Recent&amp;nbsp;yr)&amp;nbsp;(%)",Price200DayAverage:"200d avg price",DividendNextQuarter:"Div next quarter",EBITD:"EBITDA",PriceYTDPercChange:"YTD&amp;nbsp;price change&amp;nbsp;(%)",ReturnOnInvestmentTTM:"Return on investment (TTM)&amp;nbsp;(%)",NavChangePercent:"Nav change&amp;nbsp;(%)",EBITDMargin:"EBITDA margin&amp;nbsp;(%)",LTDebtToEquityQuarter:"LT debt/equity (Recent&amp;nbsp;qtr)&amp;nbsp;(%)",BetaRAS:"Beta from RAS",PriceSales:"Price to sales",NetAssets:"Net assets",ReturnOnEquityTTM:"Return on equity (TTM)&amp;nbsp;(%)",CashPerShareYear:"Cash/share",ReturnOnAssets5Years:"Return on assets (5&amp;nbsp;yr&amp;nbsp;avg)&amp;nbsp;(%)",ReturnDay:"1d return",Return52Week:"52w return",ForwardPE1Year:"1y fwd P/E",NetIncomeGrowthRate5Years:"5y net income growth rate",DividendYield:"Div yield&amp;nbsp;(%)",Dividend:"Div from cash flow",BetaUp:"Beta up from RAS",LTDebtToCapitalYear:"LT debt/capital (Recent&amp;nbsp;yr)&amp;nbsp;(%)",nprice:"Price from RAS",Return260Week:"260w return",ReturnOnEquityQuarter:"Return on equity (Recent&amp;nbsp;qtr)&amp;nbsp;(%)",ACOGS:"Cost of goods sold",LTDebtToAssetsQuarter:"LT debt/assets (Recent&amp;nbsp;qtr)&amp;nbsp;(%)",PriceToBook:"Price to book",LTDebtToEquityYear:"LT debt/equity (Recent&amp;nbsp;yr)&amp;nbsp;(%)",ReturnYTD:"Return YTD",ReturnOnEquityYear:"Return on equity (Recent&amp;nbsp;yr)&amp;nbsp;(%)",ReturnOnAssetsQuarter:"Return on assets (Recent&amp;nbsp;qtr)&amp;nbsp;(%)",TotalDebtToEquityQuarter:"Total debt/equity (Recent&amp;nbsp;qtr)&amp;nbsp;(%)",NavPrior:"Na ...
# _s_Store._asStore._addStrings(_fieldToDisplayNameMap);
# }
# if (_s_Store) {
# _s_Store._allowMultipleInBox = true;
# }
# _regOnLoad(initPage);
# </script></div>
#     </div>
#     <script>var googlefinance = {i: ["f.b.id","",null,0,"",0,null,["f.b.cf","0md5hz5pgeA.en_US.",0],[],1,[],"W5jHV5DrIIrK0AT-oreYDQ","www.google.com","TOszWVOPL7N8X0_iXnADEfQnXGg:1472698459632",1]}; GF_domReady = 1;</script>
#   </body>
# </html>

# %% [markdown]
#     HTML links are defined in HTML with the <a> tag, “<a href=“http://www.test.com”>This is a link for test.com</a>”
#     ** Search manually for '<a ' (note the space):

# %% [markdown]
# ### Task: Extract all links in HTML page:
# In our example, the 'data' object contains the root of the parsed document. To access an element in the page, we extract it by its index or name. For example, the following code gets all the links in the data.

# %%
links = data.findall('.//a') # find all 'a' which are '<a ' anchors, i.e. href links
linkURLs = []
for link in links:
    linkURLs.append(link.get('href'))

# %% [markdown]
# ### More compact way of implementing the same code is as follows:

# %%
linkURLs = [link.get('href') for link in data.findall('.//a')] # look for all the 'hrefs' in 'a' anchors
# e.g. from above: <a href="http://www.w3schools.com/html/default.asp"> HTML</a>

# %% [markdown]
# ### What type is linkURLs?

# %%
type(linkURLs)
# Out:
# list

# %% [markdown]
# ### Let's have a look on the list items:

# %%
linkURLs[0:10] # look at the first few
# Out:
# ['https://www.google.com.au/webhp?tab=ew',
#  'http://www.google.com.au/imghp?hl=en&tab=ei',
#  'https://maps.google.com.au/maps?hl=en&tab=el',
#  'https://play.google.com/?hl=en&tab=e8',
#  'https://www.youtube.com/?tab=e1',
#  'https://news.google.com.au/nwshp?hl=en&tab=en',
#  'https://mail.google.com/mail/?tab=em',
#  'https://drive.google.com/?tab=eo',
#  'https://www.google.com.au/intl/en/options/',
#  'http://www.google.com/support/finance?hl=en']

# %% [markdown]
# ### These are the links not the text, how can we get the text instead?

# %% [markdown]
# We do the same for getting the link text instead of the link, we use text_contents method instead of get in this case.

# %%
linkText=[link.text_content() for link in data.findall('.//a')]
linkText[0:10]
# Out:
# ['Search',
#  'Images',
#  'Maps',
#  'Play',
#  'YouTube',
#  'News',
#  'Gmail',
#  'Drive',
#  u'More \xbb',
#  'Help']

# %% [markdown]
# And you can see they match the linkURLs above (e.g. 'maps.google.com' & 'Maps')

# %% [markdown]
# ### 2. BeautifulSoup
#
# http://www.crummy.com/software/BeautifulSoup/
#
# An easier way to parse HTML is by using BeautifulSoup library. We first request the page then pass the contents to BeautifulSoup to parse. Once we have the parsed page object, we can use its attributes and methods. This following example asks BeautifulSoup to find all a tags (or links) on the page. First, you will need to install the libraries.
#
#     pip install BeautifulSoup
#     pip install Requests

# %%
#import the Beautiful soup functions to parse the data returned from the website
from bs4 import BeautifulSoup 
import requests

#Parse the html in the 'page' variable, and store it in Beautiful Soup format

page = requests.get("http://www.rba.gov.au/statistics/cash-rate/")
bs = BeautifulSoup(page.content,"lxml")
print bs.prettify()
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script>
#    (function(){(function(){function e(a){this.t={};this.tick=function(a,c,b){var d=void 0!=b?b:(new Date).getTime();this.t[a]=[d,c];if(void 0==b)try{window.console.timeStamp("CSI/"+a)}catch(e){}};this.tick("start",null,a)}var a,d;window.performance&&(d=(a=window.performance.timing)&&a.responseStart);var f=0<d?new e(d):new e;window.jstiming={Timer:e,load:f};if(a){var c=a.navigationStart;0<c&&d>=c&&(window.jstiming.srt=d-c)}if(a){var b=window.jstiming.load;0<c&&d>=c&&(b.tick("_wtsrt",void 0,c),b.tick("wtsrt_","_wtsrt",
# d),b.tick("tbsd_","wtsrt_"))}try{a=null,window.chrome&&window.chrome.csi&&(a=Math.floor(window.chrome.csi().pageT),b&&0<c&&(b.tick("_tbnd",void 0,window.chrome.csi().startE),b.tick("tbnd_","_tbnd",c))),null==a&&window.gtbExternal&&(a=window.gtbExternal.pageT()),null==a&&window.external&&(a=window.external.pageT,b&&0<c&&(b.tick("_tbnd",void 0,window.external.startE),b.tick("tbnd_","_tbnd",c))),a&&(window.jstiming.pt=a)}catch(g){}})();})();
#   </script>
#   <title>
#    Google Finance: Stock market quotes, news, currency conversions &amp; more
#   </title>
#   <meta content="Get real-time stock quotes &amp; charts, financial news, currency conversions, or track your portfolio with Google Finance." name="Description"/>
#   <meta content="IE=10" http-equiv="X-UA-Compatible"/>
#   <link href="/finance/f/finance_us-1489929081.css" rel="stylesheet" type="text/css"/>
#   <link href="/_/scs/finance-static/_/ss/k=finance.a.-1ad9g7dkeydo6.L.W.O/d=0/rs=AGHGApFc6f3qtgX-rKpnovDqtgcuZ4H2Ng" rel="stylesheet" type="text/css"/>
#   <link href="/finance/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
#   <style>
#    #gbar,#guser{font-size:13px;padding-right:8px;padding-top:4px !important;}#gbar{padding-left:8px;height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}
#   </style>
#   <script>
#   </script>
#   <script>
#    function _rpt() {}
#       function _tck() {}
#   </script>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-40765809-1', {
#       'allowLinker': true,
#       'cookiePath': '/finance'
#     });
#     ga('send', 'pageview');
#   </script>
#  </head>
#  <body>
#   <div class="fjfe-bodywrapper">
#    <div class="g-doc" id="fjfe-real-body">
#     <input id="hist_state" name="hist_state" style="display:none;" type="text"/>
#     <iframe class="invfr" id="hist_frame" name="hist_frame" tabindex="-1">
#     </iframe>
#     <iframe class="invfr" src="/_/scs/finance-static/_/js/k=finance.a.en_US.0md5hz5pgeA.O/m=b/rt=h/d=0/rs=AGHGApHi_3j1v_Z6n816dUrW-04N4o1Vbg" tabindex="-1">
#     </iframe>
#     <div id="gbar">
#      <nobr>
#       <a class="gb1" href="https://www.google.com.au/webhp?tab=ew">
#        Search
#       </a>
#       <a class="gb1" href="http://www.google.com.au/imghp?hl=en&amp;tab=ei">
#        Images
#       </a>
#       <a class="gb1" href="https://maps.google.com.au/maps?hl=en&amp;tab=el">
#        Maps
#       </a>
#       <a class="gb1" href="https://play.google.com/?hl=en&amp;tab=e8">
#        Play
#       </a>
#       <a class="gb1" href="https://www.youtube.com/?tab=e1">
#        YouTube
#       </a>
#       <a class="gb1" href="https://news.google.com.au/nwshp?hl=en&amp;tab=en">
#        News
#       </a>
#       <a class="gb1" href="https://mail.google.com/mail/?tab=em">
#        Gmail
#       </a>
#       <a class="gb1" href="https://drive.google.com/?tab=eo">
#        Drive
#       </a>
#       <a class="gb1" href="https://www.google.com.au/intl/en/options/" style="text-decoration:none">
#        <u>
#         More
#        </u>
#        »
#       </a>
#      </nobr>
#     </div>
#     <div id="guser" width="100%">
#      <nobr>
#       <span class="gbi" id="gbn">
#       </span>
#       <span class="gbf" id="gbf">
#       </span>
#       <span id="gbe">
#       </span>
#       <a class="gb4" href="http://www.google.com/support/finance?hl=en">
#        Help
#       </a>
#       |
#       <a class="gb4" href="https://accounts.google.com/ServiceLogin?service=finance&amp;passive=1209600&amp;continue=https://www.google.com/finance&amp;followup=https://www.google.com/finance" id="gb_70" target="_top">
#        Sign in
#       </a>
#      </nobr>
#     </div>
#     <div class="gbh" style="left:0">
#     </div>
#     <div class="gbh" style="right:0">
#     </div>
#     <div id="fjfe-click-wrapper">
#      <script>
#       (function() {
#   var l = window.location;
#   var q = l.search ? l.search.substr(1) : '';
#   var h = l.hash ? l.hash.substr(1) : '';
#   var p = '/finance';
#   var ss = 'stockscreener';
#   var conn = window.history && window.history.pushState ? '/' : '#';
#   if (l.pathname == p + '/' + ss) {
#     if (h) l.href = p + conn + ss + '?' + q + '&' + h;
#   } else if (l.pathname != p && h) {
#     l.href = p + l.hash;
#   }
#   if (h) {
# document.getElementById('fjfe-click-wrapper').style.display = 'none';
#   }
# })();
#      </script>
#      <div class="g-section g-tpl-75-25 g-split" id="gf-head">
#       <div class="g-unit g-first">
#        <div class="fjfe-logo">
#         <a href="/finance/?ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#          <img alt="Google Finance" src="/finance/f/logo_material-4224265490.png"/>
#         </a>
#        </div>
#        <div class="fjfe-search" id="gf-search">
#         <form action="/finance" autocomplete="off" method="get">
#          <input class="fjfe-searchbox-input" name="q" tabindex="1" type="text" value=""/>
#          <span class="fjfe-searchbox-button-wrapper">
#           <span class="fjfe-searchbox-button-wrapper2">
#            <input class="fjfe-searchbox-button" tabindex="2" type="submit" value="Get quotes"/>
#           </span>
#          </span>
#          <input name="ei" type="hidden" value="a5jHV6H9NIuV0ATwzZ3QBQ"/>
#         </form>
#        </div>
#       </div>
#       <div class="g-unit fjfe-promo">
#        <div class="id-ad2-target" id="ad2-target">
#        </div>
#       </div>
#      </div>
#      <div class="elastic">
#       <div class="g-section g-tpl-left-11p4em" id="app">
#        <div class="g-unit g-first">
#         <div id="gf-nav">
#          <div class="fjfe-nav-nav">
#           <ul class="fjfe-nav" id="navmenu">
#            <li class="fjfe-nav-selected">
#             Markets
#            </li>
#            <li class="fjfe-nav-item">
#             <a href="/finance/market_news?ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#              <div>
#               News
#              </div>
#             </a>
#            </li>
#            <li class="fjfe-nav-item">
#             <a href="/finance/portfolio?action=view&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#              <div>
#               Portfolios
#              </div>
#             </a>
#            </li>
#            <li class="fjfe-nav-item">
#             <a href="/finance/stockscreener?ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#              <div>
#               Stock screener
#              </div>
#             </a>
#            </li>
#            <li class="fjfe-nav-item">
#             <a href="/finance/domestic_trends?ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#              <div>
#               Google Domestic Trends
#              </div>
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="fjfe-recentquotes fjfe-recentquotes-noquote">
#           <h4>
#            Recent Quotes
#            <span class="fjfe-recentquotes-duration">
#             (
#             <a href="//www.google.com/history/optout?hl=en">
#              30 days
#             </a>
#             )
#            </span>
#           </h4>
#           <div class="fjfe-recentquotes-noquote-notification">
#            You have no recent quotes
#           </div>
#           <div class="fjfe-recentquotes-quotes">
#            <div class="fjfe-toggle fjfe-toggle-button">
#             <span class="fjfe-chg-toggle">
#              chg
#             </span>
#             |
#             <span class="fjfe-perc-toggle">
#              %
#             </span>
#            </div>
#            <div class="fjfe-table-div">
#             <table class="fjfe-recentquotes-table" id="rq" width="100%">
#             </table>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="g-unit" id="gf-viewc">
#         <div class="fjfe-content">
#          <div class="g-section sfe-break-bottom-13">
#           <div class="hdg top appbar-hide">
#            <div class="g-section g-tpl-50-50 g-split">
#             <div class="g-unit g-first">
#              <h3>
#               Market summary
#              </h3>
#             </div>
#             <div class="g-unit">
#              Aug 31 - Markets closed
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="g-section g-tpl-right-1 id-reorder" id="reorder">
#           <div class="g-unit g-first">
#            <div class="g-c">
#             <div class="sfe-break-bottom-16" id="ad">
#              <div class="id-ad-label invisible" id="ad-label">
#               Advertisement
#              </div>
#              <div class="id-ad-target ads-300-250" id="ad-target">
#              </div>
#             </div>
#             <div>
#             </div>
#             <div class="rgt-reorder">
#              <div id="portfolios">
#               <div class="id-home-portfolios" id="home-portfolios">
#               </div>
#              </div>
#              <script>
#               _tck('aft');
#              </script>
#              <div id="markets">
#               <div id="markets">
#                <div class="hdg">
#                 <div class="float">
#                  <h3>
#                   World markets
#                  </h3>
#                 </div>
#                 <div class="gf-reorder-btn SP_menu_button">
#                 </div>
#                </div>
#                <div class="sfe-section">
#                 <table class="quotes" width="100%">
#                  <tbody>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=SHA:000001&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      Shanghai
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_7521596_l">
#                      3,078.79
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_7521596_c">
#                      -6.70
#                     </span>
#                     <span class="chr" id="ref_7521596_cp">
#                      (-0.22%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=INDEXNIKKEI:NI225&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      Nikkei 225
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_15513676_l">
#                      16,908.52
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chg" id="ref_15513676_c">
#                      +21.12
#                     </span>
#                     <span class="chg" id="ref_15513676_cp">
#                      (0.13%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=INDEXHANGSENG:HSI&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      Hang Seng Index
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_13414271_l">
#                      23,014.31
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chg" id="ref_13414271_c">
#                      +37.43
#                     </span>
#                     <span class="chg" id="ref_13414271_cp">
#                      (0.16%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=TPE:TAIEX&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      TSEC
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_9947405_l">
#                      8,998.72
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_9947405_c">
#                      -70.13
#                     </span>
#                     <span class="chr" id="ref_9947405_cp">
#                      (-0.77%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=INDEXFTSE:UKX&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      FTSE 100
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_12590587_l">
#                      6,781.51
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_12590587_c">
#                      -39.28
#                     </span>
#                     <span class="chr" id="ref_12590587_cp">
#                      (-0.58%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=INDEXSTOXX:SX5E&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      EURO STOXX 50
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_7354851_l">
#                      3,023.13
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_7354851_c">
#                      -7.62
#                     </span>
#                     <span class="chr" id="ref_7354851_cp">
#                      (-0.25%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=INDEXEURO:PX1&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      CAC 40
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_9237947_l">
#                      4,438.22
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_9237947_c">
#                      -19.27
#                     </span>
#                     <span class="chr" id="ref_9237947_cp">
#                      (-0.43%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=INDEXTSI:OSPTX&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      S&amp;P TSX
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_9291235_l">
#                      14,597.15
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_9291235_c">
#                      -87.70
#                     </span>
#                     <span class="chr" id="ref_9291235_cp">
#                      (-0.60%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=INDEXASX:XJO&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      S&amp;P/ASX 200
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_14240693_l">
#                      5,417.10
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_14240693_c">
#                      -15.90
#                     </span>
#                     <span class="chr" id="ref_14240693_cp">
#                      (-0.29%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=INDEXBOM:SENSEX&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      BSE Sensex
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_15173681_l">
#                      28,452.17
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chg" id="ref_15173681_c">
#                      +109.16
#                     </span>
#                     <span class="chg" id="ref_15173681_cp">
#                      (0.39%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=TLV:T25&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      TA25
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_835285966959493_l">
#                      1,447.01
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_835285966959493_c">
#                      -1.83
#                     </span>
#                     <span class="chr" id="ref_835285966959493_cp">
#                      (-0.13%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=INDEXSWX:SMI&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      SMI
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_1052581216806242_l">
#                      8,202.13
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_1052581216806242_c">
#                      -33.88
#                     </span>
#                     <span class="chr" id="ref_1052581216806242_cp">
#                      (-0.41%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=INDEXVIE:ATX&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      ATX
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_1066235873319497_l">
#                      2,314.38
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_1066235873319497_c">
#                      -18.14
#                     </span>
#                     <span class="chr" id="ref_1066235873319497_cp">
#                      (-0.78%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=INDEXBVMF:IBOV&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      IBOVESPA
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_851377182412228_l">
#                      57,901.11
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_851377182412228_c">
#                      -674.31
#                     </span>
#                     <span class="chr" id="ref_851377182412228_cp">
#                      (-1.15%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=INDEXBKK:SET&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      SET
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_192906426752897_l">
#                      1,548.44
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chb" id="ref_192906426752897_c">
#                      0.00
#                     </span>
#                     <span class="chb" id="ref_192906426752897_cp">
#                      (0.00%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=INDEXIST:XU100&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      BIST100
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_456528970194751_l">
#                      75,967.63
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_456528970194751_c">
#                      -151.21
#                     </span>
#                     <span class="chr" id="ref_456528970194751_cp">
#                      (-0.20%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=INDEXBME:IB&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      IBEX
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_1054681020857808_l">
#                      8,716.80
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chg" id="ref_1054681020857808_c">
#                      +31.40
#                     </span>
#                     <span class="chg" id="ref_1054681020857808_cp">
#                      (0.36%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=WSE:WIG&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      WIG
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_698684623076010_l">
#                      47,935.10
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_698684623076010_c">
#                      -54.49
#                     </span>
#                     <span class="chr" id="ref_698684623076010_cp">
#                      (-0.11%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=TADAWUL:TASI&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      TASI
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_1095233500396574_l">
#                      6,079.51
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_1095233500396574_c">
#                      -50.08
#                     </span>
#                     <span class="chr" id="ref_1095233500396574_cp">
#                      (-0.82%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=BCBA:IAR&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      MERVAL
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_393322345722481_l">
#                      14,480.19
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_393322345722481_c">
#                      -121.14
#                     </span>
#                     <span class="chr" id="ref_393322345722481_cp">
#                      (-0.83%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=INDEXBMV:ME&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      IPC
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_999678732197294_l">
#                      47,541.32
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_999678732197294_c">
#                      -109.25
#                     </span>
#                     <span class="chr" id="ref_999678732197294_cp">
#                      (-0.23%)
#                     </span>
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=IDX:COMPOSITE&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      IDX Composite
#                     </a>
#                    </td>
#                    <td class="price">
#                     <span id="ref_218574097879841_l">
#                      5,368.62
#                     </span>
#                    </td>
#                    <td class="change">
#                     <span class="chr" id="ref_218574097879841_c">
#                      -17.47
#                     </span>
#                     <span class="chr" id="ref_218574097879841_cp">
#                      (-0.32%)
#                     </span>
#                    </td>
#                   </tr>
#                  </tbody>
#                 </table>
#                </div>
#               </div>
#              </div>
#              <div id="currencies">
#               <div id="currencies">
#                <div class="hdg">
#                 <div class="float">
#                  <h3>
#                   Currencies
#                  </h3>
#                 </div>
#                 <div class="gf-reorder-btn SP_menu_button">
#                 </div>
#                </div>
#                <div class="sfe-section">
#                 <table class="quotes" width="100%">
#                  <tbody>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=EURUSD&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      EUR/USD
#                     </a>
#                    </td>
#                    <td class="price">
#                     1.1156
#                    </td>
#                    <td class="change chr">
#                     -0.0003 (-0.03%)
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=USDJPY&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      USD/JPY
#                     </a>
#                    </td>
#                    <td class="price">
#                     103.2250
#                    </td>
#                    <td class="change chr">
#                     -0.0830 (-0.08%)
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=GBPUSD&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      GBP/USD
#                     </a>
#                    </td>
#                    <td class="price">
#                     1.3141
#                    </td>
#                    <td class="change chg">
#                     +0.0009 (0.07%)
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=USDCAD&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      USD/CAD
#                     </a>
#                    </td>
#                    <td class="price">
#                     1.3105
#                    </td>
#                    <td class="change chr">
#                     -0.0006 (-0.05%)
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=USDHKD&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      USD/HKD
#                     </a>
#                    </td>
#                    <td class="price">
#                     7.7570
#                    </td>
#                    <td class="change chg">
#                     +0.0005 (0.01%)
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=USDCNY&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      USD/CNY
#                     </a>
#                    </td>
#                    <td class="price">
#                     6.6805
#                    </td>
#                    <td class="change chg">
#                     +0.0018 (0.03%)
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     <a href="/finance?q=AUDUSD&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                      AUD/USD
#                     </a>
#                    </td>
#                    <td class="price">
#                     0.7532
#                    </td>
#                    <td class="change chg">
#                     +0.0013 (0.17%)
#                    </td>
#                   </tr>
#                  </tbody>
#                 </table>
#                </div>
#               </div>
#              </div>
#              <div id="bonds">
#               <div id="bonds">
#                <div class="hdg">
#                 <div class="float">
#                  <h3>
#                   Bonds
#                  </h3>
#                 </div>
#                 <div class="gf-reorder-btn SP_menu_button">
#                 </div>
#                </div>
#                <div class="sfe-section">
#                 <table class="quotes" width="100%">
#                  <tbody>
#                   <tr>
#                    <td class="symbol">
#                     3 Month
#                    </td>
#                    <td class="price">
#                     0.29%
#                    </td>
#                    <td class="change chr">
#                     -0.01 (-3.33%)
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     6 Month
#                    </td>
#                    <td class="price">
#                     0.45%
#                    </td>
#                    <td class="change chr">
#                     -0.01 (-2.17%)
#                    </td>
#                   </tr>
#                   <tr>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     2 Year
#                    </td>
#                    <td class="price">
#                     0.80%
#                    </td>
#                    <td class="change chg">
#                     +0.01 (1.27%)
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     5 Year
#                    </td>
#                    <td class="price">
#                     1.19%
#                    </td>
#                    <td class="change chg">
#                     +0.01 (0.85%)
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     10 Year
#                    </td>
#                    <td class="price">
#                     1.58%
#                    </td>
#                    <td class="change chg">
#                     +0.01 (0.64%)
#                    </td>
#                   </tr>
#                   <tr>
#                    <td class="symbol">
#                     30 Year
#                    </td>
#                    <td class="price">
#                     2.23%
#                    </td>
#                    <td class="change chr">
#                     -0.01 (-0.45%)
#                    </td>
#                   </tr>
#                  </tbody>
#                 </table>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="g-unit">
#            <div class="g-c sfe-break-right g-floatfix">
#             <div class="sfe-section" id="summary">
#              <div id="summary-news-story">
#               <div class="g-section news">
#                <div class="news major" id="fix-w">
#                 <span class="name">
#                  <a href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=http://www.bloomberg.com/news/articles/2016-09-01/asian-stocks-swing-before-u-s-jobs-data-as-energy-shares-slip&amp;cid=52779195575814&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNGOZBt7576gOw7OcMFpHIu1mi3VGQ" id="n-hp-" rel="nofollow">
#                   Asian Stocks Swing Before U.S. Jobs Data as Energy Shares Slip
#                  </a>
#                 </span>
#                 <br/>
#                 <div class="byline">
#                  <span class="src">
#                   Bloomberg
#                  </span>
#                  -
#                  <span class="date">
#                   2 hours ago
#                  </span>
#                 </div>
#                 <!-- google_ad_section_end -->
#                 <div class="snippet">
#                  Asian stocks swung between gains and losses, after capping a monthly increase, as commodity shares fell after a selloff in U.S. energy companies and investors awaited a report on U.S.
#                 </div>
#                 <!-- google_ad_section_start -->
#                 <div class="rel-article">
#                  <a href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=http://www.cnbc.com/2016/08/31/suddenly-these-two-fears-could-spook-stocks.html&amp;cid=52779195575814&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNHlF0Teq2LYyAflYQIxcLr7y1ESwA" id="n-hp-" rel="nofollow">
#                   Suddenly, these two fears could spook stocks
#                  </a>
#                  <span class="byline">
#                   <span class="src">
#                    CNBC
#                   </span>
#                  </span>
#                 </div>
#                 <div class="rel-article">
#                  <a href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=http://www.marketwatch.com/story/japan-shares-rise-on-yen-weakness-other-asia-stocks-drop-2016-08-31&amp;cid=52779195575814&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNFjgcFmivjiwmKSjaIowAB9rnAMyg" id="n-hp-" rel="nofollow">
#                   Nikkei bucks downward trend in Asia markets, boosted by weak yen
#                  </a>
#                  <span class="byline">
#                   <span class="src">
#                    MarketWatch
#                   </span>
#                  </span>
#                 </div>
#                 <div class="rel-article">
#                  <span class="byline">
#                   <a class="rel" href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=https://www.zacks.com/stock/news/229901/stock-market-news-for-august-31-2016&amp;cid=52779195575814&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNEDiXT1vbaypLFcgqmLYWH_YyJ9Vw" id="n-hp-" rel="nofollow">
#                    Zacks.com
#                   </a>
#                   <a class="rel" href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=https://www.tradingfloor.com/posts/todays-trade-asx-slips-on-oil-price-spill-8031088&amp;cid=52779195575814&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNFdHiZMb9-ppKKSsxeTrFWunoTGMg" id="n-hp-" rel="nofollow">
#                    TradingFloor.com
#                   </a>
#                  </span>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="id-summary-chart">
#               <div class="sfe-home-chart">
#                <div class="ic-chart">
#                 <a href="/finance?q=INDEXDJX:.DJI,INDEXSP:.INX,INDEXNASDAQ:.IXIC&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                  <img alt="Market Chart" class="id-mkt-chart" height="130" id="mkt-chart" onload="_tck('ic')" src="/finance/chart?cht=c&amp;q=INDEXDJX:.DJI,INDEXSP:.INX,INDEXNASDAQ:.IXIC&amp;tlf=12h&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ" width="250"/>
#                 </a>
#                </div>
#               </div>
#               <table id="sfe-mktsumm">
#                <tr>
#                 <td class="legend">
#                  <img alt="" class="SP_legend0 legend" src="..."/>
#                 </td>
#                 <td>
#                  <div class="name bld">
#                   <a href="/finance?q=INDEXDJX:.DJI&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                    Dow Jones
#                   </a>
#                  </div>
#                 </td>
#                 <td class="bld">
#                  <span id="ref_983582_l">
#                   18,400.88
#                  </span>
#                 </td>
#                 <td>
#                  <span class="bld chr" id="ref_983582_c">
#                   -53.42
#                  </span>
#                 </td>
#                 <td>
#                  <span class="chr" id="ref_983582_cp">
#                   (-0.29%)
#                  </span>
#                 </td>
#                </tr>
#                <tr>
#                 <td class="legend">
#                  <img alt="" class="SP_legend1 legend" src="..."/>
#                 </td>
#                 <td>
#                  <div class="name bld">
#                   <a href="/finance?q=INDEXSP:.INX&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                    S&amp;P 500
#                   </a>
#                  </div>
#                 </td>
#                 <td class="bld">
#                  <span id="ref_626307_l">
#                   2,170.95
#                  </span>
#                 </td>
#                 <td>
#                  <span class="bld chr" id="ref_626307_c">
#                   -5.17
#                  </span>
#                 </td>
#                 <td>
#                  <span class="chr" id="ref_626307_cp">
#                   (-0.24%)
#                  </span>
#                 </td>
#                </tr>
#                <tr>
#                 <td class="legend">
#                  <img alt="" class="SP_legend2 legend" src="..."/>
#                 </td>
#                 <td>
#                  <div class="name bld">
#                   <a href="/finance?q=INDEXNASDAQ:.IXIC&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                    Nasdaq
#                   </a>
#                  </div>
#                 </td>
#                 <td class="bld">
#                  <span id="ref_13756934_l">
#                   5,213.22
#                  </span>
#                 </td>
#                 <td>
#                  <span class="bld chr" id="ref_13756934_c">
#                   -9.77
#                  </span>
#                 </td>
#                 <td>
#                  <span class="chr" id="ref_13756934_cp">
#                   (-0.19%)
#                  </span>
#                 </td>
#                </tr>
#               </table>
#              </div>
#             </div>
#             <div class="sfe-section clf">
#             </div>
#             <div class="mid-reorder">
#              <div id="mk-news">
#               <div class="hdg">
#                <h3>
#                 Top stories
#                </h3>
#                <div class="gf-reorder-btn SP_menu_button">
#                </div>
#               </div>
#               <div class="goog-tab-bar hdg id-news-tabs" id="news-tabs">
#                <div class="goog-tab goog-tab-selected">
#                 <a class="t" id="market-news-title">
#                  <b class="t">
#                   <b class="t">
#                    Market
#                   </b>
#                  </b>
#                 </a>
#                </div>
#               </div>
#               <div class="goog-tabpane-clear">
#               </div>
#               <div class="news sfe-section-major id-market-news" id="market-news">
#                <div class="g-section g-tpl-right-14 g-floatfix">
#                 <div class="g-unit g-first">
#                  <div id="scroll-container">
#                  </div>
#                 </div>
#                 <div class="g-unit">
#                  <div class="streaming id-market-news-stream" id="market-news-stream">
#                   <div class="cluster">
#                    <div>
#                     <a class="title" href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=http://www.chicagotribune.com/business/ct-mcdonalds-president-leaving-0901-biz-20160831-story.html&amp;cid=52779195715522&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNFg_oaHoxtq7UJkG9ZW-yU3IaFLDw" id="n-hp-" rel="nofollow">
#                      McDonald's U.S. president, key architect of transformation, to leave at year-end
#                     </a>
#                    </div>
#                    <div class="byline">
#                     <span class="src">
#                      Chicago Tribune
#                     </span>
#                     <span class="date" tm="1472675477">
#                      - 6 hours ago
#                     </span>
#                    </div>
#                    <!-- google_ad_section_end -->
#                    <div class="snippet">
#                     Mike Andres, the president of McDonald's U.S. business and a key architect of the fast food giant's attempt to transform itself through initiatives like all-day breakfast, will leave the company at the end of the year.
#                    </div>
#                    <!-- google_ad_section_start -->
#                   </div>
#                   <div class="cluster">
#                    <div>
#                     <a class="title" href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=http://www.forbes.com/sites/alanohnsman/2016/08/31/musk-promises-major-upgrade-in-tesla-autopilots-ability-to-see/&amp;cid=52779193398911&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNGjVVeJvQTnnTyZsNYhqX2PJA-CoA" id="n-hp-" rel="nofollow">
#                      Musk Promises Major Upgrade In Tesla Autopilot's Ability To 'See'
#                     </a>
#                    </div>
#                    <div class="byline">
#                     <span class="src">
#                      Forbes
#                     </span>
#                     <span class="date" tm="1472670655">
#                      - 7 hours ago
#                     </span>
#                    </div>
#                    <!-- google_ad_section_end -->
#                    <div class="snippet">
#                     Elon Musk said Wednesday he's soon going to make good on a promise to upgrade Tesla Motors' TSLA +0.34% semi-automated Autopilot driving system.
#                    </div>
#                    <!-- google_ad_section_start -->
#                   </div>
#                   <div class="cluster">
#                    <div>
#                     <a class="title" href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=http://www.presstelegram.com/business/20160831/why-big-ships-are-adrift-off-the-ports-of-los-angeles-and-long-beach&amp;cid=52779195613871&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNFNI032dTSOebAPbXkujKE9Sse-KA" id="n-hp-" rel="nofollow">
#                      Why big ships are adrift off the ports of Los Angeles and Long Beach
#                     </a>
#                    </div>
#                    <div class="byline">
#                     <span class="src">
#                      Long Beach Press Telegram
#                     </span>
#                     <span class="date" tm="1472696775">
#                      - 28 minutes ago
#                     </span>
#                    </div>
#                    <!-- google_ad_section_end -->
#                    <div class="snippet">
#                     The container ship Hanjin Montevideo leaves the Hanjin Terminal and the the Port of Long Beach. Hanjin's financial troubles led to the ship Hanjin Montevideo being anchored inside the breakwater.
#                    </div>
#                    <!-- google_ad_section_start -->
#                   </div>
#                   <div class="cluster">
#                    <div>
#                     <a class="title" href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=http://www.cnbc.com/2016/08/31/why-the-federal-reserve-probably-will-not-like-the-nonfarm-payrolls-jobs-report-friday.html&amp;cid=52779195350789&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNE5nhDzG3BEyEhZbQq3UHPE-jy6CA" id="n-hp-" rel="nofollow">
#                      Why the Fed probably won't like the jobs report Friday
#                     </a>
#                    </div>
#                    <div class="byline">
#                     <span class="src">
#                      CNBC
#                     </span>
#                     <span class="date" tm="1472664375">
#                      - 9 hours ago
#                     </span>
#                    </div>
#                    <!-- google_ad_section_end -->
#                    <div class="snippet">
#                     August has disappointed the market nine of the last 12 years and is usually followed by substantial revisions. Jeff Cox | @JeffCoxCNBCcom.
#                    </div>
#                    <!-- google_ad_section_start -->
#                   </div>
#                   <div class="cluster">
#                    <div>
#                     <a class="title" href="http://news.google.com/news/url?sa=T&amp;ct2=us&amp;fd=S&amp;url=http://www.reuters.com/article/us-usa-stocks-idUSKCN1161O0&amp;cid=52779195680199&amp;ei=9JfHV-CtEMXgugTQjajYAg&amp;usg=AFQjCNGY7Uq23Seyrf6dnaAcrjh5XhVpJg" id="n-hp-" rel="nofollow">
#                      Energy drags Wall St. lower; S&amp;P down slightly in August
#                     </a>
#                    </div>
#                    <div class="byline">
#                     <span class="src">
#                      Reuters
#                     </span>
#                     <span class="date" tm="1472648472">
#                      - 13 hours ago
#                     </span>
#                    </div>
#                    <!-- google_ad_section_end -->
#                    <div class="snippet">
#                     Traders work on the floor of the New York Stock Exchange (NYSE) in New York City, U.S., August 31, 2016. REUTERS/Brendan McDermid.
#                    </div>
#                    <!-- google_ad_section_start -->
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="section-link">
#                 <a href="/finance/market_news?ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                  More market news »
#                 </a>
#                </div>
#               </div>
#              </div>
#              <div id="trend">
#               <div class="hdg">
#                <h3>
#                 Trends
#                </h3>
#                <div class="gf-reorder-btn SP_menu_button hide">
#                </div>
#               </div>
#               <div class="hdg goog-tab-bar id-trends" id="trends">
#                <div class="goog-tab goog-tab-selected">
#                 <a class="t" id="l_tm_zeitgeist">
#                  <b class="t">
#                   <b class="t">
#                    Popular
#                   </b>
#                  </b>
#                 </a>
#                </div>
#                <div class="goog-tab">
#                 <a class="t" id="l_tm_price">
#                  <b class="t">
#                   <b class="t">
#                    Price
#                   </b>
#                  </b>
#                 </a>
#                </div>
#                <div class="goog-tab">
#                 <a class="t" id="l_tm_mcap">
#                  <b class="t">
#                   <b class="t">
#                    Mkt Cap
#                   </b>
#                  </b>
#                 </a>
# ...
#                     </td>
#                    </tr>
#                   </table>
#                  </td>
#                  <td style="width:28%">
#                   <table cellpadding="0" cellspacing="0" class="bars" width="100%">
#                    <tr style="height:0.9em">
#                     <td class="chgSectorLight" style="width:51%;" title="32% companies in Healthcare are up between 0% and 2%">
#                     </td>
#                     <td class="chgSectorDark" style="width:6%" title="4% companies in Healthcare are up more than 2%">
#                     </td>
#                     <td style="background-color:#FFFFFF; width:43%">
#                     </td>
#                    </tr>
#                   </table>
#                  </td>
#                 </tr>
#                 <tr>
#                  <td style="text-align:left; padding-right:0.5em">
#                   <a href="/finance?catid=TRBC:57&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                    Technology
#                   </a>
#                  </td>
#                  <td style="width:20%; padding-right:1em">
#                   <span class="chr">
#                    -0.22%
#                   </span>
#                  </td>
#                  <td style="width:32%">
#                   <table cellpadding="0" cellspacing="0" class="bars" width="100%">
#                    <tr style="height:0.9em">
#                     <td style="background-color:#FFFFFF; width:30%">
#                     </td>
#                     <td class="chrSectorDark" style="width:16%" title="12% companies in Technology down by more than 2%">
#                     </td>
#                     <td class="chrSectorLight" style="width:54%; border-right:1px #CCB3AB solid" title="41% companies in Technology down between 0% and 2%">
#                     </td>
#                    </tr>
#                   </table>
#                  </td>
#                  <td style="width:28%">
#                   <table cellpadding="0" cellspacing="0" class="bars" width="100%">
#                    <tr style="height:0.9em">
#                     <td class="chgSectorLight" style="width:64%;" title="40% companies in Technology are up between 0% and 2%">
#                     </td>
#                     <td class="chgSectorDark" style="width:11%" title="7% companies in Technology are up more than 2%">
#                     </td>
#                     <td style="background-color:#FFFFFF; width:25%">
#                     </td>
#                    </tr>
#                   </table>
#                  </td>
#                 </tr>
#                 <tr>
#                  <td style="text-align:left; padding-right:0.5em">
#                   <a href="/finance?catid=TRBC:58&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                    Telecommunications Servi...
#                   </a>
#                  </td>
#                  <td style="width:20%; padding-right:1em">
#                   <span class="chr">
#                    -0.41%
#                   </span>
#                  </td>
#                  <td style="width:32%">
#                   <table cellpadding="0" cellspacing="0" class="bars" width="100%">
#                    <tr style="height:0.9em">
#                     <td style="background-color:#FFFFFF; width:14%">
#                     </td>
#                     <td class="chrSectorDark" style="width:16%" title="12% companies in Telecommunications Services down by more than 2%">
#                     </td>
#                     <td class="chrSectorLight" style="width:70%; border-right:1px #CCB3AB solid" title="53% companies in Telecommunications Services down between 0% and 2%">
#                     </td>
#                    </tr>
#                   </table>
#                  </td>
#                  <td style="width:28%">
#                   <table cellpadding="0" cellspacing="0" class="bars" width="100%">
#                    <tr style="height:0.9em">
#                     <td class="chgSectorLight" style="width:50%;" title="31% companies in Telecommunications Services are up between 0% and 2%">
#                     </td>
#                     <td class="chgSectorDark" style="width:6%" title="4% companies in Telecommunications Services are up more than 2%">
#                     </td>
#                     <td style="background-color:#FFFFFF; width:44%">
#                     </td>
#                    </tr>
#                   </table>
#                  </td>
#                 </tr>
#                 <tr>
#                  <td style="text-align:left; padding-right:0.5em">
#                   <a href="/finance?catid=TRBC:59&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#                    Utilities
#                   </a>
#                  </td>
#                  <td style="width:20%; padding-right:1em">
#                   <span class="chg">
#                    +0.23%
#                   </span>
#                  </td>
#                  <td style="width:32%">
#                   <table cellpadding="0" cellspacing="0" class="bars" width="100%">
#                    <tr style="height:0.9em">
#                     <td style="background-color:#FFFFFF; width:50%">
#                     </td>
#                     <td class="chrSectorDark" style="width:4%" title="3% companies in Utilities down by more than 2%">
#                     </td>
#                     <td class="chrSectorLight" style="width:46%; border-right:1px #CCB3AB solid" title="35% companies in Utilities down between 0% and 2%">
#                     </td>
#                    </tr>
#                   </table>
#                  </td>
#                  <td style="width:28%">
#                   <table cellpadding="0" cellspacing="0" class="bars" width="100%">
#                    <tr style="height:0.9em">
#                     <td class="chgSectorLight" style="width:93%;" title="58% companies in Utilities are up between 0% and 2%">
#                     </td>
#                     <td class="chgSectorDark" style="width:6%" title="4% companies in Utilities are up more than 2%">
#                     </td>
#                     <td style="background-color:#FFFFFF; width:1%">
#                     </td>
#                    </tr>
#                   </table>
#                  </td>
#                 </tr>
#                </table>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div id="gf-foot">
#      <div class="fjfe-footer-links" id="fjfe-edition-links">
#       Google Finance Beta available in:
#       <a class="fjfe-edition-link" href="http://www.google.com.hk/finance?ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#        Hong Kong
#       </a>
#       -
#       <a class="fjfe-edition-link" href="http://www.google.ca/finance?ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#        Canada
#       </a>
#       -
#       <a class="fjfe-edition-link" href="http://www.google.com/finance?ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#        U.S.
#       </a>
#       -
#       <a class="fjfe-edition-link" href="http://www.google.com.hk/finance?hl=zh-CN&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#        China
#       </a>
#       -
#       <a class="fjfe-edition-link" href="http://www.google.co.uk/finance?ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#        U.K.
#       </a>
#      </div>
#      <p class="fjfe-footer-disclaimer">
#       Information is provided "as is" and solely for informational purposes, not for trading purposes or advice, and may be delayed.
#       <br/>
#       To see all exchange delays, please
#       <a class="fjfe-secondary-link fjfe-no-sticky-params" href="http://www.google.com/intl/en/googlefinance/disclaimer/?ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#        see disclaimer
#       </a>
#       .
#      </p>
#      <div class="fjfe-footer-links">
#       ©2016 Google -
#       <a href="http://www.google.com?hl=en&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#        Google Home
#       </a>
#       -
#       <a href="http://googlefinanceblog.blogspot.com?ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#        Blog
#       </a>
#       -
#       <a href="http://support.google.com/finance?hl=en&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#        Help
#       </a>
#       -
#       <a href="http://support.google.com/finance?ctx=report&amp;hl=en&amp;ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#        Report a Problem
#       </a>
#       -
#       <a href="http://www.google.com/intl/en/policies/privacy/?ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#        Privacy Policy
#       </a>
#       -
#       <a href="http://www.google.com/intl/en/policies/terms/?ei=a5jHV6H9NIuV0ATwzZ3QBQ">
#        Terms of Service
#       </a>
#      </div>
#     </div>
#     <script>
#      var _cleardot = '...\/\/\/\/\/\/\/yH5BAEKAAEALAAAAAABAAEAAAICTAEAOw\x3d\x3d';
#     var google = google || {};
#     google.finance = google.finance || {};
#     google.finance.gce = false ;
#     </script>
#     <script src="/finance/f/sfe-opt-3379333646.js">
#     </script>
#     <script>
#      _regOnLoad = function(f) {
#         if (document.readyState == 'complete') {
#           f && f();
#         } else {
#           // Window.attachEvent() for IE8 and below compatability.
#           var addEventFunction = window.attachEvent ||
#               window.addEventListener || function(ignored, f) { f(); };
#           var event = window.attachEvent ? 'onload' : 'load';
#           f && addEventFunction(event, f);
#         }
#       };
#
#       google.finance.renderRecentQuotes = function() {};
#     </script>
#     <script>
#      var _prefs=_prefs||{};_prefs.hash="";
# _prefs.promo=_prefs.promo||{};
# _prefs.home_tabs=_prefs.home_tabs||{};
# _prefs.home=_prefs.home||{};
# _prefs.home["sorder"] = 'MPTC-WAFB';
# function initPage() {
# google.MiniPortfolios.setHiddenPids(
# "",
# "");
# google.finance.data.home = google.finance.data.home || {};
# google.finance.data.home.tmExch = [];
# google.finance.common.listenToForm('pform');
# google.finance.onHomeLoad();
# }
# var _chartConfigObject;
# var _cleardot;
# var _companyName;
# var _eventid = 'a5jHV6H9NIuV0ATwzZ3QBQ';
# var _expid;
# var _external_target;
# var _localDomain = 'www.google.com';
# var _minZoomDays;
# var _minZoomDaysNoIntraDay;
# var _prefs;
# var _ticker;
# var _urlSuffix;
# var google = google || {};
# google.finance = google.finance || {};
# google.finance.data = {common:{rq:{ct:""},up:"chg",down:"chr",linktargetInternal:"",hash:"",dfp:"ad-g.doubleclick.net/adi/com.gf.home/default;ssl=1;dcopt=ist;myd=ad;sz=300x250;tile=1",streaming:[{cid:"983582",s:".DJI",e:"INDEXDJX"},{cid:"626307",s:".INX",e:"INDEXSP"},{cid:"13756934",s:".IXIC",e:"INDEXNASDAQ"},{cid:"7521596",s:"000001",e:"SHA"},{cid:"15513676",s:"NI225",e:"INDEXNIKKEI"},{cid:"13414271",s:"HSI",e:"INDEXHANGSENG"},{cid:"9947405",s:"TAIEX",e:"TPE"},{cid:"12590587",s:"UKX",e:"INDEXFTSE"},{cid:"7354851",s:"SX5E",e:"INDEXSTOXX"},{cid:"9237947",s:"PX1",e:"INDEXEURO"},{cid:"9291235",s:"OSPTX",e:"INDEXTSI"},{cid:"14240693",s:"XJO",e:"INDEXASX"},{cid:"15173681",s:"SENSEX",e:"INDEXBOM"},{cid:"835285966959493",s:"T25",e:"TLV"},{cid:"542029859096076",s:"KOSPI",e:"INDEXKRX"},{cid:"1052581216806242",s:"SMI",e:"INDEXSWX"},{cid:"1066235873319497",s:"ATX",e:"INDEXVIE"},{cid:"851377182412228",s:"IBOV",e:"INDEXBVMF"},{cid:"192906426752897",s:"SET",e:"INDEXBKK"},{cid:"456528970194751",s:"XU100",e:"INDEXIST"},{cid:"1054681020857808",s:"IB",e:"INDEXBME"},{cid:"698684623076010",s:"WIG",e:"WSE"},{cid:"1095233500396574",s:"TASI",e:"TADAWUL"},{cid:"393322345722481",s:"IAR",e:"BCBA"},{cid:"999678732197294",s:"ME",e:"INDEXBMV"},{cid:"218574097879841",s:"COMPOSITE",e:"IDX"}]},home:{widescreen_width:1290},stickyUrlArgs:"\u0026ei=a5jHV6H9NIuV0ATwzZ3QBQ"};
# google.finance.data.numberFormat = [{'threshold':1000000, 'symbol':'M'}, {'threshold':1000000000,'symbol':'B'}, {'threshold':1000000000000,'symbol':'T'}] ;
# _setStickyUrlParams("ei=a5jHV6H9NIuV0ATwzZ3QBQ");
# if (_s_Store) {
# _s_Store._allowMatchAdvancedSearch = true;
# var _fieldToDisplayNameMap = {GrossMargin:"Gross margin&nbsp;(%)",Return1Week:"1w return",Return156Week:"156w return",NextYearEPS:"Next year EPS",LTDebtToAssetsYear:"LT debt/assets (Recent&nbsp;yr)&nbsp;(%)",RevenueGrowthRate5Years:"5y revenue growth rate",EarningsAfterTaxes:"Earnings after taxes",DividendPerShare:"Div per share",MarketCap:"Market cap",NetProfitMarginPercent:"Net profit margin&nbsp;(%)",Float:"Float",EarningsBeforeTaxes:"Earnings before taxes",QuotePercChange:"Quote change&nbsp;(%)",TotalDebtToEquityYear:"Total debt/equity (Recent&nbsp;yr)&nbsp;(%)",TotalDebtToCapitalQuarter:"Total debt/capital (Recent&nbsp;qtr)&nbsp;(%)",LTDebtToCapitalQuarter:"LT debt/capital (Recent&nbsp;qtr)&nbsp;(%)",EPSGrowthRate10Years:"10y EPS growth rate",Beta:"Beta",ReturnOnAssetsPTM:"Return on assets (PTM)&nbsp;(%)",CapitalGain:"Capital gain",BetaDown:"Beta down from RAS",IncomeDividend:"Income dividend",RevenueGrowthRate10Years:"10y revenue growth rate",MarketCapShareBasis:"Market cap share basis",IAD:"Div rate indicated annual",Return4Week:"4w return",Price150DayAverage:"150d avg price",EPSGrowthRate5Years:"5y EPS growth rate",ReturnOnAssetsTTM:"Return on assets (TTM)&nbsp;(%)",TotalDebtToAssetsYear:"Total debt/assets (Recent&nbsp;yr)&nbsp;(%)",Volume:"Volume",DividendRecentQuarter:"Div recent quarter",CurrentRatioYear:"Current ratio",Low52Week:"52w low",ExpenseRatio:"Expense ratio",Price13WeekPercChange:"13w&nbsp;price change&nbsp;(%)",Price1DayPercChange:"1d&nbsp;price change&nbsp;(%)",ReturnOnEquity5Years:"Return on equity (5&nbsp;yr&nbsp;avg)&nbsp;(%)",TotalDebtToCapitalYear:"Total debt/capital (Recent&nbsp;yr)&nbsp;(%)",TotalDebtToAssetsQuarter:"Total debt/assets (Recent&nbsp;qtr)&nbsp;(%)",NavChange:"Nav change",OperatingMargin:"Operating margin&nbsp;(%)",DPSRecentYear:"Div per share (Recent&nbsp;yr)",ANI:"Earnings after taxes (Recent&nbsp;yr)",AverageVolume:"Average volume",High52Week:"52w high",Return13Week:"13w return",PriceToCashFlowPerShare:"Price to cash flow per share",ATAXRATE:"Tax rate (Recent&nbsp;yr)",Price26WeekPercChange:"26w&nbsp;price change&nbsp;(%)",QuoteChange:"Quote change",NetIncomeChangePerc:"Net income change&nbsp;(%)",ReturnOnInvestment5Years:"Return on investment (5&nbsp;yr&nbsp;avg)&nbsp;(%)",PE:"P/E ratio",ReturnOnInvestmentYear:"Return on investment (Recent&nbsp;yr)&nbsp;(%)",Price200DayAverage:"200d avg price",DividendNextQuarter:"Div next quarter",EBITD:"EBITDA",PriceYTDPercChange:"YTD&nbsp;price change&nbsp;(%)",ReturnOnInvestmentTTM:"Return on investment (TTM)&nbsp;(%)",NavChangePercent:"Nav change&nbsp;(%)",EBITDMargin:"EBITDA margin&nbsp;(%)",LTDebtToEquityQuarter:"LT debt/equity (Recent&nbsp;qtr)&nbsp;(%)",BetaRAS:"Beta from RAS",PriceSales:"Price to sales",NetAssets:"Net assets",ReturnOnEquityTTM:"Return on equity (TTM)&nbsp;(%)",CashPerShareYear:"Cash/share",ReturnOnAssets5Years:"Return on assets (5&nbsp;yr&nbsp;avg)&nbsp;(%)",ReturnDay:"1d return",Return52Week:"52w return",ForwardPE1Year:"1y fwd P/E",NetIncomeGrowthRate5Years:"5y net income growth rate",DividendYield:"Div yield&nbsp;(%)",Dividend:"Div from cash flow",BetaUp:"Beta up from RAS",LTDebtToCapitalYear:"LT debt/capital (Recent&nbsp;yr)&nbsp;(%)",nprice:"Price from RAS",Return260Week:"260w return",ReturnOnEquityQuarter:"Return on equity (Recent&nbsp;qtr)&nbsp;(%)",ACOGS:"Cost of goods sold",LTDebtToAssetsQuarter:"LT debt/assets (Recent&nbsp;qtr)&nbsp;(%)",PriceToBook:"Price to book",LTDebtToEquityYear:"LT debt/equity (Recent&nbsp;yr)&nbsp;(%)",ReturnYTD:"Return YTD",ReturnOnEquityYear:"Return on equity (Recent&nbsp;yr)&nbsp;(%)",ReturnOnAssetsQuarter:"Return on assets (Recent&nbsp;qtr)&nbsp;(%)",TotalDebtToEquityQuarter:"Total debt/equity (Recent&nbsp;qtr)&nbsp;(%)",NavPrior:"Nav prior",AINTCOV:"Interest coverage",EPS:"EPS",ReturnOnInvestmentQuarter:"Return on investment (Recent&nbsp;qtr)&nbsp;(%)",QuoteLast:"Last price",Price50DayAverage:"50d avg price",Price4WeekPercChange:"4w&nbsp;price change&nbsp;(%)",ReturnOnAssetsYear:"Ret ...
# _s_Store._asStore._addStrings(_fieldToDisplayNameMap);
# }
# if (_s_Store) {
# _s_Store._allowMultipleInBox = true;
# }
# _regOnLoad(initPage);
#     </script>
#    </div>
#   </div>
#   <script>
#    var googlefinance = {i: ["f.b.id","",null,0,"",0,null,["f.b.cf","0md5hz5pgeA.en_US.",0],[],1,[],"a5jHV6H9NIuV0ATwzZ3QBQ","www.google.com","pTq2F_PPTXT4GLdbVQ2PL5rBT5Y:1472698475979",1]}; GF_domReady = 1;
#   </script>
#  </body>
# </html>

# %% [markdown]
# ### Extract the links using BeautifulSoup

# %%
links= bs.find_all('a')
links[1:10]
# Out:
# [<a class="gb1" href="http://www.google.com.au/imghp?hl=en&amp;tab=ei">Images</a>,
#  <a class="gb1" href="https://maps.google.com.au/maps?hl=en&amp;tab=el">Maps</a>,
#  <a class="gb1" href="https://play.google.com/?hl=en&amp;tab=e8">Play</a>,
#  <a class="gb1" href="https://www.youtube.com/?tab=e1">YouTube</a>,
#  <a class="gb1" href="https://news.google.com.au/nwshp?hl=en&amp;tab=en">News</a>,
#  <a class="gb1" href="https://mail.google.com/mail/?tab=em">Gmail</a>,
#  <a class="gb1" href="https://drive.google.com/?tab=eo">Drive</a>,
#  <a class="gb1" href="https://www.google.com.au/intl/en/options/" style="text-decoration:none"><u>More</u> »</a>,
#  <a class="gb4" href="http://www.google.com/support/finance?hl=en">Help</a>]

# %% [markdown]
# ### Discussion:
#
# Tables are also very important elements in HTML for parsing. Similarly, we can use findall method to find all tables in the page. Try to fetch important tables in the page and convert the data inside into a dataframe.

# %% [markdown]
# ### Solution:

# %%
# grab a piece of a table, row & column
def fetch_row_in_table(table, table_id, row_id):
    elements=[]
    contents=[]
    if len(table)> table_id + 1: rows= table[table_id].findall('.//tr')
    if len(rows)> row_id + 1: elements= rows[row_id].findall('.//td')
    for element in elements:
        contents += [val.text_content() for val in element]
    return contents

# %%
tables = data.findall('.//table')
fetch_row_in_table(tables,1,1)
# Out:
# ['Nikkei 225\n', '16,908.52', '+21.12', '(0.13%)']

# %%
# and, as above, search for '<table ' in the raw html, then Nikkei (Japanese stock market)
# seems it's not the first one, it's 'Shanghai'
fetch_row_in_table(tables,1,0)
# Out:
# ['Shanghai\n', '3,079.38', '-6.11', '(-0.20%)']

# %% [markdown]
# ### Discussion
# Pandas makes our life easier with many useful functions.
# Try pandas.read_html.

# %%
import pandas as pd
all_tables = pd.read_html('https://www.google.com/finance#stockscreener')

# %% [markdown]
# ***
# ## API:
# In addition to HTML format, data is commonly found on the web through public APIs. We use the 'requests' package (http://docs.python-requests.org) to call APIs using Python. In the following example, we call a public API for collecting weather data.
#
#
# ** You need to sign up for a free account to get your unique API key to use in the following code. register at**  http://api.openweathermap.org

# %%
#Now we  use requests to retrieve the web page with our data
import requests
url= 'http://api.openweathermap.org/data/2.5/forecast/city?id=524901&APPID=8b54baa39e4e6fa4ae7baea09320d63c'#write your APPID here#
response= requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# The response object contains GET query response. A successfull one has a value of 200. we need to parse the response with json to extract the information.

# %%
#Check the HTTP status code https://en.wikipedia.org/wiki/List_of_HTTP_status_codes
print response.status_code
# Out:
# 200

# %%
# response.content is text
print type(response.content)
# Out:
# <type 'str'>

# %%
#response.json() converts the content to json 
data = response.json()
print type(data)
# Out:
# <type 'dict'>

# %%
data.keys()
# Out:
# [u'city', u'message', u'list', u'cod', u'cnt']

# %% [markdown]
# The keys explain the structure of the fetched data. Try displaying values for each element. In this example, the weather information exists in the 'list'.

# %%
data['list'][10]
# Out:
# {u'clouds': {u'all': 64},
#  u'dt': 1472806800,
#  u'dt_txt': u'2016-09-02 09:00:00',
#  u'main': {u'grnd_level': 1007.4,
#   u'humidity': 74,
#   u'pressure': 1007.4,
#   u'sea_level': 1026.82,
#   u'temp': 292.55,
#   u'temp_kf': -0.99,
#   u'temp_max': 293.532,
#   u'temp_min': 292.55},
#  u'rain': {},
#  u'sys': {u'pod': u'd'},
#  u'weather': [{u'description': u'broken clouds',
#    u'icon': u'04d',
#    u'id': 803,
#    u'main': u'Clouds'}],
#  u'wind': {u'deg': 269.516, u'speed': 3.04}}

# %% [markdown]
# The next step is to create a DataFrame with the weather information, which is demonstrated as follows. You can select a subset to display or display the entire data

# %%
from pandas import DataFrame
# data with the default column headers
weather_table_all= DataFrame(data['list'])
weather_table_all
# Out:
#           clouds          dt               dt_txt  \
# 0    {u'all': 0}  1472698800  2016-09-01 03:00:00
# 1    {u'all': 0}  1472709600  2016-09-01 06:00:00
# 2    {u'all': 8}  1472720400  2016-09-01 09:00:00
# 3    {u'all': 0}  1472731200  2016-09-01 12:00:00
# 4    {u'all': 0}  1472742000  2016-09-01 15:00:00
# 5   {u'all': 12}  1472752800  2016-09-01 18:00:00
# 6   {u'all': 80}  1472763600  2016-09-01 21:00:00
# 7   {u'all': 56}  1472774400  2016-09-02 00:00:00
# 8   {u'all': 80}  1472785200  2016-09-02 03:00:00
# 9   {u'all': 12}  1472796000  2016-09-02 06:00:00
# 10  {u'all': 64}  1472806800  2016-09-02 09:00:00
# 11   {u'all': 8}  1472817600  2016-09-02 12:00:00
# 12  {u'all': 68}  1472828400  2016-09-02 15:00:00
# 13  {u'all': 36}  1472839200  2016-09-02 18:00:00
# 14   {u'all': 0}  1472850000  2016-09-02 21:00:00
# 15   {u'all': 0}  1472860800  2016-09-03 00:00:00
# 16  {u'all': 68}  1472871600  2016-09-03 03:00:00
# 17  {u'all': 80}  1472882400  2016-09-03 06:00:00
# 18  {u'all': 64}  1472893200  2016-09-03 09:00:00
# 19  {u'all': 56}  1472904000  2016-09-03 12:00:00
# 20  {u'all': 64}  1472914800  2016-09-03 15:00:00
# 21   {u'all': 0}  1472925600  2016-09-03 18:00:00
# 22  {u'all': 20}  1472936400  2016-09-03 21:00:00
# 23  {u'all': 56}  1472947200  2016-09-04 00:00:00
# 24  {u'all': 88}  1472958000  2016-09-04 03:00:00
# 25  {u'all': 36}  1472968800  2016-09-04 06:00:00
# 26  {u'all': 44}  1472979600  2016-09-04 09:00:00
# 27  {u'all': 68}  1472990400  2016-09-04 12:00:00
# 28  {u'all': 64}  1473001200  2016-09-04 15:00:00
# 29  {u'all': 92}  1473012000  2016-09-04 18:00:00
# 30  {u'all': 92}  1473022800  2016-09-04 21:00:00
# 31  {u'all': 44}  1473033600  2016-09-05 00:00:00
# 32  {u'all': 88}  1473044400  2016-09-05 03:00:00
# 33  {u'all': 48}  1473055200  2016-09-05 06:00:00
# 34  {u'all': 76}  1473066000  2016-09-05 09:00:00
# 35  {u'all': 56}  1473076800  2016-09-05 12:00:00
# 36  {u'all': 36}  1473087600  2016-09-05 15:00:00
# 37   {u'all': 0}  1473098400  2016-09-05 18:00:00
# 38   {u'all': 0}  1473109200  2016-09-05 21:00:00
# 39   {u'all': 0}  1473120000  2016-09-06 00:00:00
#
#                                                  main            rain  \
# 0   {u'temp_kf': -2.08, u'temp': 280.61, u'grnd_le...              {}
# 1   {u'temp_kf': -1.97, u'temp': 284.85, u'grnd_le...              {}
# 2   {u'temp_kf': -1.86, u'temp': 287.64, u'grnd_le...              {}
# 3   {u'temp_kf': -1.75, u'temp': 289.06, u'grnd_le...              {}
# 4   {u'temp_kf': -1.64, u'temp': 288.46, u'grnd_le...              {}
# 5   {u'temp_kf': -1.53, u'temp': 283.49, u'grnd_le...              {}
# 6   {u'temp_kf': -1.42, u'temp': 282.98, u'grnd_le...              {}
# 7   {u'temp_kf': -1.31, u'temp': 284.15, u'grnd_le...              {}
# 8   {u'temp_kf': -1.2, u'temp': 284.07, u'grnd_lev...   {u'3h': 0.02}
# 9   {u'temp_kf': -1.1, u'temp': 289.56, u'grnd_lev...  {u'3h': 0.025}
# 10  {u'temp_kf': -0.99, u'temp': 292.55, u'grnd_le...              {}
# 11  {u'temp_kf': -0.88, u'temp': 293.87, u'grnd_le...              {}
# 12  {u'temp_kf': -0.77, u'temp': 292.98, u'grnd_le...              {}
# 13  {u'temp_kf': -0.66, u'temp': 290.57, u'grnd_le...   {u'3h': 0.02}
# 14  {u'temp_kf': -0.55, u'temp': 287.16, u'grnd_le...              {}
# 15  {u'temp_kf': -0.44, u'temp': 285.33, u'grnd_le...              {}
# 16  {u'temp_kf': -0.33, u'temp': 284.01, u'grnd_le...              {}
# 17  {u'temp_kf': -0.22, u'temp': 288.67, u'grnd_le...              {}
# 18  {u'temp_kf': -0.11, u'temp': 291.79, u'grnd_le...              {}
# 19  {u'temp_kf': 0, u'temp': 291.849, u'grnd_level...   {u'3h': 0.01}
# 20  {u'temp_kf': 0, u'temp': 291.27, u'grnd_level'...   {u'3h': 0.01}
# 21  {u'temp_kf': 0, u'temp': 287.218, u'grnd_level...              {}
# 22  {u'temp_kf': 0, u'temp': 284.145, u'grnd_level...              {}
# 23  {u'temp_kf': 0, u'temp': 282.992, u'grnd_level...              {}
# 24  {u'temp_kf': 0, u'temp': 284.531, u'grnd_level...   {u'3h': 0.65}
# 25  {u'temp_kf': 0, u'temp': 287.152, u'grnd_level...      {u'3h': 1}
# 26  {u'temp_kf': 0, u'temp': 290.487, u'grnd_level...              {}
# 27  {u'temp_kf': 0, u'temp': 291.486, u'grnd_level...              {}
# 28  {u'temp_kf': 0, u'temp': 290.726, u'grnd_level...   {u'3h': 0.19}
# 29  {u'temp_kf': 0, u'temp': 287.731, u'grnd_level...   {u'3h': 1.95}
# 30  {u'temp_kf': 0, u'temp': 286.777, u'grnd_level...  {u'3h': 10.83}
# 31  {u'temp_kf': 0, u'temp': 285.409, u'grnd_level...   {u'3h': 0.28}
# 32  {u'temp_kf': 0, u'temp': 285.121, u'grnd_level...   {u'3h': 0.03}
# 33  {u'temp_kf': 0, u'temp': 287.257, u'grnd_level...   {u'3h': 0.08}
# 34  {u'temp_kf': 0, u'temp': 288.215, u'grnd_level...   {u'3h': 0.11}
# 35  {u'temp_kf': 0, u'temp': 288.655, u'grnd_level...   {u'3h': 0.01}
# 36  {u'temp_kf': 0, u'temp': 288.563, u'grnd_level...   {u'3h': 0.01}
# 37  {u'temp_kf': 0, u'temp': 285.471, u'grnd_level...              {}
# 38  {u'temp_kf': 0, u'temp': 283.809, u'grnd_level...              {}
# 39  {u'temp_kf': 0, u'temp': 282.673, u'grnd_level...              {}
#
#                sys                                            weather  \
# 0   {u'pod': u'd'}  [{u'main': u'Clear', u'id': 800, u'icon': u'01...
# 1   {u'pod': u'd'}  [{u'main': u'Clear', u'id': 800, u'icon': u'01...
# 2   {u'pod': u'd'}  [{u'main': u'Clear', u'id': 800, u'icon': u'02...
# 3   {u'pod': u'd'}  [{u'main': u'Clear', u'id': 800, u'icon': u'01...
# 4   {u'pod': u'd'}  [{u'main': u'Clear', u'id': 800, u'icon': u'01...
# 5   {u'pod': u'n'}  [{u'main': u'Clouds', u'id': 801, u'icon': u'0...
# 6   {u'pod': u'n'}  [{u'main': u'Clouds', u'id': 803, u'icon': u'0...
# 7   {u'pod': u'n'}  [{u'main': u'Clouds', u'id': 803, u'icon': u'0...
# 8   {u'pod': u'd'}  [{u'main': u'Rain', u'id': 500, u'icon': u'10d...
# 9   {u'pod': u'd'}  [{u'main': u'Rain', u'id': 500, u'icon': u'10d...
# 10  {u'pod': u'd'}  [{u'main': u'Clouds', u'id': 803, u'icon': u'0...
# 11  {u'pod': u'd'}  [{u'main': u'Clear', u'id': 800, u'icon': u'02...
# 12  {u'pod': u'd'}  [{u'main': u'Clouds', u'id': 803, u'icon': u'0...
# 13  {u'pod': u'n'}  [{u'main': u'Rain', u'id': 500, u'icon': u'10n...
# 14  {u'pod': u'n'}  [{u'main': u'Clear', u'id': 800, u'icon': u'01...
# 15  {u'pod': u'n'}  [{u'main': u'Clear', u'id': 800, u'icon': u'01...
# 16  {u'pod': u'd'}  [{u'main': u'Clouds', u'id': 803, u'icon': u'0...
# 17  {u'pod': u'd'}  [{u'main': u'Clouds', u'id': 803, u'icon': u'0...
# 18  {u'pod': u'd'}  [{u'main': u'Clouds', u'id': 803, u'icon': u'0...
# 19  {u'pod': u'd'}  [{u'main': u'Rain', u'id': 500, u'icon': u'10d...
# 20  {u'pod': u'd'}  [{u'main': u'Rain', u'id': 500, u'icon': u'10d...
# 21  {u'pod': u'n'}  [{u'main': u'Clear', u'id': 800, u'icon': u'01...
# 22  {u'pod': u'n'}  [{u'main': u'Clouds', u'id': 801, u'icon': u'0...
# 23  {u'pod': u'n'}  [{u'main': u'Clouds', u'id': 803, u'icon': u'0...
# 24  {u'pod': u'd'}  [{u'main': u'Rain', u'id': 500, u'icon': u'10d...
# 25  {u'pod': u'd'}  [{u'main': u'Rain', u'id': 500, u'icon': u'10d...
# 26  {u'pod': u'd'}  [{u'main': u'Clouds', u'id': 802, u'icon': u'0...
# 27  {u'pod': u'd'}  [{u'main': u'Clouds', u'id': 803, u'icon': u'0...
# 28  {u'pod': u'd'}  [{u'main': u'Rain', u'id': 500, u'icon': u'10d...
# 29  {u'pod': u'n'}  [{u'main': u'Rain', u'id': 500, u'icon': u'10n...
# 30  {u'pod': u'n'}  [{u'main': u'Rain', u'id': 501, u'icon': u'10n...
# 31  {u'pod': u'n'}  [{u'main': u'Rain', u'id': 500, u'icon': u'10n...
# 32  {u'pod': u'd'}  [{u'main': u'Rain', u'id': 500, u'icon': u'10d...
# 33  {u'pod': u'd'}  [{u'main': u'Rain', u'id': 500, u'icon': u'10d...
# 34  {u'pod': u'd'}  [{u'main': u'Rain', u'id': 500, u'icon': u'10d...
# 35  {u'pod': u'd'}  [{u'main': u'Rain', u'id': 500, u'icon': u'10d...
# 36  {u'pod': u'd'}  [{u'main': u'Rain', u'id': 500, u'icon': u'10d...
# 37  {u'pod': u'n'}  [{u'main': u'Clear', u'id': 800, u'icon': u'01...
# 38  {u'pod': u'n'}  [{u'main': u'Clear', u'id': 800, u'icon': u'01...
# 39  {u'pod': u'n'}  [{u'main': u'Clear', u'id': 800, u'icon': u'01...
#
#                                  wind
# 0   {u'speed': 3.42, u'deg': 318.006}
# 1   {u'speed': 3.75, u'deg': 315.003}
# 2       {u'speed': 5.01, u'deg': 322}
# 3   {u'speed': 4.82, u'deg': 321.002}
# 4   {u'speed': 3.57, u'deg': 320.501}
# 5   {u'speed': 1.75, u'deg': 304.502}
# 6   {u'speed': 1.15, u'deg': 264.503}
# 7   {u'speed': 1.69, u'deg': 227.001}
# 8   {u'speed': 1.47, u'deg': 233.501}
# 9       {u'speed': 1.96, u'deg': 258}
# 10  {u'speed': 3.04, u'deg': 269.516}
# 11  {u'speed': 2.96, u'deg': 266.502}
# 12  {u'speed': 3.23, u'deg': 272.002}
# 13  {u'speed': 2.61, u'deg': 274.005}
# 14  {u'speed': 2.56, u'deg': 253.501}
# 15  {u'speed': 2.46, u'deg': 254.001}
# 16  {u'speed': 1.17, u'deg': 240.507}
# 17     {u'speed': 1.9, u'deg': 287.5}
# 18   {u'speed': 2.61, u'deg': 270.01}
# 19  {u'speed': 2.76, u'deg': 300.003}
# 20    {u'speed': 2.51, u'deg': 293.5}
# 21  {u'speed': 2.31, u'deg': 277.002}
# 22  {u'speed': 1.16, u'deg': 277.501}
# 23  {u'speed': 1.16, u'deg': 220.005}
# 24  {u'speed': 1.71, u'deg': 226.502}
# 25    {u'speed': 2.06, u'deg': 254.5}
# 26  {u'speed': 3.12, u'deg': 246.008}
# 27  {u'speed': 3.71, u'deg': 235.001}
# 28    {u'speed': 3.31, u'deg': 220.5}
# 29  {u'speed': 4.56, u'deg': 203.509}
# 30  {u'speed': 3.11, u'deg': 263.002}
# 31      {u'speed': 3.97, u'deg': 277}
# 32     {u'speed': 3.2, u'deg': 261.5}
# 33  {u'speed': 4.47, u'deg': 249.506}
# 34  {u'speed': 4.92, u'deg': 258.501}
# 35  {u'speed': 4.81, u'deg': 264.501}
# 36  {u'speed': 3.57, u'deg': 282.001}
# 37   {u'speed': 2.8, u'deg': 278.005}
# 38      {u'speed': 2.57, u'deg': 278}
# 39  {u'speed': 2.48, u'deg': 270.002}

# %%
#Select data to display, looks like main has the information we need
weather_table_sel= DataFrame(data['list'],columns=['main'])
weather_table_sel
# Out:
#                                                  main
# 0   {u'temp_kf': -2.08, u'temp': 280.61, u'grnd_le...
# 1   {u'temp_kf': -1.97, u'temp': 284.85, u'grnd_le...
# 2   {u'temp_kf': -1.86, u'temp': 287.64, u'grnd_le...
# 3   {u'temp_kf': -1.75, u'temp': 289.06, u'grnd_le...
# 4   {u'temp_kf': -1.64, u'temp': 288.46, u'grnd_le...
# 5   {u'temp_kf': -1.53, u'temp': 283.49, u'grnd_le...
# 6   {u'temp_kf': -1.42, u'temp': 282.98, u'grnd_le...
# 7   {u'temp_kf': -1.31, u'temp': 284.15, u'grnd_le...
# 8   {u'temp_kf': -1.2, u'temp': 284.07, u'grnd_lev...
# 9   {u'temp_kf': -1.1, u'temp': 289.56, u'grnd_lev...
# 10  {u'temp_kf': -0.99, u'temp': 292.55, u'grnd_le...
# 11  {u'temp_kf': -0.88, u'temp': 293.87, u'grnd_le...
# 12  {u'temp_kf': -0.77, u'temp': 292.98, u'grnd_le...
# 13  {u'temp_kf': -0.66, u'temp': 290.57, u'grnd_le...
# 14  {u'temp_kf': -0.55, u'temp': 287.16, u'grnd_le...
# 15  {u'temp_kf': -0.44, u'temp': 285.33, u'grnd_le...
# 16  {u'temp_kf': -0.33, u'temp': 284.01, u'grnd_le...
# 17  {u'temp_kf': -0.22, u'temp': 288.67, u'grnd_le...
# 18  {u'temp_kf': -0.11, u'temp': 291.79, u'grnd_le...
# 19  {u'temp_kf': 0, u'temp': 291.849, u'grnd_level...
# 20  {u'temp_kf': 0, u'temp': 291.27, u'grnd_level'...
# 21  {u'temp_kf': 0, u'temp': 287.218, u'grnd_level...
# 22  {u'temp_kf': 0, u'temp': 284.145, u'grnd_level...
# 23  {u'temp_kf': 0, u'temp': 282.992, u'grnd_level...
# 24  {u'temp_kf': 0, u'temp': 284.531, u'grnd_level...
# 25  {u'temp_kf': 0, u'temp': 287.152, u'grnd_level...
# 26  {u'temp_kf': 0, u'temp': 290.487, u'grnd_level...
# 27  {u'temp_kf': 0, u'temp': 291.486, u'grnd_level...
# 28  {u'temp_kf': 0, u'temp': 290.726, u'grnd_level...
# 29  {u'temp_kf': 0, u'temp': 287.731, u'grnd_level...
# 30  {u'temp_kf': 0, u'temp': 286.777, u'grnd_level...
# 31  {u'temp_kf': 0, u'temp': 285.409, u'grnd_level...
# 32  {u'temp_kf': 0, u'temp': 285.121, u'grnd_level...
# 33  {u'temp_kf': 0, u'temp': 287.257, u'grnd_level...
# 34  {u'temp_kf': 0, u'temp': 288.215, u'grnd_level...
# 35  {u'temp_kf': 0, u'temp': 288.655, u'grnd_level...
# 36  {u'temp_kf': 0, u'temp': 288.563, u'grnd_level...
# 37  {u'temp_kf': 0, u'temp': 285.471, u'grnd_level...
# 38  {u'temp_kf': 0, u'temp': 283.809, u'grnd_level...
# 39  {u'temp_kf': 0, u'temp': 282.673, u'grnd_level...

# %% [markdown]
# ### Discussion:
#
# Further parsing is still required to get the table (DataFrame) in a flat shape.Now it it's your turn, parse the weather data to generate a table with the following information (each in a column):  temp, humidity, rain duration, wind speed, wind degree.
